# %% [markdown]
# # Drizzling WFPC2 Images to use a Single Zeropoint

# %% [markdown]
# <div class="alert-danger">Note: The notebook in this repository 'Initialization.ipynb' goes over many of the basic concepts such as the setup of the environment/package installation and should be read first if you are new to HST images, DrizzlePac, or Astroquery.</div>

# %% [markdown]
# ## Introduction
#
# Extra care must be taken when using `AstroDrizzle` to combine observations from detectors comprised of multiple chips of varying sensitivity. `AstroDrizzle` works with calibrated images in units of counts (electrons or Data Numbers) or count rates and not in units of flux. It assumes that all input frames can be converted to physical flux units using a single inverse-sensitivity factor, recorded in the FITS image headers as `PHOTFLAM`, and the output drizzled product simply copies the `PHOTFLAM` keyword value from the first input image. When this occurs, the inverse-sensitivity will vary across the final drizzled product, and users will need to keep track of which sources fell on which chip when doing photometry. Moreover, varying detector sensitivities will affect the cosmic-ray rejection algorithm used by `AstroDrizzle`, and this may result in the misidentification of some good pixels as cosmic rays.
#
# This is a typical situation when drizzle-combining images from HST instruments with different chip sensitivities, e.g. Wide Field and Planetary Camera 2 (WFPC2). For more detail, see the section on [Gain Variation](http://www.stsci.edu/instruments/wfpc2/Wfpc2_dhb/wfpc2_ch53.html) under 'Position-Dependent Photometric Corrections' in the WFPC2 Data Handbook. As a result, each of the four chips requires a [unique PHOTFLAM](http://www.stsci.edu/instruments/wfpc2/Wfpc2_dhb/wfpc2_ch52.html#1933986) header keyword value. A similar situation may occur when drizzle-combining observations taken over a span of several years as detector's sensitivity declines over time, see e.g. [ACS ISR 2016-03](https://doi.org/10.3847/0004-6256/152/3/60).
#
# One approach is to rescale the input data so that `AstroDrizzle` can properly assume the images/chips have the same sensitivity; that is, a single `PHOTFLAM` value can be used to convert re-scaled image counts (or count-rates) to physical _integrated_ flux units. The `photeq` task in `Drizzlepac` automates this image intensity rescaling to a single inverse-sensitivity factor `PHOTFLAM`.
#
# In this example notebook, archival WFPC2 images are used to demonstrate advanced reprocessing using `TweakReg` and `AstroDrizzle` for alignment and image combination. The notebook is based on a prior WFPC2 [example](http://www.stsci.edu/hst/HST_overview/drizzlepac/examples/example7) but includes additional information about equalizing the chip sensitivities prior to combining.
#
# **NOTE:** It is important to note that `photeq` only adjusts image counts so that _integrated_ physical fluxes can be obtained using a single `PHOTFLAM`. It does nothing to account for different throughtputs at different wavelengths.

# %%
import shutil
import glob
import os
import subprocess

import matplotlib.pyplot as plt
from astropy.io import fits

from astroquery.mast import Observations
from stwcs.updatewcs import updatewcs
from drizzlepac import tweakreg, astrodrizzle, photeq
from stsci.skypac import skymatch

# ONLY needed for the simulation section:
import numpy as np
from stwcs.wcsutil import HSTWCS
from drizzlepac.wfpc2Data import WFPC2_GAINS

# %matplotlib inline
# Out:
# WARNING: AstropyDeprecationWarning: astropy.extern.six will be removed in 4.0, use the six module directly if it is still needed [astropy.extern.six]
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %% [markdown]
# ## 1. Download the Data
#
# This example uses WFPC2 observations of Messier 2 in the F814W filter. The data come from GO proposal [11100](http://www.stsci.edu/cgi-bin/get-proposal-info?id=11100&observatory=HST) _"Two new 'bullets' for MOND: revealing the properties of dark matter in massive merging clusters"_. Four images were acquired using a 4-pt dither box pattern, followed by two images offset with a dither-line pattern.
#
# The data are downloaded using the `astroquery` API to access the [MAST](http://archive.stsci.edu) archive. The `astroquery.mast` [documentation](http://astroquery.readthedocs.io/en/latest/mast/mast.html) has more examples for how to find and download data from MAST.

# %%
# Retrieve the observation information.
if os.path.isdir('mastDownload'):
    shutil.rmtree('mastDownload')
#obs_table = Observations.query_criteria(obs_id='ua0605*', filters='F814W', obstype='ALL')
obs_table = Observations.query_criteria(obs_collection='HST', proposal_id=['10424'],filters='F336W')

products = Observations.get_product_list(obs_table)

# Download only the ua0605*_c0m.fits and ua0605*_c1m.fits (DQ) images:
Observations.download_products(products, mrp_only=False, productSubGroupDescription=['C0M', 'C1M'], extension='fits')

# Move the files from the mastDownload directory to the current working
# directory and make a backup of the files.
fits_files = glob.glob('mastDownload/HST/u*/u*c?m.fits')
for fil in fits_files:
    base_name = os.path.basename(fil)
    if os.path.isfile(base_name):
        os.remove(base_name)
    shutil.move(fil, '.')
    
# Delete the mastDownload directory and all subdirectories it contains.
shutil.rmtree('mastDownload')
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710103m_c0m.fits to ./mastDownload/HST/u9710103m/u9710103m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710103m_c1m.fits to ./mastDownload/HST/u9710103m/u9710103m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710106m_c0m.fits to ./mastDownload/HST/u9710106m/u9710106m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710106m_c1m.fits to ./mastDownload/HST/u9710106m/u9710106m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710109m_c0m.fits to ./mastDownload/HST/u9710109m/u9710109m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710109m_c1m.fits to ./mastDownload/HST/u9710109m/u9710109m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710203m_c0m.fits to ./mastDownload/HST/u9710203m/u9710203m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710203m_c1m.fits to ./mastDownload/HST/u9710203m/u9710203m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710206m_c0m.fits to ./mastDownload/HST/u9710206m/u9710206m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710206m_c1m.fits to ./mastDownload/HST/u9710206m/u9710206m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710209m_c0m.fits to ./mastDownload/HST/u9710209m/u9710209m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710209m_c1m.fits to ./mastDownload/HST/u9710209m/u9710209m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710303m_c0m.fits to ./mastDownload/HST/u9710303m/u9710303m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710303m_c1m.fits to ./mastDownload/HST/u9710303m/u9710303m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710306m_c0m.fits to ./mastDownload/HST/u9710306m/u9710306m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710306m_c1m.fits to ./mastDownload/HST/u9710306m/u9710306m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710403m_c0m.fits to ./mastDownload/HST/u9710403m/u9710403m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710403m_c1m.fits to ./mastDownload/HST/u9710403m/u9710403m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710406m_c0m.fits to ./mastDownload/HST/u9710406m/u9710406m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710406m_c1m.fits to ./mastDownload/HST/u9710406m/u9710406m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710503m_c0m.fits to ./mastDownload/HST/u9710503m/u9710503m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710503m_c1m.fits to ./mastDownload/HST/u9710503m/u9710503m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710506m_c0m.fits to ./mastDownload/HST/u9710506m/u9710506m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710506m_c1m.fits to ./mastDownload/HST/u9710506m/u9710506m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710603m_c0m.fits to ./mastDownload/HST/u9710603m/u9710603m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710603m_c1m.fits to ./mastDownload/HST/u9710603m/u9710603m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710606m_c0m.fits to ./mastDownload/HST/u9710606m/u9710606m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710606m_c1m.fits to ./mastDownload/HST/u9710606m/u9710606m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710703m_c0m.fits to ./mastDownload/HST/u9710703m/u9710703m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710703m_c1m.fits to ./mastDownload/HST/u9710703m/u9710703m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710706m_c0m.fits to ./mastDownload/HST/u9710706m/u9710706m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710706m_c1m.fits to ./mastDownload/HST/u9710706m/u9710706m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710803m_c0m.fits to ./mastDownload/HST/u9710803m/u9710803m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710803m_c1m.fits to ./mastDownload/HST/u9710803m/u9710803m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710806m_c0m.fits to ./mastDownload/HST/u9710806m/u9710806m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710806m_c1m.fits to ./mastDownload/HST/u9710806m/u9710806m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710903m_c0m.fits to ./mastDownload/HST/u9710903m/u9710903m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710903m_c1m.fits to ./mastDownload/HST/u9710903m/u9710903m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710906m_c0m.fits to ./mastDownload/HST/u9710906m/u9710906m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710906m_c1m.fits to ./mastDownload/HST/u9710906m/u9710906m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711003m_c0m.fits to ./mastDownload/HST/u9711003m/u9711003m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711003m_c1m.fits to ./mastDownload/HST/u9711003m/u9711003m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711006m_c0m.fits to ./mastDownload/HST/u9711006m/u9711006m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711006m_c1m.fits to ./mastDownload/HST/u9711006m/u9711006m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711103m_c0m.fits to ./mastDownload/HST/u9711103m/u9711103m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711103m_c1m.fits to ./mastDownload/HST/u9711103m/u9711103m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711106m_c0m.fits to ./mastDownload/HST/u9711106m/u9711106m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711106m_c1m.fits to ./mastDownload/HST/u9711106m/u9711106m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711203m_c0m.fits to ./mastDownload/HST/u9711203m/u9711203m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711203m_c1m.fits to ./mastDownload/HST/u9711203m/u9711203m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711206m_c0m.fits to ./mastDownload/HST/u9711206m/u9711206m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711206m_c1m.fits to ./mastDownload/HST/u9711206m/u9711206m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711209m_c0m.fits to ./mastDownload/HST/u9711209m/u9711209m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711209m_c1m.fits to ./mastDownload/HST/u9711209m/u9711209m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971120cm_c0m.fits to ./mastDownload/HST/u971120cm/u971120cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971120cm_c1m.fits to ./mastDownload/HST/u971120cm/u971120cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971120fm_c0m.fits to ./mastDownload/HST/u971120fm/u971120fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971120fm_c1m.fits to ./mastDownload/HST/u971120fm/u971120fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711303m_c0m.fits to ./mastDownload/HST/u9711303m/u9711303m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711303m_c1m.fits to ./mastDownload/HST/u9711303m/u9711303m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711306m_c0m.fits to ./mastDownload/HST/u9711306m/u9711306m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711306m_c1m.fits to ./mastDownload/HST/u9711306m/u9711306m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711309m_c0m.fits to ./mastDownload/HST/u9711309m/u9711309m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711309m_c1m.fits to ./mastDownload/HST/u9711309m/u9711309m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971130cm_c0m.fits to ./mastDownload/HST/u971130cm/u971130cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971130cm_c1m.fits to ./mastDownload/HST/u971130cm/u971130cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971130fm_c0m.fits to ./mastDownload/HST/u971130fm/u971130fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971130fm_c1m.fits to ./mastDownload/HST/u971130fm/u971130fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711403m_c0m.fits to ./mastDownload/HST/u9711403m/u9711403m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711403m_c1m.fits to ./mastDownload/HST/u9711403m/u9711403m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711406m_c0m.fits to ./mastDownload/HST/u9711406m/u9711406m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711406m_c1m.fits to ./mastDownload/HST/u9711406m/u9711406m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711409m_c0m.fits to ./mastDownload/HST/u9711409m/u9711409m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711409m_c1m.fits to ./mastDownload/HST/u9711409m/u9711409m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971140cm_c0m.fits to ./mastDownload/HST/u971140cm/u971140cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971140cm_c1m.fits to ./mastDownload/HST/u971140cm/u971140cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971140fm_c0m.fits to ./mastDownload/HST/u971140fm/u971140fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971140fm_c1m.fits to ./mastDownload/HST/u971140fm/u971140fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711503m_c0m.fits to ./mastDownload/HST/u9711503m/u9711503m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711503m_c1m.fits to ./mastDownload/HST/u9711503m/u9711503m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711506m_c0m.fits to ./mastDownload/HST/u9711506m/u9711506m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711506m_c1m.fits to ./mastDownload/HST/u9711506m/u9711506m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711509m_c0m.fits to ./mastDownload/HST/u9711509m/u9711509m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711509m_c1m.fits to ./mastDownload/HST/u9711509m/u9711509m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971150cm_c0m.fits to ./mastDownload/HST/u971150cm/u971150cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971150cm_c1m.fits to ./mastDownload/HST/u971150cm/u971150cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971150fm_c0m.fits to ./mastDownload/HST/u971150fm/u971150fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971150fm_c1m.fits to ./mastDownload/HST/u971150fm/u971150fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711603m_c0m.fits to ./mastDownload/HST/u9711603m/u9711603m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711603m_c1m.fits to ./mastDownload/HST/u9711603m/u9711603m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711606m_c0m.fits to ./mastDownload/HST/u9711606m/u9711606m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711606m_c1m.fits to ./mastDownload/HST/u9711606m/u9711606m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711609m_c0m.fits to ./mastDownload/HST/u9711609m/u9711609m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711609m_c1m.fits to ./mastDownload/HST/u9711609m/u9711609m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971160cm_c0m.fits to ./mastDownload/HST/u971160cm/u971160cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971160cm_c1m.fits to ./mastDownload/HST/u971160cm/u971160cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971160fm_c0m.fits to ./mastDownload/HST/u971160fm/u971160fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971160fm_c1m.fits to ./mastDownload/HST/u971160fm/u971160fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711703m_c0m.fits to ./mastDownload/HST/u9711703m/u9711703m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711703m_c1m.fits to ./mastDownload/HST/u9711703m/u9711703m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711706m_c0m.fits to ./mastDownload/HST/u9711706m/u9711706m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711706m_c1m.fits to ./mastDownload/HST/u9711706m/u9711706m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711709m_c0m.fits to ./mastDownload/HST/u9711709m/u9711709m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711709m_c1m.fits to ./mastDownload/HST/u9711709m/u9711709m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971170cm_c0m.fits to ./mastDownload/HST/u971170cm/u971170cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971170cm_c1m.fits to ./mastDownload/HST/u971170cm/u971170cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971170fm_c0m.fits to ./mastDownload/HST/u971170fm/u971170fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971170fm_c1m.fits to ./mastDownload/HST/u971170fm/u971170fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711803m_c0m.fits to ./mastDownload/HST/u9711803m/u9711803m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711803m_c1m.fits to ./mastDownload/HST/u9711803m/u9711803m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711806m_c0m.fits to ./mastDownload/HST/u9711806m/u9711806m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711806m_c1m.fits to ./mastDownload/HST/u9711806m/u9711806m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711809m_c0m.fits to ./mastDownload/HST/u9711809m/u9711809m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711809m_c1m.fits to ./mastDownload/HST/u9711809m/u9711809m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971180cm_c0m.fits to ./mastDownload/HST/u971180cm/u971180cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971180cm_c1m.fits to ./mastDownload/HST/u971180cm/u971180cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971180fm_c0m.fits to ./mastDownload/HST/u971180fm/u971180fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971180fm_c1m.fits to ./mastDownload/HST/u971180fm/u971180fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711903m_c0m.fits to ./mastDownload/HST/u9711903m/u9711903m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711903m_c1m.fits to ./mastDownload/HST/u9711903m/u9711903m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711906m_c0m.fits to ./mastDownload/HST/u9711906m/u9711906m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711906m_c1m.fits to ./mastDownload/HST/u9711906m/u9711906m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711909m_c0m.fits to ./mastDownload/HST/u9711909m/u9711909m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711909m_c1m.fits to ./mastDownload/HST/u9711909m/u9711909m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971190cm_c0m.fits to ./mastDownload/HST/u971190cm/u971190cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971190cm_c1m.fits to ./mastDownload/HST/u971190cm/u971190cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971190fm_c0m.fits to ./mastDownload/HST/u971190fm/u971190fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971190fm_c1m.fits to ./mastDownload/HST/u971190fm/u971190fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712003m_c0m.fits to ./mastDownload/HST/u9712003m/u9712003m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712003m_c1m.fits to ./mastDownload/HST/u9712003m/u9712003m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712006m_c0m.fits to ./mastDownload/HST/u9712006m/u9712006m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712006m_c1m.fits to ./mastDownload/HST/u9712006m/u9712006m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712009m_c0m.fits to ./mastDownload/HST/u9712009m/u9712009m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712009m_c1m.fits to ./mastDownload/HST/u9712009m/u9712009m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971200cm_c0m.fits to ./mastDownload/HST/u971200cm/u971200cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971200cm_c1m.fits to ./mastDownload/HST/u971200cm/u971200cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971200fm_c0m.fits to ./mastDownload/HST/u971200fm/u971200fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971200fm_c1m.fits to ./mastDownload/HST/u971200fm/u971200fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712103m_c0m.fits to ./mastDownload/HST/u9712103m/u9712103m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712103m_c1m.fits to ./mastDownload/HST/u9712103m/u9712103m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712106m_c0m.fits to ./mastDownload/HST/u9712106m/u9712106m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712106m_c1m.fits to ./mastDownload/HST/u9712106m/u9712106m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712109m_c0m.fits to ./mastDownload/HST/u9712109m/u9712109m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712109m_c1m.fits to ./mastDownload/HST/u9712109m/u9712109m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971210cm_c0m.fits to ./mastDownload/HST/u971210cm/u971210cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971210cm_c1m.fits to ./mastDownload/HST/u971210cm/u971210cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971210fm_c0m.fits to ./mastDownload/HST/u971210fm/u971210fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971210fm_c1m.fits to ./mastDownload/HST/u971210fm/u971210fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712203m_c0m.fits to ./mastDownload/HST/u9712203m/u9712203m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712203m_c1m.fits to ./mastDownload/HST/u9712203m/u9712203m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712206m_c0m.fits to ./mastDownload/HST/u9712206m/u9712206m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712206m_c1m.fits to ./mastDownload/HST/u9712206m/u9712206m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712209m_c0m.fits to ./mastDownload/HST/u9712209m/u9712209m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712209m_c1m.fits to ./mastDownload/HST/u9712209m/u9712209m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971220cm_c0m.fits to ./mastDownload/HST/u971220cm/u971220cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971220cm_c1m.fits to ./mastDownload/HST/u971220cm/u971220cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971220fm_c0m.fits to ./mastDownload/HST/u971220fm/u971220fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971220fm_c1m.fits to ./mastDownload/HST/u971220fm/u971220fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712303m_c0m.fits to ./mastDownload/HST/u9712303m/u9712303m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712303m_c1m.fits to ./mastDownload/HST/u9712303m/u9712303m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712306m_c0m.fits to ./mastDownload/HST/u9712306m/u9712306m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712306m_c1m.fits to ./mastDownload/HST/u9712306m/u9712306m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712309m_c0m.fits to ./mastDownload/HST/u9712309m/u9712309m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712309m_c1m.fits to ./mastDownload/HST/u9712309m/u9712309m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971230cm_c0m.fits to ./mastDownload/HST/u971230cm/u971230cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971230cm_c1m.fits to ./mastDownload/HST/u971230cm/u971230cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971230fm_c0m.fits to ./mastDownload/HST/u971230fm/u971230fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971230fm_c1m.fits to ./mastDownload/HST/u971230fm/u971230fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712403m_c0m.fits to ./mastDownload/HST/u9712403m/u9712403m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712403m_c1m.fits to ./mastDownload/HST/u9712403m/u9712403m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712406m_c0m.fits to ./mastDownload/HST/u9712406m/u9712406m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712406m_c1m.fits to ./mastDownload/HST/u9712406m/u9712406m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712409m_c0m.fits to ./mastDownload/HST/u9712409m/u9712409m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712409m_c1m.fits to ./mastDownload/HST/u9712409m/u9712409m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971240cm_c0m.fits to ./mastDownload/HST/u971240cm/u971240cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971240cm_c1m.fits to ./mastDownload/HST/u971240cm/u971240cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971240fm_c0m.fits to ./mastDownload/HST/u971240fm/u971240fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971240fm_c1m.fits to ./mastDownload/HST/u971240fm/u971240fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712503m_c0m.fits to ./mastDownload/HST/u9712503m/u9712503m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712503m_c1m.fits to ./mastDownload/HST/u9712503m/u9712503m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712506m_c0m.fits to ./mastDownload/HST/u9712506m/u9712506m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712506m_c1m.fits to ./mastDownload/HST/u9712506m/u9712506m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712509m_c0m.fits to ./mastDownload/HST/u9712509m/u9712509m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712509m_c1m.fits to ./mastDownload/HST/u9712509m/u9712509m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971250cm_c0m.fits to ./mastDownload/HST/u971250cm/u971250cm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971250cm_c1m.fits to ./mastDownload/HST/u971250cm/u971250cm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971250fm_c0m.fits to ./mastDownload/HST/u971250fm/u971250fm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971250fm_c1m.fits to ./mastDownload/HST/u971250fm/u971250fm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712603m_c0m.fits to ./mastDownload/HST/u9712603m/u9712603m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712603m_c1m.fits to ./mastDownload/HST/u9712603m/u9712603m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712606m_c0m.fits to ./mastDownload/HST/u9712606m/u9712606m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712606m_c1m.fits to ./mastDownload/HST/u9712606m/u9712606m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712609m_c0m.fits to ./mastDownload/HST/u9712609m/u9712609m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712609m_c1m.fits to ./mastDownload/HST/u9712609m/u9712609m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712703m_c0m.fits to ./mastDownload/HST/u9712703m/u9712703m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712703m_c1m.fits to ./mastDownload/HST/u9712703m/u9712703m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712706m_c0m.fits to ./mastDownload/HST/u9712706m/u9712706m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712706m_c1m.fits to ./mastDownload/HST/u9712706m/u9712706m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712803m_c0m.fits to ./mastDownload/HST/u9712803m/u9712803m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712803m_c1m.fits to ./mastDownload/HST/u9712803m/u9712803m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712806m_c0m.fits to ./mastDownload/HST/u9712806m/u9712806m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712806m_c1m.fits to ./mastDownload/HST/u9712806m/u9712806m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712809m_c0m.fits to ./mastDownload/HST/u9712809m/u9712809m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712809m_c1m.fits to ./mastDownload/HST/u9712809m/u9712809m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712903m_c0m.fits to ./mastDownload/HST/u9712903m/u9712903m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712903m_c1m.fits to ./mastDownload/HST/u9712903m/u9712903m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712906m_c0m.fits to ./mastDownload/HST/u9712906m/u9712906m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712906m_c1m.fits to ./mastDownload/HST/u9712906m/u9712906m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712909m_c0m.fits to ./mastDownload/HST/u9712909m/u9712909m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712909m_c1m.fits to ./mastDownload/HST/u9712909m/u9712909m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713003m_c0m.fits to ./mastDownload/HST/u9713003m/u9713003m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713003m_c1m.fits to ./mastDownload/HST/u9713003m/u9713003m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713006m_c0m.fits to ./mastDownload/HST/u9713006m/u9713006m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713006m_c1m.fits to ./mastDownload/HST/u9713006m/u9713006m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713009m_c0m.fits to ./mastDownload/HST/u9713009m/u9713009m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713009m_c1m.fits to ./mastDownload/HST/u9713009m/u9713009m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713103m_c0m.fits to ./mastDownload/HST/u9713103m/u9713103m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713103m_c1m.fits to ./mastDownload/HST/u9713103m/u9713103m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713106m_c0m.fits to ./mastDownload/HST/u9713106m/u9713106m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713106m_c1m.fits to ./mastDownload/HST/u9713106m/u9713106m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713109m_c0m.fits to ./mastDownload/HST/u9713109m/u9713109m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713109m_c1m.fits to ./mastDownload/HST/u9713109m/u9713109m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713203m_c0m.fits to ./mastDownload/HST/u9713203m/u9713203m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713203m_c1m.fits to ./mastDownload/HST/u9713203m/u9713203m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713206m_c0m.fits to ./mastDownload/HST/u9713206m/u9713206m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713206m_c1m.fits to ./mastDownload/HST/u9713206m/u9713206m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713209m_c0m.fits to ./mastDownload/HST/u9713209m/u9713209m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713209m_c1m.fits to ./mastDownload/HST/u9713209m/u9713209m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713303m_c0m.fits to ./mastDownload/HST/u9713303m/u9713303m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713303m_c1m.fits to ./mastDownload/HST/u9713303m/u9713303m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713306m_c0m.fits to ./mastDownload/HST/u9713306m/u9713306m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713306m_c1m.fits to ./mastDownload/HST/u9713306m/u9713306m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713309m_c0m.fits to ./mastDownload/HST/u9713309m/u9713309m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713309m_c1m.fits to ./mastDownload/HST/u9713309m/u9713309m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713403m_c0m.fits to ./mastDownload/HST/u9713403m/u9713403m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713403m_c1m.fits to ./mastDownload/HST/u9713403m/u9713403m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713406m_c0m.fits to ./mastDownload/HST/u9713406m/u9713406m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713406m_c1m.fits to ./mastDownload/HST/u9713406m/u9713406m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713409m_c0m.fits to ./mastDownload/HST/u9713409m/u9713409m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713409m_c1m.fits to ./mastDownload/HST/u9713409m/u9713409m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713503m_c0m.fits to ./mastDownload/HST/u9713503m/u9713503m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713503m_c1m.fits to ./mastDownload/HST/u9713503m/u9713503m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713506m_c0m.fits to ./mastDownload/HST/u9713506m/u9713506m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713506m_c1m.fits to ./mastDownload/HST/u9713506m/u9713506m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713509m_c0m.fits to ./mastDownload/HST/u9713509m/u9713509m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713509m_c1m.fits to ./mastDownload/HST/u9713509m/u9713509m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713603m_c0m.fits to ./mastDownload/HST/u9713603m/u9713603m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713603m_c1m.fits to ./mastDownload/HST/u9713603m/u9713603m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713606m_c0m.fits to ./mastDownload/HST/u9713606m/u9713606m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713606m_c1m.fits to ./mastDownload/HST/u9713606m/u9713606m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713609m_c0m.fits to ./mastDownload/HST/u9713609m/u9713609m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713609m_c1m.fits to ./mastDownload/HST/u9713609m/u9713609m_c1m.fits ... [Done]

# %% [markdown]
# ## 2. Update the WCS
#
# WFPC2 images downloaded from the archive contain World Coordinate System (WCS) information based on an older-style description of image distortions. Before these images can be processed with `drizzlepac`, their WCS must be converted to a new format. This can be achieved using `updatewcs()` function from the `stwcs` package. More details may be found here: ['Making WFPC2 Images Compatible with AstroDrizzle'](http://documents.stsci.edu/hst/HST_overview/documents/DrizzlePac/ch45.html#601857). Note that `updatewcs` is no longer a parameter in AstroDrizzle or TweakReg and must be run separately before processing the data.
#
# First we download the reference files from the CRDS website. See the initialization notebook in this repository for more information.

# %%
os.environ['CRDS_SERVER_URL'] = 'https://hst-crds.stsci.edu'
os.environ['CRDS_PATH'] = os.path.abspath(os.path.join('.', 'reference_files'))

subprocess.check_output('crds bestrefs --files *c0m.fits --sync-references=1 --update-bestrefs', shell=True)

#
os.environ['uref'] = os.path.abspath(os.path.join('.', 'reference_files', 'references', 'hst', 'wfpc2')) + os.path.sep

# %%
! echo $uref
# Out:
# /home/mmarcano/Documents/NGC6397F336W/u9712005F336Copy/Driz/reference_files/references/hst/wfpc2/

# %% [markdown]
# **NOTE:** This next step may raise warnings because the Astrometry database is in progress and currently does not cover the entire sky. Please ignore these warnings. The WCS will still be updated.

# %%
updatewcs('u*c0m.fits', True)
# Out:
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# ...
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 22 for chip 1 : F336W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 188 for chip 2 : F336W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 354 for chip 3 : F336W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 520 for chip 4 : F336W
# - OFFTAB: Offset interpolated from rows 28 and 32
# ['u9710103m_c0m.fits',
#  'u9710106m_c0m.fits',
#  'u9710109m_c0m.fits',
#  'u9710203m_c0m.fits',
#  'u9710206m_c0m.fits',
#  'u9710209m_c0m.fits',
#  'u9710303m_c0m.fits',
#  'u9710306m_c0m.fits',
#  'u9710403m_c0m.fits',
#  'u9710406m_c0m.fits',
#  'u9710503m_c0m.fits',
#  'u9710506m_c0m.fits',
#  'u9710603m_c0m.fits',
#  'u9710606m_c0m.fits',
#  'u9710703m_c0m.fits',
#  'u9710706m_c0m.fits',
#  'u9710803m_c0m.fits',
#  'u9710806m_c0m.fits',
#  'u9710903m_c0m.fits',
#  'u9710906m_c0m.fits',
#  'u9711003m_c0m.fits',
#  'u9711006m_c0m.fits',
#  'u9711103m_c0m.fits',
#  'u9711106m_c0m.fits',
#  'u9711203m_c0m.fits',
#  'u9711206m_c0m.fits',
#  'u9711209m_c0m.fits',
#  'u971120cm_c0m.fits',
#  'u971120fm_c0m.fits',
#  'u9711303m_c0m.fits',
#  'u9711306m_c0m.fits',
#  'u9711309m_c0m.fits',
#  'u971130cm_c0m.fits',
#  'u971130fm_c0m.fits',
#  'u9711403m_c0m.fits',
#  'u9711406m_c0m.fits',
#  'u9711409m_c0m.fits',
#  'u971140cm_c0m.fits',
#  'u971140fm_c0m.fits',
#  'u9711503m_c0m.fits',
#  'u9711506m_c0m.fits',
#  'u9711509m_c0m.fits',
#  'u971150cm_c0m.fits',
#  'u971150fm_c0m.fits',
#  'u9711603m_c0m.fits',
#  'u9711606m_c0m.fits',
#  'u9711609m_c0m.fits',
#  'u971160cm_c0m.fits',
#  'u971160fm_c0m.fits',
#  'u9711703m_c0m.fits',
#  'u9711706m_c0m.fits',
#  'u9711709m_c0m.fits',
#  'u971170cm_c0m.fits',
#  'u971170fm_c0m.fits',
#  'u9711803m_c0m.fits',
#  'u9711806m_c0m.fits',
#  'u9711809m_c0m.fits',
#  'u971180cm_c0m.fits',
#  'u971180fm_c0m.fits',
#  'u9711903m_c0m.fits',
#  'u9711906m_c0m.fits',
#  'u9711909m_c0m.fits',
#  'u971190cm_c0m.fits',
#  'u971190fm_c0m.fits',
#  'u9712003m_c0m.fits',
#  'u9712006m_c0m.fits',
#  'u9712009m_c0m.fits',
#  'u971200cm_c0m.fits',
#  'u971200fm_c0m.fits',
#  'u9712103m_c0m.fits',
#  'u9712106m_c0m.fits',
#  'u9712109m_c0m.fits',
#  'u971210cm_c0m.fits',
#  'u971210fm_c0m.fits',
#  'u9712203m_c0m.fits',
#  'u9712206m_c0m.fits',
#  'u9712209m_c0m.fits',
#  'u971220cm_c0m.fits',
#  'u971220fm_c0m.fits',
#  'u9712303m_c0m.fits',
#  'u9712306m_c0m.fits',
#  'u9712309m_c0m.fits',
#  'u971230cm_c0m.fits',
#  'u971230fm_c0m.fits',
#  'u9712403m_c0m.fits',
#  'u9712406m_c0m.fits',
#  'u9712409m_c0m.fits',
#  'u971240cm_c0m.fits',
#  'u971240fm_c0m.fits',
#  'u9712503m_c0m.fits',
#  'u9712506m_c0m.fits',
#  'u9712509m_c0m.fits',
#  'u971250cm_c0m.fits',
#  'u971250fm_c0m.fits',
#  'u9712603m_c0m.fits',
#  'u9712606m_c0m.fits',
#  'u9712609m_c0m.fits',
#  'u9712703m_c0m.fits',
#  'u9712706m_c0m.fits',
#  'u9712803m_c0m.fits',
#  'u9712806m_c0m.fits',
#  'u9712809m_c0m.fits',
#  'u9712903m_c0m.fits',
#  'u9712906m_c0m.fits',
#  'u9712909m_c0m.fits',
#  'u9713003m_c0m.fits',
#  'u9713006m_c0m.fits',
#  'u9713009m_c0m.fits',
#  'u9713103m_c0m.fits',
#  'u9713106m_c0m.fits',
#  'u9713109m_c0m.fits',
#  'u9713203m_c0m.fits',
#  'u9713206m_c0m.fits',
#  'u9713209m_c0m.fits',
#  'u9713303m_c0m.fits',
#  'u9713306m_c0m.fits',
#  'u9713309m_c0m.fits',
#  'u9713403m_c0m.fits',
#  'u9713406m_c0m.fits',
#  'u9713409m_c0m.fits',
#  'u9713503m_c0m.fits',
#  'u9713506m_c0m.fits',
#  'u9713509m_c0m.fits',
#  'u9713603m_c0m.fits',
#  'u9713606m_c0m.fits',
#  'u9713609m_c0m.fits']

# %% [markdown]
# ### Backup an Image
#
# In a later section we will generate simulated data to illustrate the effects of drizzling WFPC2 images without sensitivity equalization. For that purpose we will need a copy of an original image that has the original inverse-sensitivity values (`PHOTFLAM`) in their headers. Here we create a backup copy of the first image.
#
# **NOTE:** This step is needed for illustration purpose in this notebook only. It is not needed when processing data.

# %%
orig_image = glob.glob('u*c0m.fits')[0]
backup_image = 'simulation.fits'
if os.path.isfile(backup_image):
    os.remove(backup_image)
shutil.copy2(orig_image, backup_image)
# Out:
# 'simulation.fits'

# %% [markdown]
# ## 3. Align the Images
#
# Due to small pointing errors, the image header WCS typically needs to be updated in order to achieve the best drizzle-combined products. The expected pointing accuracy for various observing scenerios is summarized in the DrizzlePac Handbook [Appendix B](http://documents.stsci.edu/hst/HST_overview/documents/DrizzlePac/AppendixB2.html). Input images must first be aligned so that when the coordinates of a given object (in detector space) are converted to sky coordinates (using the WCS), that object's sky coordinates must be approximately equal in each frame.
#
# The `DrizzlePac` task `TweakReg` may be used to correct for any errors in the image header WCS. First, `TweakReg` finds sources in each image, matches sources in common across images, and finds a separate linear transformation to align each image. `TweakReg` then computes a new WCS for each image based on this linear transformation.
#
# Here we show a basic image alignment procedure. For a more detailed illustration of image alignment, please refer to other example notebooks such as the mosaic example in this repository.

# %%
tweakreg.TweakReg('u*c0m.fits', updatehdr=True, reusename=True, interactive=False,
                  conv_width=3.0, threshold=300.0, peakmin=100, peakmax=10000)
# Out:
# Setting up logfile :  tweakreg.log
# TweakReg Version 1.4.7(18-April-2018) started at: 20:27:35.589 (28/10/2019)
#
# Version Information
# --------------------
# Python Version [GCC 7.3.0]
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# numpy Version -> 1.16.4
# astropy Version -> 3.2.1
# stwcs Version -> 1.5.1
#
# Finding shifts for:
#     u9710103m_c0m.fits
#     u9710106m_c0m.fits
#     u9710109m_c0m.fits
#     u9710203m_c0m.fits
#     u9710206m_c0m.fits
#     u9710209m_c0m.fits
#     u9710303m_c0m.fits
#     u9710306m_c0m.fits
#     u9710403m_c0m.fits
#     u9710406m_c0m.fits
#     u9710503m_c0m.fits
#     u9710506m_c0m.fits
#     u9710603m_c0m.fits
#     u9710606m_c0m.fits
#     u9710703m_c0m.fits
#     u9710706m_c0m.fits
#     u9710803m_c0m.fits
#     u9710806m_c0m.fits
#     u9710903m_c0m.fits
#     u9710906m_c0m.fits
#     u9711003m_c0m.fits
#     u9711006m_c0m.fits
#     u9711103m_c0m.fits
#     u9711106m_c0m.fits
#     u9711203m_c0m.fits
#     u9711206m_c0m.fits
#     u9711209m_c0m.fits
#     u971120cm_c0m.fits
#     u971120fm_c0m.fits
#     u9711303m_c0m.fits
#     u9711306m_c0m.fits
#     u9711309m_c0m.fits
#     u971130cm_c0m.fits
#     u971130fm_c0m.fits
#     u9711403m_c0m.fits
#     u9711406m_c0m.fits
#     u9711409m_c0m.fits
#     u971140cm_c0m.fits
#     u971140fm_c0m.fits
#     u9711503m_c0m.fits
#     u9711506m_c0m.fits
#     u9711509m_c0m.fits
#     u971150cm_c0m.fits
#     u971150fm_c0m.fits
#     u9711603m_c0m.fits
#     u9711606m_c0m.fits
#     u9711609m_c0m.fits
#     u971160cm_c0m.fits
#     u971160fm_c0m.fits
#     u9711703m_c0m.fits
#     u9711706m_c0m.fits
#     u9711709m_c0m.fits
#     u971170cm_c0m.fits
#     u971170fm_c0m.fits
#     u9711803m_c0m.fits
#     u9711806m_c0m.fits
#     u9711809m_c0m.fits
#     u971180cm_c0m.fits
#     u971180fm_c0m.fits
#     u9711903m_c0m.fits
#     u9711906m_c0m.fits
#     u9711909m_c0m.fits
#     u971190cm_c0m.fits
#     u971190fm_c0m.fits
#     u9712003m_c0m.fits
#     u9712006m_c0m.fits
#     u9712009m_c0m.fits
#     u971200cm_c0m.fits
#     u971200fm_c0m.fits
#     u9712103m_c0m.fits
#     u9712106m_c0m.fits
#     u9712109m_c0m.fits
#     u971210cm_c0m.fits
#     u971210fm_c0m.fits
#     u9712203m_c0m.fits
#     u9712206m_c0m.fits
#     u9712209m_c0m.fits
#     u971220cm_c0m.fits
#     u971220fm_c0m.fits
#     u9712303m_c0m.fits
#     u9712306m_c0m.fits
#     u9712309m_c0m.fits
#     u971230cm_c0m.fits
#     u971230fm_c0m.fits
#     u9712403m_c0m.fits
#     u9712406m_c0m.fits
#     u9712409m_c0m.fits
#     u971240cm_c0m.fits
#     u971240fm_c0m.fits
#     u9712503m_c0m.fits
#     u9712506m_c0m.fits
#     u9712509m_c0m.fits
#     u971250cm_c0m.fits
#     u971250fm_c0m.fits
#     u9712603m_c0m.fits
#     u9712606m_c0m.fits
#     u9712609m_c0m.fits
#     u9712703m_c0m.fits
#     u9712706m_c0m.fits
#     u9712803m_c0m.fits
#     u9712806m_c0m.fits
#     u9712809m_c0m.fits
#     u9712903m_c0m.fits
#     u9712906m_c0m.fits
#     u9712909m_c0m.fits
#     u9713003m_c0m.fits
#     u9713006m_c0m.fits
#     u9713009m_c0m.fits
#     u9713103m_c0m.fits
#     u9713106m_c0m.fits
#     u9713109m_c0m.fits
#     u9713203m_c0m.fits
#     u9713206m_c0m.fits
#     u9713209m_c0m.fits
#     u9713303m_c0m.fits
#     u9713306m_c0m.fits
#     u9713309m_c0m.fits
#     u9713403m_c0m.fits
#     u9713406m_c0m.fits
#     u9713409m_c0m.fits
#     u9713503m_c0m.fits
#     u9713506m_c0m.fits
#     u9713509m_c0m.fits
#     u9713603m_c0m.fits
#     u9713606m_c0m.fits
#     u9713609m_c0m.fits
#
# ===  Source finding for image 'u9710103m_c0m.fits':
#   #  Source finding for 'u9710103m_c0m.fits', EXT=('SCI', 1) started at: 20:27:35.825 (28/10/2019)
#      Found 403 objects.
#   #  Source finding for 'u9710103m_c0m.fits', EXT=('SCI', 2) started at: 20:27:36.027 (28/10/2019)
#      Found 490 objects.
#   #  Source finding for 'u9710103m_c0m.fits', EXT=('SCI', 3) started at: 20:27:36.17 (28/10/2019)
#      Found 723 objects.
#   #  Source finding for 'u9710103m_c0m.fits', EXT=('SCI', 4) started at: 20:27:36.340 (28/10/2019)
#      Found 499 objects.
# ===  FINAL number of objects in image 'u9710103m_c0m.fits': 2115
#
# ===  Source finding for image 'u9710106m_c0m.fits':
#   #  Source finding for 'u9710106m_c0m.fits', EXT=('SCI', 1) started at: 20:27:37.26 (28/10/2019)
#      Found 489 objects.
#   #  Source finding for 'u9710106m_c0m.fits', EXT=('SCI', 2) started at: 20:27:37.412 (28/10/2019)
#      Found 752 objects.
#   #  Source finding for 'u9710106m_c0m.fits', EXT=('SCI', 3) started at: 20:27:37.585 (28/10/2019)
#      Found 779 objects.
#   #  Source finding for 'u9710106m_c0m.fits', EXT=('SCI', 4) started at: 20:27:37.766 (28/10/2019)
#      Found 643 objects.
# ===  FINAL number of objects in image 'u9710106m_c0m.fits': 2663
#
# ===  Source finding for image 'u9710109m_c0m.fits':
#   #  Source finding for 'u9710109m_c0m.fits', EXT=('SCI', 1) started at: 20:27:38.966 (28/10/2019)
#      Found 382 objects.
#   #  Source finding for 'u9710109m_c0m.fits', EXT=('SCI', 2) started at: 20:27:39.161 (28/10/2019)
#      Found 457 objects.
#   #  Source finding for 'u9710109m_c0m.fits', EXT=('SCI', 3) started at: 20:27:39.39 (28/10/2019)
#      Found 684 objects.
#   #  Source finding for 'u9710109m_c0m.fits', EXT=('SCI', 4) started at: 20:27:39.562 (28/10/2019)
#      Found 600 objects.
# ===  FINAL number of objects in image 'u9710109m_c0m.fits': 2123
#
# ===  Source finding for image 'u9710203m_c0m.fits':
#   #  Source finding for 'u9710203m_c0m.fits', EXT=('SCI', 1) started at: 20:27:40.689 (28/10/2019)
#      Found 337 objects.
#   #  Source finding for 'u9710203m_c0m.fits', EXT=('SCI', 2) started at: 20:27:40.882 (28/10/2019)
#      Found 412 objects.
#   #  Source finding for 'u9710203m_c0m.fits', EXT=('SCI', 3) started at: 20:27:41.098 (28/10/2019)
#      Found 857 objects.
#   #  Source finding for 'u9710203m_c0m.fits', EXT=('SCI', 4) started at: 20:27:41.309 (28/10/2019)
#      Found 627 objects.
# ===  FINAL number of objects in image 'u9710203m_c0m.fits': 2233
#
# ===  Source finding for image 'u9710206m_c0m.fits':
#   #  Source finding for 'u9710206m_c0m.fits', EXT=('SCI', 1) started at: 20:27:42.213 (28/10/2019)
#      Found 646 objects.
#   #  Source finding for 'u9710206m_c0m.fits', EXT=('SCI', 2) started at: 20:27:42.462 (28/10/2019)
#      Found 514 objects.
#   #  Source finding for 'u9710206m_c0m.fits', EXT=('SCI', 3) started at: 20:27:42.694 (28/10/2019)
#      Found 791 objects.
#   #  Source finding for 'u9710206m_c0m.fits', EXT=('SCI', 4) started at: 20:27:42.939 (28/10/2019)
#      Found 532 objects.
# ===  FINAL number of objects in image 'u9710206m_c0m.fits': 2483
#
# ===  Source finding for image 'u9710209m_c0m.fits':
#   #  Source finding for 'u9710209m_c0m.fits', EXT=('SCI', 1) started at: 20:27:43.966 (28/10/2019)
#      Found 561 objects.
#   #  Source finding for 'u9710209m_c0m.fits', EXT=('SCI', 2) started at: 20:27:44.117 (28/10/2019)
#      Found 641 objects.
#   #  Source finding for 'u9710209m_c0m.fits', EXT=('SCI', 3) started at: 20:27:44.280 (28/10/2019)
#      Found 850 objects.
#   #  Source finding for 'u9710209m_c0m.fits', EXT=('SCI', 4) started at: 20:27:44.468 (28/10/2019)
#      Found 559 objects.
# ===  FINAL number of objects in image 'u9710209m_c0m.fits': 2611
#
# ===  Source finding for image 'u9710303m_c0m.fits':
#   #  Source finding for 'u9710303m_c0m.fits', EXT=('SCI', 1) started at: 20:27:45.464 (28/10/2019)
#      Found 416 objects.
#   #  Source finding for 'u9710303m_c0m.fits', EXT=('SCI', 2) started at: 20:27:45.600 (28/10/2019)
#      Found 675 objects.
#   #  Source finding for 'u9710303m_c0m.fits', EXT=('SCI', 3) started at: 20:27:45.760 (28/10/2019)
#      Found 856 objects.
#   #  Source finding for 'u9710303m_c0m.fits', EXT=('SCI', 4) started at: 20:27:45.939 (28/10/2019)
#      Found 529 objects.
# ===  FINAL number of objects in image 'u9710303m_c0m.fits': 2476
#
# ===  Source finding for image 'u9710306m_c0m.fits':
#   #  Source finding for 'u9710306m_c0m.fits', EXT=('SCI', 1) started at: 20:27:46.922 (28/10/2019)
#      Found 401 objects.
#   #  Source finding for 'u9710306m_c0m.fits', EXT=('SCI', 2) started at: 20:27:47.059 (28/10/2019)
#      Found 750 objects.
#   #  Source finding for 'u9710306m_c0m.fits', EXT=('SCI', 3) started at: 20:27:47.226 (28/10/2019)
#      Found 734 objects.
#   #  Source finding for 'u9710306m_c0m.fits', EXT=('SCI', 4) started at: 20:27:47.392 (28/10/2019)
#      Found 560 objects.
# ===  FINAL number of objects in image 'u9710306m_c0m.fits': 2445
#
# ===  Source finding for image 'u9710403m_c0m.fits':
#   #  Source finding for 'u9710403m_c0m.fits', EXT=('SCI', 1) started at: 20:27:48.406 (28/10/2019)
#      Found 478 objects.
#   #  Source finding for 'u9710403m_c0m.fits', EXT=('SCI', 2) started at: 20:27:48.545 (28/10/2019)
#      Found 418 objects.
#   #  Source finding for 'u9710403m_c0m.fits', EXT=('SCI', 3) started at: 20:27:48.68 (28/10/2019)
#      Found 688 objects.
#   #  Source finding for 'u9710403m_c0m.fits', EXT=('SCI', 4) started at: 20:27:48.856 (28/10/2019)
#      Found 478 objects.
# ===  FINAL number of objects in image 'u9710403m_c0m.fits': 2062
#
# ===  Source finding for image 'u9710406m_c0m.fits':
#   #  Source finding for 'u9710406m_c0m.fits', EXT=('SCI', 1) started at: 20:27:49.697 (28/10/2019)
#      Found 922 objects.
#   #  Source finding for 'u9710406m_c0m.fits', EXT=('SCI', 2) started at: 20:27:49.87 (28/10/2019)
#      Found 554 objects.
#   #  Source finding for 'u9710406m_c0m.fits', EXT=('SCI', 3) started at: 20:27:50.045 (28/10/2019)
#      Found 854 objects.
#   #  Source finding for 'u9710406m_c0m.fits', EXT=('SCI', 4) started at: 20:27:50.227 (28/10/2019)
#      Found 595 objects.
# ===  FINAL number of objects in image 'u9710406m_c0m.fits': 2925
#
# ===  Source finding for image 'u9710503m_c0m.fits':
#   #  Source finding for 'u9710503m_c0m.fits', EXT=('SCI', 1) started at: 20:27:51.167 (28/10/2019)
#      Found 783 objects.
#   #  Source finding for 'u9710503m_c0m.fits', EXT=('SCI', 2) started at: 20:27:51.343 (28/10/2019)
#      Found 689 objects.
#   #  Source finding for 'u9710503m_c0m.fits', EXT=('SCI', 3) started at: 20:27:51.510 (28/10/2019)
#      Found 845 objects.
#   #  Source finding for 'u9710503m_c0m.fits', EXT=('SCI', 4) started at: 20:27:51.788 (28/10/2019)
#      Found 616 objects.
# ===  FINAL number of objects in image 'u9710503m_c0m.fits': 2933
#
# ===  Source finding for image 'u9710506m_c0m.fits':
#   #  Source finding for 'u9710506m_c0m.fits', EXT=('SCI', 1) started at: 20:27:53.085 (28/10/2019)
#      Found 1367 objects.
#   #  Source finding for 'u9710506m_c0m.fits', EXT=('SCI', 2) started at: 20:27:53.39 (28/10/2019)
#      Found 454 objects.
#   #  Source finding for 'u9710506m_c0m.fits', EXT=('SCI', 3) started at: 20:27:53.625 (28/10/2019)
#      Found 760 objects.
#   #  Source finding for 'u9710506m_c0m.fits', EXT=('SCI', 4) started at: 20:27:53.884 (28/10/2019)
#      Found 596 objects.
# ===  FINAL number of objects in image 'u9710506m_c0m.fits': 3177
#
# ===  Source finding for image 'u9710603m_c0m.fits':
#   #  Source finding for 'u9710603m_c0m.fits', EXT=('SCI', 1) started at: 20:27:55.005 (28/10/2019)
#      Found 524 objects.
#   #  Source finding for 'u9710603m_c0m.fits', EXT=('SCI', 2) started at: 20:27:55.166 (28/10/2019)
#      Found 477 objects.
#   #  Source finding for 'u9710603m_c0m.fits', EXT=('SCI', 3) started at: 20:27:55.403 (28/10/2019)
#      Found 698 objects.
#   #  Source finding for 'u9710603m_c0m.fits', EXT=('SCI', 4) started at: 20:27:55.645 (28/10/2019)
#      Found 561 objects.
# ===  FINAL number of objects in image 'u9710603m_c0m.fits': 2260
#
# ===  Source finding for image 'u9710606m_c0m.fits':
#   #  Source finding for 'u9710606m_c0m.fits', EXT=('SCI', 1) started at: 20:27:56.523 (28/10/2019)
#      Found 459 objects.
#   #  Source finding for 'u9710606m_c0m.fits', EXT=('SCI', 2) started at: 20:27:56.739 (28/10/2019)
#      Found 537 objects.
#   #  Source finding for 'u9710606m_c0m.fits', EXT=('SCI', 3) started at: 20:27:56.967 (28/10/2019)
#      Found 854 objects.
#   #  Source finding for 'u9710606m_c0m.fits', EXT=('SCI', 4) started at: 20:27:57.22 (28/10/2019)
#      Found 588 objects.
# ===  FINAL number of objects in image 'u9710606m_c0m.fits': 2438
#
# ===  Source finding for image 'u9710703m_c0m.fits':
#   #  Source finding for 'u9710703m_c0m.fits', EXT=('SCI', 1) started at: 20:27:58.324 (28/10/2019)
#      Found 660 objects.
#   #  Source finding for 'u9710703m_c0m.fits', EXT=('SCI', 2) started at: 20:27:58.501 (28/10/2019)
#      Found 446 objects.
#   #  Source finding for 'u9710703m_c0m.fits', EXT=('SCI', 3) started at: 20:27:58.644 (28/10/2019)
#      Found 773 objects.
#   #  Source finding for 'u9710703m_c0m.fits', EXT=('SCI', 4) started at: 20:27:58.81 (28/10/2019)
#      Found 559 objects.
# ===  FINAL number of objects in image 'u9710703m_c0m.fits': 2438
#
# ===  Source finding for image 'u9710706m_c0m.fits':
#   #  Source finding for 'u9710706m_c0m.fits', EXT=('SCI', 1) started at: 20:27:59.773 (28/10/2019)
#      Found 397 objects.
#   #  Source finding for 'u9710706m_c0m.fits', EXT=('SCI', 2) started at: 20:27:59.907 (28/10/2019)
#      Found 495 objects.
#   #  Source finding for 'u9710706m_c0m.fits', EXT=('SCI', 3) started at: 20:28:00.053 (28/10/2019)
#      Found 785 objects.
#   #  Source finding for 'u9710706m_c0m.fits', EXT=('SCI', 4) started at: 20:28:00.226 (28/10/2019)
#      Found 523 objects.
# ===  FINAL number of objects in image 'u9710706m_c0m.fits': 2200
#
# ===  Source finding for image 'u9710803m_c0m.fits':
#   #  Source finding for 'u9710803m_c0m.fits', EXT=('SCI', 1) started at: 20:28:01.119 (28/10/2019)
#      Found 537 objects.
#   #  Source finding for 'u9710803m_c0m.fits', EXT=('SCI', 2) started at: 20:28:01.354 (28/10/2019)
#      Found 415 objects.
#   #  Source finding for 'u9710803m_c0m.fits', EXT=('SCI', 3) started at: 20:28:01.501 (28/10/2019)
#      Found 693 objects.
#   #  Source finding for 'u9710803m_c0m.fits', EXT=('SCI', 4) started at: 20:28:01.669 (28/10/2019)
#      Found 514 objects.
# ===  FINAL number of objects in image 'u9710803m_c0m.fits': 2159
#
# ===  Source finding for image 'u9710806m_c0m.fits':
#   #  Source finding for 'u9710806m_c0m.fits', EXT=('SCI', 1) started at: 20:28:02.582 (28/10/2019)
#      Found 981 objects.
#   #  Source finding for 'u9710806m_c0m.fits', EXT=('SCI', 2) started at: 20:28:02.775 (28/10/2019)
#      Found 620 objects.
#   #  Source finding for 'u9710806m_c0m.fits', EXT=('SCI', 3) started at: 20:28:02.998 (28/10/2019)
#      Found 773 objects.
#   #  Source finding for 'u9710806m_c0m.fits', EXT=('SCI', 4) started at: 20:28:03.176 (28/10/2019)
#      Found 640 objects.
# ===  FINAL number of objects in image 'u9710806m_c0m.fits': 3014
#
# ===  Source finding for image 'u9710903m_c0m.fits':
#   #  Source finding for 'u9710903m_c0m.fits', EXT=('SCI', 1) started at: 20:28:04.084 (28/10/2019)
#      Found 472 objects.
#   #  Source finding for 'u9710903m_c0m.fits', EXT=('SCI', 2) started at: 20:28:04.227 (28/10/2019)
#      Found 513 objects.
#   #  Source finding for 'u9710903m_c0m.fits', EXT=('SCI', 3) started at: 20:28:04.377 (28/10/2019)
#      Found 742 objects.
#   #  Source finding for 'u9710903m_c0m.fits', EXT=('SCI', 4) started at: 20:28:04.55 (28/10/2019)
#      Found 531 objects.
# ===  FINAL number of objects in image 'u9710903m_c0m.fits': 2258
#
# ===  Source finding for image 'u9710906m_c0m.fits':
#   #  Source finding for 'u9710906m_c0m.fits', EXT=('SCI', 1) started at: 20:28:05.637 (28/10/2019)
#      Found 931 objects.
#   #  Source finding for 'u9710906m_c0m.fits', EXT=('SCI', 2) started at: 20:28:05.870 (28/10/2019)
#      Found 566 objects.
#   #  Source finding for 'u9710906m_c0m.fits', EXT=('SCI', 3) started at: 20:28:06.054 (28/10/2019)
#      Found 822 objects.
#   #  Source finding for 'u9710906m_c0m.fits', EXT=('SCI', 4) started at: 20:28:06.240 (28/10/2019)
#      Found 641 objects.
# ===  FINAL number of objects in image 'u9710906m_c0m.fits': 2960
#
# ===  Source finding for image 'u9711003m_c0m.fits':
#   #  Source finding for 'u9711003m_c0m.fits', EXT=('SCI', 1) started at: 20:28:07.263 (28/10/2019)
#      Found 1381 objects.
#   #  Source finding for 'u9711003m_c0m.fits', EXT=('SCI', 2) started at: 20:28:07.589 (28/10/2019)
#      Found 514 objects.
#   #  Source finding for 'u9711003m_c0m.fits', EXT=('SCI', 3) started at: 20:28:07.752 (28/10/2019)
#      Found 724 objects.
#   #  Source finding for 'u9711003m_c0m.fits', EXT=('SCI', 4) started at: 20:28:07.942 (28/10/2019)
#      Found 517 objects.
# ===  FINAL number of objects in image 'u9711003m_c0m.fits': 3136
#
# ===  Source finding for image 'u9711006m_c0m.fits':
#   #  Source finding for 'u9711006m_c0m.fits', EXT=('SCI', 1) started at: 20:28:08.82 (28/10/2019)
#      Found 818 objects.
#   #  Source finding for 'u9711006m_c0m.fits', EXT=('SCI', 2) started at: 20:28:09.017 (28/10/2019)
#      Found 572 objects.
#   #  Source finding for 'u9711006m_c0m.fits', EXT=('SCI', 3) started at: 20:28:09.179 (28/10/2019)
#      Found 772 objects.
#   #  Source finding for 'u9711006m_c0m.fits', EXT=('SCI', 4) started at: 20:28:09.354 (28/10/2019)
#      Found 489 objects.
# ===  FINAL number of objects in image 'u9711006m_c0m.fits': 2651
#
# ===  Source finding for image 'u9711103m_c0m.fits':
#   #  Source finding for 'u9711103m_c0m.fits', EXT=('SCI', 1) started at: 20:28:10.265 (28/10/2019)
#      Found 706 objects.
#   #  Source finding for 'u9711103m_c0m.fits', EXT=('SCI', 2) started at: 20:28:10.445 (28/10/2019)
#      Found 541 objects.
#   #  Source finding for 'u9711103m_c0m.fits', EXT=('SCI', 3) started at: 20:28:10.601 (28/10/2019)
#      Found 703 objects.
#   #  Source finding for 'u9711103m_c0m.fits', EXT=('SCI', 4) started at: 20:28:10.785 (28/10/2019)
#      Found 584 objects.
# ===  FINAL number of objects in image 'u9711103m_c0m.fits': 2534
#
# ===  Source finding for image 'u9711106m_c0m.fits':
#   #  Source finding for 'u9711106m_c0m.fits', EXT=('SCI', 1) started at: 20:28:11.753 (28/10/2019)
#      Found 489 objects.
#   #  Source finding for 'u9711106m_c0m.fits', EXT=('SCI', 2) started at: 20:28:11.927 (28/10/2019)
#      Found 457 objects.
#   #  Source finding for 'u9711106m_c0m.fits', EXT=('SCI', 3) started at: 20:28:12.155 (28/10/2019)
#      Found 685 objects.
#   #  Source finding for 'u9711106m_c0m.fits', EXT=('SCI', 4) started at: 20:28:12.331 (28/10/2019)
#      Found 589 objects.
# ===  FINAL number of objects in image 'u9711106m_c0m.fits': 2220
#
# ===  Source finding for image 'u9711203m_c0m.fits':
#   #  Source finding for 'u9711203m_c0m.fits', EXT=('SCI', 1) started at: 20:28:13.297 (28/10/2019)
#      Found 432 objects.
#   #  Source finding for 'u9711203m_c0m.fits', EXT=('SCI', 2) started at: 20:28:13.466 (28/10/2019)
#      Found 455 objects.
#   #  Source finding for 'u9711203m_c0m.fits', EXT=('SCI', 3) started at: 20:28:13.709 (28/10/2019)
#      Found 630 objects.
#   #  Source finding for 'u9711203m_c0m.fits', EXT=('SCI', 4) started at: 20:28:14.011 (28/10/2019)
#      Found 529 objects.
# ===  FINAL number of objects in image 'u9711203m_c0m.fits': 2046
#
# ===  Source finding for image 'u9711206m_c0m.fits':
#   #  Source finding for 'u9711206m_c0m.fits', EXT=('SCI', 1) started at: 20:28:14.941 (28/10/2019)
#      Found 1114 objects.
#   #  Source finding for 'u9711206m_c0m.fits', EXT=('SCI', 2) started at: 20:28:15.210 (28/10/2019)
#      Found 456 objects.
#   #  Source finding for 'u9711206m_c0m.fits', EXT=('SCI', 3) started at: 20:28:15.409 (28/10/2019)
#      Found 692 objects.
#   #  Source finding for 'u9711206m_c0m.fits', EXT=('SCI', 4) started at: 20:28:15.574 (28/10/2019)
#      Found 789 objects.
# ===  FINAL number of objects in image 'u9711206m_c0m.fits': 3051
#
# ===  Source finding for image 'u9711209m_c0m.fits':
#   #  Source finding for 'u9711209m_c0m.fits', EXT=('SCI', 1) started at: 20:28:16.510 (28/10/2019)
#      Found 883 objects.
#   #  Source finding for 'u9711209m_c0m.fits', EXT=('SCI', 2) started at: 20:28:16.769 (28/10/2019)
#      Found 470 objects.
#   #  Source finding for 'u9711209m_c0m.fits', EXT=('SCI', 3) started at: 20:28:17.003 (28/10/2019)
#      Found 698 objects.
#   #  Source finding for 'u9711209m_c0m.fits', EXT=('SCI', 4) started at: 20:28:17.253 (28/10/2019)
#      Found 674 objects.
# ===  FINAL number of objects in image 'u9711209m_c0m.fits': 2725
#
# ===  Source finding for image 'u971120cm_c0m.fits':
#   #  Source finding for 'u971120cm_c0m.fits', EXT=('SCI', 1) started at: 20:28:18.259 (28/10/2019)
#      Found 391 objects.
#   #  Source finding for 'u971120cm_c0m.fits', EXT=('SCI', 2) started at: 20:28:18.454 (28/10/2019)
#      Found 422 objects.
#   #  Source finding for 'u971120cm_c0m.fits', EXT=('SCI', 3) started at: 20:28:18.670 (28/10/2019)
#      Found 704 objects.
#   #  Source finding for 'u971120cm_c0m.fits', EXT=('SCI', 4) started at: 20:28:18.86 (28/10/2019)
#      Found 663 objects.
# ===  FINAL number of objects in image 'u971120cm_c0m.fits': 2180
#
# ===  Source finding for image 'u971120fm_c0m.fits':
#   #  Source finding for 'u971120fm_c0m.fits', EXT=('SCI', 1) started at: 20:28:19.768 (28/10/2019)
#      Found 337 objects.
#   #  Source finding for 'u971120fm_c0m.fits', EXT=('SCI', 2) started at: 20:28:19.932 (28/10/2019)
#      Found 430 objects.
#   #  Source finding for 'u971120fm_c0m.fits', EXT=('SCI', 3) started at: 20:28:20.147 (28/10/2019)
#      Found 690 objects.
#   #  Source finding for 'u971120fm_c0m.fits', EXT=('SCI', 4) started at: 20:28:20.391 (28/10/2019)
#      Found 512 objects.
# ===  FINAL number of objects in image 'u971120fm_c0m.fits': 1969
#
# ===  Source finding for image 'u9711303m_c0m.fits':
#   #  Source finding for 'u9711303m_c0m.fits', EXT=('SCI', 1) started at: 20:28:21.345 (28/10/2019)
#      Found 654 objects.
#   #  Source finding for 'u9711303m_c0m.fits', EXT=('SCI', 2) started at: 20:28:21.51 (28/10/2019)
#      Found 386 objects.
#   #  Source finding for 'u9711303m_c0m.fits', EXT=('SCI', 3) started at: 20:28:21.655 (28/10/2019)
#      Found 617 objects.
#   #  Source finding for 'u9711303m_c0m.fits', EXT=('SCI', 4) started at: 20:28:21.823 (28/10/2019)
#      Found 463 objects.
# ===  FINAL number of objects in image 'u9711303m_c0m.fits': 2120
#
# ===  Source finding for image 'u9711306m_c0m.fits':
#   #  Source finding for 'u9711306m_c0m.fits', EXT=('SCI', 1) started at: 20:28:22.613 (28/10/2019)
#      Found 408 objects.
#   #  Source finding for 'u9711306m_c0m.fits', EXT=('SCI', 2) started at: 20:28:22.758 (28/10/2019)
#      Found 589 objects.
#   #  Source finding for 'u9711306m_c0m.fits', EXT=('SCI', 3) started at: 20:28:22.931 (28/10/2019)
#      Found 758 objects.
#   #  Source finding for 'u9711306m_c0m.fits', EXT=('SCI', 4) started at: 20:28:23.114 (28/10/2019)
#      Found 553 objects.
# ===  FINAL number of objects in image 'u9711306m_c0m.fits': 2308
#
# ===  Source finding for image 'u9711309m_c0m.fits':
#   #  Source finding for 'u9711309m_c0m.fits', EXT=('SCI', 1) started at: 20:28:24.219 (28/10/2019)
#      Found 237 objects.
#   #  Source finding for 'u9711309m_c0m.fits', EXT=('SCI', 2) started at: 20:28:24.342 (28/10/2019)
#      Found 384 objects.
#   #  Source finding for 'u9711309m_c0m.fits', EXT=('SCI', 3) started at: 20:28:24.481 (28/10/2019)
#      Found 855 objects.
#   #  Source finding for 'u9711309m_c0m.fits', EXT=('SCI', 4) started at: 20:28:24.718 (28/10/2019)
#      Found 574 objects.
# ===  FINAL number of objects in image 'u9711309m_c0m.fits': 2050
#
# ===  Source finding for image 'u971130cm_c0m.fits':
#   #  Source finding for 'u971130cm_c0m.fits', EXT=('SCI', 1) started at: 20:28:25.77 (28/10/2019)
#      Found 441 objects.
#   #  Source finding for 'u971130cm_c0m.fits', EXT=('SCI', 2) started at: 20:28:25.920 (28/10/2019)
#      Found 438 objects.
#   #  Source finding for 'u971130cm_c0m.fits', EXT=('SCI', 3) started at: 20:28:26.093 (28/10/2019)
#      Found 756 objects.
#   #  Source finding for 'u971130cm_c0m.fits', EXT=('SCI', 4) started at: 20:28:26.353 (28/10/2019)
#      Found 564 objects.
# ===  FINAL number of objects in image 'u971130cm_c0m.fits': 2199
#
# ===  Source finding for image 'u971130fm_c0m.fits':
#   #  Source finding for 'u971130fm_c0m.fits', EXT=('SCI', 1) started at: 20:28:27.387 (28/10/2019)
#      Found 407 objects.
#   #  Source finding for 'u971130fm_c0m.fits', EXT=('SCI', 2) started at: 20:28:27.548 (28/10/2019)
#      Found 575 objects.
#   #  Source finding for 'u971130fm_c0m.fits', EXT=('SCI', 3) started at: 20:28:27.760 (28/10/2019)
#      Found 787 objects.
#   #  Source finding for 'u971130fm_c0m.fits', EXT=('SCI', 4) started at: 20:28:27.980 (28/10/2019)
#      Found 452 objects.
# ===  FINAL number of objects in image 'u971130fm_c0m.fits': 2221
#
# ===  Source finding for image 'u9711403m_c0m.fits':
#   #  Source finding for 'u9711403m_c0m.fits', EXT=('SCI', 1) started at: 20:28:28.973 (28/10/2019)
#      Found 322 objects.
#   #  Source finding for 'u9711403m_c0m.fits', EXT=('SCI', 2) started at: 20:28:29.107 (28/10/2019)
#      Found 927 objects.
#   #  Source finding for 'u9711403m_c0m.fits', EXT=('SCI', 3) started at: 20:28:29.314 (28/10/2019)
#      Found 829 objects.
#   #  Source finding for 'u9711403m_c0m.fits', EXT=('SCI', 4) started at: 20:28:29.490 (28/10/2019)
#      Found 513 objects.
# ===  FINAL number of objects in image 'u9711403m_c0m.fits': 2591
#
# ===  Source finding for image 'u9711406m_c0m.fits':
#   #  Source finding for 'u9711406m_c0m.fits', EXT=('SCI', 1) started at: 20:28:30.592 (28/10/2019)
#      Found 770 objects.
#   #  Source finding for 'u9711406m_c0m.fits', EXT=('SCI', 2) started at: 20:28:30.783 (28/10/2019)
#      Found 465 objects.
#   #  Source finding for 'u9711406m_c0m.fits', EXT=('SCI', 3) started at: 20:28:30.938 (28/10/2019)
#      Found 736 objects.
#   #  Source finding for 'u9711406m_c0m.fits', EXT=('SCI', 4) started at: 20:28:31.112 (28/10/2019)
#      Found 672 objects.
# ===  FINAL number of objects in image 'u9711406m_c0m.fits': 2643
#
# ===  Source finding for image 'u9711409m_c0m.fits':
#   #  Source finding for 'u9711409m_c0m.fits', EXT=('SCI', 1) started at: 20:28:32.106 (28/10/2019)
#      Found 607 objects.
#   #  Source finding for 'u9711409m_c0m.fits', EXT=('SCI', 2) started at: 20:28:32.266 (28/10/2019)
#      Found 348 objects.
#   #  Source finding for 'u9711409m_c0m.fits', EXT=('SCI', 3) started at: 20:28:32.402 (28/10/2019)
#      Found 800 objects.
#   #  Source finding for 'u9711409m_c0m.fits', EXT=('SCI', 4) started at: 20:28:32.594 (28/10/2019)
#      Found 1106 objects.
# ===  FINAL number of objects in image 'u9711409m_c0m.fits': 2861
#
# ===  Source finding for image 'u971140cm_c0m.fits':
#   #  Source finding for 'u971140cm_c0m.fits', EXT=('SCI', 1) started at: 20:28:33.775 (28/10/2019)
#      Found 260 objects.
#   #  Source finding for 'u971140cm_c0m.fits', EXT=('SCI', 2) started at: 20:28:33.91 (28/10/2019)
#      Found 349 objects.
#   #  Source finding for 'u971140cm_c0m.fits', EXT=('SCI', 3) started at: 20:28:34.0 (28/10/2019)
#      Found 850 objects.
#   #  Source finding for 'u971140cm_c0m.fits', EXT=('SCI', 4) started at: 20:28:34.29 (28/10/2019)
#      Found 524 objects.
# ===  FINAL number of objects in image 'u971140cm_c0m.fits': 1983
#
# ===  Source finding for image 'u971140fm_c0m.fits':
#   #  Source finding for 'u971140fm_c0m.fits', EXT=('SCI', 1) started at: 20:28:35.410 (28/10/2019)
#      Found 781 objects.
#   #  Source finding for 'u971140fm_c0m.fits', EXT=('SCI', 2) started at: 20:28:35.589 (28/10/2019)
#      Found 400 objects.
#   #  Source finding for 'u971140fm_c0m.fits', EXT=('SCI', 3) started at: 20:28:35.726 (28/10/2019)
#      Found 672 objects.
#   #  Source finding for 'u971140fm_c0m.fits', EXT=('SCI', 4) started at: 20:28:35.889 (28/10/2019)
#      Found 514 objects.
# ===  FINAL number of objects in image 'u971140fm_c0m.fits': 2367
#
# ===  Source finding for image 'u9711503m_c0m.fits':
#   #  Source finding for 'u9711503m_c0m.fits', EXT=('SCI', 1) started at: 20:28:36.91 (28/10/2019)
#      Found 368 objects.
#   #  Source finding for 'u9711503m_c0m.fits', EXT=('SCI', 2) started at: 20:28:37.048 (28/10/2019)
#      Found 429 objects.
#   #  Source finding for 'u9711503m_c0m.fits', EXT=('SCI', 3) started at: 20:28:37.188 (28/10/2019)
#      Found 866 objects.
#   #  Source finding for 'u9711503m_c0m.fits', EXT=('SCI', 4) started at: 20:28:37.36 (28/10/2019)
#      Found 480 objects.
# ===  FINAL number of objects in image 'u9711503m_c0m.fits': 2143
#
# ===  Source finding for image 'u9711506m_c0m.fits':
#   #  Source finding for 'u9711506m_c0m.fits', EXT=('SCI', 1) started at: 20:28:38.256 (28/10/2019)
#      Found 380 objects.
#   #  Source finding for 'u9711506m_c0m.fits', EXT=('SCI', 2) started at: 20:28:38.387 (28/10/2019)
#      Found 395 objects.
#   #  Source finding for 'u9711506m_c0m.fits', EXT=('SCI', 3) started at: 20:28:38.525 (28/10/2019)
#      Found 846 objects.
#   #  Source finding for 'u9711506m_c0m.fits', EXT=('SCI', 4) started at: 20:28:38.702 (28/10/2019)
#      Found 744 objects.
# ===  FINAL number of objects in image 'u9711506m_c0m.fits': 2365
#
# ===  Source finding for image 'u9711509m_c0m.fits':
#   #  Source finding for 'u9711509m_c0m.fits', EXT=('SCI', 1) started at: 20:28:39.52 (28/10/2019)
#      Found 857 objects.
#   #  Source finding for 'u9711509m_c0m.fits', EXT=('SCI', 2) started at: 20:28:39.713 (28/10/2019)
#      Found 419 objects.
#   #  Source finding for 'u9711509m_c0m.fits', EXT=('SCI', 3) started at: 20:28:39.852 (28/10/2019)
#      Found 891 objects.
#   #  Source finding for 'u9711509m_c0m.fits', EXT=('SCI', 4) started at: 20:28:40.034 (28/10/2019)
#      Found 572 objects.
# ===  FINAL number of objects in image 'u9711509m_c0m.fits': 2739
#
# ===  Source finding for image 'u971150cm_c0m.fits':
#   #  Source finding for 'u971150cm_c0m.fits', EXT=('SCI', 1) started at: 20:28:41.169 (28/10/2019)
#      Found 489 objects.
#   #  Source finding for 'u971150cm_c0m.fits', EXT=('SCI', 2) started at: 20:28:41.313 (28/10/2019)
#      Found 434 objects.
#   #  Source finding for 'u971150cm_c0m.fits', EXT=('SCI', 3) started at: 20:28:41.455 (28/10/2019)
#      Found 747 objects.
#   #  Source finding for 'u971150cm_c0m.fits', EXT=('SCI', 4) started at: 20:28:41.627 (28/10/2019)
#      Found 518 objects.
# ===  FINAL number of objects in image 'u971150cm_c0m.fits': 2188
#
# ===  Source finding for image 'u971150fm_c0m.fits':
#   #  Source finding for 'u971150fm_c0m.fits', EXT=('SCI', 1) started at: 20:28:42.683 (28/10/2019)
#      Found 507 objects.
#   #  Source finding for 'u971150fm_c0m.fits', EXT=('SCI', 2) started at: 20:28:42.834 (28/10/2019)
#      Found 567 objects.
#   #  Source finding for 'u971150fm_c0m.fits', EXT=('SCI', 3) started at: 20:28:42.991 (28/10/2019)
#      Found 803 objects.
#   #  Source finding for 'u971150fm_c0m.fits', EXT=('SCI', 4) started at: 20:28:43.172 (28/10/2019)
#      Found 696 objects.
# ===  FINAL number of objects in image 'u971150fm_c0m.fits': 2573
#
# ===  Source finding for image 'u9711603m_c0m.fits':
#   #  Source finding for 'u9711603m_c0m.fits', EXT=('SCI', 1) started at: 20:28:44.213 (28/10/2019)
#      Found 350 objects.
#   #  Source finding for 'u9711603m_c0m.fits', EXT=('SCI', 2) started at: 20:28:44.347 (28/10/2019)
#      Found 380 objects.
#   #  Source finding for 'u9711603m_c0m.fits', EXT=('SCI', 3) started at: 20:28:44.490 (28/10/2019)
#      Found 799 objects.
#   #  Source finding for 'u9711603m_c0m.fits', EXT=('SCI', 4) started at: 20:28:44.668 (28/10/2019)
#      Found 472 objects.
# ===  FINAL number of objects in image 'u9711603m_c0m.fits': 2001
#
# ===  Source finding for image 'u9711606m_c0m.fits':
#   #  Source finding for 'u9711606m_c0m.fits', EXT=('SCI', 1) started at: 20:28:45.49 (28/10/2019)
#      Found 803 objects.
#   #  Source finding for 'u9711606m_c0m.fits', EXT=('SCI', 2) started at: 20:28:45.684 (28/10/2019)
#      Found 421 objects.
#   #  Source finding for 'u9711606m_c0m.fits', EXT=('SCI', 3) started at: 20:28:45.830 (28/10/2019)
#      Found 680 objects.
#   #  Source finding for 'u9711606m_c0m.fits', EXT=('SCI', 4) started at: 20:28:45.99 (28/10/2019)
#      Found 585 objects.
# ===  FINAL number of objects in image 'u9711606m_c0m.fits': 2489
#
# ===  Source finding for image 'u9711609m_c0m.fits':
#   #  Source finding for 'u9711609m_c0m.fits', EXT=('SCI', 1) started at: 20:28:46.960 (28/10/2019)
#      Found 406 objects.
#   #  Source finding for 'u9711609m_c0m.fits', EXT=('SCI', 2) started at: 20:28:47.100 (28/10/2019)
#      Found 484 objects.
#   #  Source finding for 'u9711609m_c0m.fits', EXT=('SCI', 3) started at: 20:28:47.249 (28/10/2019)
#      Found 699 objects.
#   #  Source finding for 'u9711609m_c0m.fits', EXT=('SCI', 4) started at: 20:28:47.42 (28/10/2019)
#      Found 505 objects.
# ===  FINAL number of objects in image 'u9711609m_c0m.fits': 2094
#
# ===  Source finding for image 'u971160cm_c0m.fits':
#   #  Source finding for 'u971160cm_c0m.fits', EXT=('SCI', 1) started at: 20:28:48.383 (28/10/2019)
#      Found 449 objects.
#   #  Source finding for 'u971160cm_c0m.fits', EXT=('SCI', 2) started at: 20:28:48.570 (28/10/2019)
#      Found 381 objects.
#   #  Source finding for 'u971160cm_c0m.fits', EXT=('SCI', 3) started at: 20:28:48.712 (28/10/2019)
#      Found 813 objects.
#   #  Source finding for 'u971160cm_c0m.fits', EXT=('SCI', 4) started at: 20:28:48.896 (28/10/2019)
#      Found 482 objects.
# ===  FINAL number of objects in image 'u971160cm_c0m.fits': 2125
#
# ===  Source finding for image 'u971160fm_c0m.fits':
#   #  Source finding for 'u971160fm_c0m.fits', EXT=('SCI', 1) started at: 20:28:49.869 (28/10/2019)
#      Found 505 objects.
#   #  Source finding for 'u971160fm_c0m.fits', EXT=('SCI', 2) started at: 20:28:50.023 (28/10/2019)
#      Found 402 objects.
#   #  Source finding for 'u971160fm_c0m.fits', EXT=('SCI', 3) started at: 20:28:50.190 (28/10/2019)
#      Found 681 objects.
#   #  Source finding for 'u971160fm_c0m.fits', EXT=('SCI', 4) started at: 20:28:50.426 (28/10/2019)
#      Found 493 objects.
# ===  FINAL number of objects in image 'u971160fm_c0m.fits': 2081
#
# ===  Source finding for image 'u9711703m_c0m.fits':
#   #  Source finding for 'u9711703m_c0m.fits', EXT=('SCI', 1) started at: 20:28:51.356 (28/10/2019)
#      Found 700 objects.
#   #  Source finding for 'u9711703m_c0m.fits', EXT=('SCI', 2) started at: 20:28:51.579 (28/10/2019)
#      Found 548 objects.
#   #  Source finding for 'u9711703m_c0m.fits', EXT=('SCI', 3) started at: 20:28:51.756 (28/10/2019)
#      Found 769 objects.
#   #  Source finding for 'u9711703m_c0m.fits', EXT=('SCI', 4) started at: 20:28:51.943 (28/10/2019)
#      Found 696 objects.
# ===  FINAL number of objects in image 'u9711703m_c0m.fits': 2713
#
# ===  Source finding for image 'u9711706m_c0m.fits':
#   #  Source finding for 'u9711706m_c0m.fits', EXT=('SCI', 1) started at: 20:28:52.911 (28/10/2019)
#      Found 829 objects.
#   #  Source finding for 'u9711706m_c0m.fits', EXT=('SCI', 2) started at: 20:28:53.091 (28/10/2019)
#      Found 503 objects.
#   #  Source finding for 'u9711706m_c0m.fits', EXT=('SCI', 3) started at: 20:28:53.260 (28/10/2019)
#      Found 714 objects.
#   #  Source finding for 'u9711706m_c0m.fits', EXT=('SCI', 4) started at: 20:28:53.432 (28/10/2019)
#      Found 851 objects.
# ===  FINAL number of objects in image 'u9711706m_c0m.fits': 2897
#
# ===  Source finding for image 'u9711709m_c0m.fits':
#   #  Source finding for 'u9711709m_c0m.fits', EXT=('SCI', 1) started at: 20:28:54.418 (28/10/2019)
#      Found 456 objects.
#   #  Source finding for 'u9711709m_c0m.fits', EXT=('SCI', 2) started at: 20:28:54.576 (28/10/2019)
#      Found 405 objects.
#   #  Source finding for 'u9711709m_c0m.fits', EXT=('SCI', 3) started at: 20:28:54.76 (28/10/2019)
#      Found 776 objects.
#   #  Source finding for 'u9711709m_c0m.fits', EXT=('SCI', 4) started at: 20:28:54.987 (28/10/2019)
#      Found 832 objects.
# ===  FINAL number of objects in image 'u9711709m_c0m.fits': 2469
#
# ===  Source finding for image 'u971170cm_c0m.fits':
#   #  Source finding for 'u971170cm_c0m.fits', EXT=('SCI', 1) started at: 20:28:55.939 (28/10/2019)
#      Found 1006 objects.
#   #  Source finding for 'u971170cm_c0m.fits', EXT=('SCI', 2) started at: 20:28:56.166 (28/10/2019)
#      Found 452 objects.
#   #  Source finding for 'u971170cm_c0m.fits', EXT=('SCI', 3) started at: 20:28:56.312 (28/10/2019)
#      Found 755 objects.
#   #  Source finding for 'u971170cm_c0m.fits', EXT=('SCI', 4) started at: 20:28:56.495 (28/10/2019)
#      Found 501 objects.
# ===  FINAL number of objects in image 'u971170cm_c0m.fits': 2714
#
# ===  Source finding for image 'u971170fm_c0m.fits':
#   #  Source finding for 'u971170fm_c0m.fits', EXT=('SCI', 1) started at: 20:28:57.470 (28/10/2019)
#      Found 1002 objects.
#   #  Source finding for 'u971170fm_c0m.fits', EXT=('SCI', 2) started at: 20:28:57.685 (28/10/2019)
#      Found 574 objects.
#   #  Source finding for 'u971170fm_c0m.fits', EXT=('SCI', 3) started at: 20:28:57.843 (28/10/2019)
#      Found 745 objects.
#   #  Source finding for 'u971170fm_c0m.fits', EXT=('SCI', 4) started at: 20:28:58.025 (28/10/2019)
#      Found 600 objects.
# ===  FINAL number of objects in image 'u971170fm_c0m.fits': 2921
#
# ===  Source finding for image 'u9711803m_c0m.fits':
#   #  Source finding for 'u9711803m_c0m.fits', EXT=('SCI', 1) started at: 20:28:59.137 (28/10/2019)
#      Found 866 objects.
#   #  Source finding for 'u9711803m_c0m.fits', EXT=('SCI', 2) started at: 20:28:59.392 (28/10/2019)
#      Found 402 objects.
#   #  Source finding for 'u9711803m_c0m.fits', EXT=('SCI', 3) started at: 20:28:59.563 (28/10/2019)
#      Found 698 objects.
#   #  Source finding for 'u9711803m_c0m.fits', EXT=('SCI', 4) started at: 20:28:59.740 (28/10/2019)
#      Found 507 objects.
# ===  FINAL number of objects in image 'u9711803m_c0m.fits': 2473
#
# ===  Source finding for image 'u9711806m_c0m.fits':
#   #  Source finding for 'u9711806m_c0m.fits', EXT=('SCI', 1) started at: 20:29:00.689 (28/10/2019)
#      Found 519 objects.
#   #  Source finding for 'u9711806m_c0m.fits', EXT=('SCI', 2) started at: 20:29:00.841 (28/10/2019)
#      Found 523 objects.
#   #  Source finding for 'u9711806m_c0m.fits', EXT=('SCI', 3) started at: 20:29:00.997 (28/10/2019)
#      Found 729 objects.
#   #  Source finding for 'u9711806m_c0m.fits', EXT=('SCI', 4) started at: 20:29:01.170 (28/10/2019)
#      Found 891 objects.
# ===  FINAL number of objects in image 'u9711806m_c0m.fits': 2662
#
# ===  Source finding for image 'u9711809m_c0m.fits':
#   #  Source finding for 'u9711809m_c0m.fits', EXT=('SCI', 1) started at: 20:29:02.243 (28/10/2019)
#      Found 448 objects.
#   #  Source finding for 'u9711809m_c0m.fits', EXT=('SCI', 2) started at: 20:29:02.390 (28/10/2019)
#      Found 371 objects.
#   #  Source finding for 'u9711809m_c0m.fits', EXT=('SCI', 3) started at: 20:29:02.533 (28/10/2019)
#      Found 642 objects.
#   #  Source finding for 'u9711809m_c0m.fits', EXT=('SCI', 4) started at: 20:29:02.704 (28/10/2019)
#      Found 493 objects.
# ===  FINAL number of objects in image 'u9711809m_c0m.fits': 1954
#
# ===  Source finding for image 'u971180cm_c0m.fits':
#   #  Source finding for 'u971180cm_c0m.fits', EXT=('SCI', 1) started at: 20:29:03.526 (28/10/2019)
#      Found 884 objects.
#   #  Source finding for 'u971180cm_c0m.fits', EXT=('SCI', 2) started at: 20:29:03.717 (28/10/2019)
#      Found 474 objects.
#   #  Source finding for 'u971180cm_c0m.fits', EXT=('SCI', 3) started at: 20:29:03.867 (28/10/2019)
#      Found 678 objects.
#   #  Source finding for 'u971180cm_c0m.fits', EXT=('SCI', 4) started at: 20:29:04.035 (28/10/2019)
#      Found 620 objects.
# ===  FINAL number of objects in image 'u971180cm_c0m.fits': 2656
#
# ===  Source finding for image 'u971180fm_c0m.fits':
#   #  Source finding for 'u971180fm_c0m.fits', EXT=('SCI', 1) started at: 20:29:04.883 (28/10/2019)
#      Found 644 objects.
#   #  Source finding for 'u971180fm_c0m.fits', EXT=('SCI', 2) started at: 20:29:05.044 (28/10/2019)
#      Found 464 objects.
#   #  Source finding for 'u971180fm_c0m.fits', EXT=('SCI', 3) started at: 20:29:05.190 (28/10/2019)
#      Found 868 objects.
#   #  Source finding for 'u971180fm_c0m.fits', EXT=('SCI', 4) started at: 20:29:05.377 (28/10/2019)
#      Found 626 objects.
# ===  FINAL number of objects in image 'u971180fm_c0m.fits': 2602
#
# ===  Source finding for image 'u9711903m_c0m.fits':
#   #  Source finding for 'u9711903m_c0m.fits', EXT=('SCI', 1) started at: 20:29:06.348 (28/10/2019)
#      Found 746 objects.
#   #  Source finding for 'u9711903m_c0m.fits', EXT=('SCI', 2) started at: 20:29:06.536 (28/10/2019)
#      Found 541 objects.
#   #  Source finding for 'u9711903m_c0m.fits', EXT=('SCI', 3) started at: 20:29:06.717 (28/10/2019)
#      Found 752 objects.
#   #  Source finding for 'u9711903m_c0m.fits', EXT=('SCI', 4) started at: 20:29:06.9 (28/10/2019)
#      Found 469 objects.
# ===  FINAL number of objects in image 'u9711903m_c0m.fits': 2508
#
# ===  Source finding for image 'u9711906m_c0m.fits':
#   #  Source finding for 'u9711906m_c0m.fits', EXT=('SCI', 1) started at: 20:29:07.949 (28/10/2019)
#      Found 1097 objects.
#   #  Source finding for 'u9711906m_c0m.fits', EXT=('SCI', 2) started at: 20:29:08.153 (28/10/2019)
#      Found 783 objects.
#   #  Source finding for 'u9711906m_c0m.fits', EXT=('SCI', 3) started at: 20:29:08.330 (28/10/2019)
#      Found 719 objects.
#   #  Source finding for 'u9711906m_c0m.fits', EXT=('SCI', 4) started at: 20:29:08.504 (28/10/2019)
#      Found 1189 objects.
# ===  FINAL number of objects in image 'u9711906m_c0m.fits': 3788
#
# ===  Source finding for image 'u9711909m_c0m.fits':
#   #  Source finding for 'u9711909m_c0m.fits', EXT=('SCI', 1) started at: 20:29:09.687 (28/10/2019)
#      Found 729 objects.
#   #  Source finding for 'u9711909m_c0m.fits', EXT=('SCI', 2) started at: 20:29:09.902 (28/10/2019)
#      Found 504 objects.
#   #  Source finding for 'u9711909m_c0m.fits', EXT=('SCI', 3) started at: 20:29:10.054 (28/10/2019)
#      Found 693 objects.
#   #  Source finding for 'u9711909m_c0m.fits', EXT=('SCI', 4) started at: 20:29:10.228 (28/10/2019)
#      Found 626 objects.
# ===  FINAL number of objects in image 'u9711909m_c0m.fits': 2552
#
# ===  Source finding for image 'u971190cm_c0m.fits':
#   #  Source finding for 'u971190cm_c0m.fits', EXT=('SCI', 1) started at: 20:29:11.2 (28/10/2019)
#      Found 1456 objects.
#   #  Source finding for 'u971190cm_c0m.fits', EXT=('SCI', 2) started at: 20:29:11.632 (28/10/2019)
#      Found 564 objects.
#   #  Source finding for 'u971190cm_c0m.fits', EXT=('SCI', 3) started at: 20:29:11.866 (28/10/2019)
#      Found 753 objects.
#   #  Source finding for 'u971190cm_c0m.fits', EXT=('SCI', 4) started at: 20:29:12.12 (28/10/2019)
#      Found 605 objects.
# ===  FINAL number of objects in image 'u971190cm_c0m.fits': 3378
#
# ===  Source finding for image 'u971190fm_c0m.fits':
#   #  Source finding for 'u971190fm_c0m.fits', EXT=('SCI', 1) started at: 20:29:13.175 (28/10/2019)
#      Found 590 objects.
#   #  Source finding for 'u971190fm_c0m.fits', EXT=('SCI', 2) started at: 20:29:13.32 (28/10/2019)
#      Found 561 objects.
#   #  Source finding for 'u971190fm_c0m.fits', EXT=('SCI', 3) started at: 20:29:13.483 (28/10/2019)
#      Found 756 objects.
#   #  Source finding for 'u971190fm_c0m.fits', EXT=('SCI', 4) started at: 20:29:13.704 (28/10/2019)
#      Found 652 objects.
# ===  FINAL number of objects in image 'u971190fm_c0m.fits': 2559
#
# ===  Source finding for image 'u9712003m_c0m.fits':
#   #  Source finding for 'u9712003m_c0m.fits', EXT=('SCI', 1) started at: 20:29:14.893 (28/10/2019)
#      Found 922 objects.
#   #  Source finding for 'u9712003m_c0m.fits', EXT=('SCI', 2) started at: 20:29:15.107 (28/10/2019)
#      Found 407 objects.
#   #  Source finding for 'u9712003m_c0m.fits', EXT=('SCI', 3) started at: 20:29:15.243 (28/10/2019)
#      Found 589 objects.
#   #  Source finding for 'u9712003m_c0m.fits', EXT=('SCI', 4) started at: 20:29:15.399 (28/10/2019)
#      Found 630 objects.
# ===  FINAL number of objects in image 'u9712003m_c0m.fits': 2548
#
# ===  Source finding for image 'u9712006m_c0m.fits':
#   #  Source finding for 'u9712006m_c0m.fits', EXT=('SCI', 1) started at: 20:29:16.419 (28/10/2019)
#      Found 759 objects.
#   #  Source finding for 'u9712006m_c0m.fits', EXT=('SCI', 2) started at: 20:29:16.591 (28/10/2019)
#      Found 389 objects.
#   #  Source finding for 'u9712006m_c0m.fits', EXT=('SCI', 3) started at: 20:29:16.72 (28/10/2019)
#      Found 788 objects.
#   #  Source finding for 'u9712006m_c0m.fits', EXT=('SCI', 4) started at: 20:29:17.00 (28/10/2019)
#      Found 512 objects.
# ===  FINAL number of objects in image 'u9712006m_c0m.fits': 2448
#
# ===  Source finding for image 'u9712009m_c0m.fits':
#   #  Source finding for 'u9712009m_c0m.fits', EXT=('SCI', 1) started at: 20:29:17.890 (28/10/2019)
#      Found 366 objects.
#   #  Source finding for 'u9712009m_c0m.fits', EXT=('SCI', 2) started at: 20:29:18.020 (28/10/2019)
#      Found 439 objects.
#   #  Source finding for 'u9712009m_c0m.fits', EXT=('SCI', 3) started at: 20:29:18.200 (28/10/2019)
#      Found 686 objects.
#   #  Source finding for 'u9712009m_c0m.fits', EXT=('SCI', 4) started at: 20:29:18.401 (28/10/2019)
#      Found 494 objects.
# ===  FINAL number of objects in image 'u9712009m_c0m.fits': 1985
#
# ===  Source finding for image 'u971200cm_c0m.fits':
#   #  Source finding for 'u971200cm_c0m.fits', EXT=('SCI', 1) started at: 20:29:19.312 (28/10/2019)
#      Found 1245 objects.
#   #  Source finding for 'u971200cm_c0m.fits', EXT=('SCI', 2) started at: 20:29:19.618 (28/10/2019)
#      Found 536 objects.
#   #  Source finding for 'u971200cm_c0m.fits', EXT=('SCI', 3) started at: 20:29:19.852 (28/10/2019)
#      Found 800 objects.
#   #  Source finding for 'u971200cm_c0m.fits', EXT=('SCI', 4) started at: 20:29:20.099 (28/10/2019)
#      Found 498 objects.
# ===  FINAL number of objects in image 'u971200cm_c0m.fits': 3079
#
# ===  Source finding for image 'u971200fm_c0m.fits':
#   #  Source finding for 'u971200fm_c0m.fits', EXT=('SCI', 1) started at: 20:29:21.125 (28/10/2019)
#      Found 703 objects.
#   #  Source finding for 'u971200fm_c0m.fits', EXT=('SCI', 2) started at: 20:29:21.379 (28/10/2019)
#      Found 669 objects.
#   #  Source finding for 'u971200fm_c0m.fits', EXT=('SCI', 3) started at: 20:29:21.628 (28/10/2019)
#      Found 818 objects.
#   #  Source finding for 'u971200fm_c0m.fits', EXT=('SCI', 4) started at: 20:29:21.883 (28/10/2019)
#      Found 610 objects.
# ===  FINAL number of objects in image 'u971200fm_c0m.fits': 2800
#
# ===  Source finding for image 'u9712103m_c0m.fits':
#   #  Source finding for 'u9712103m_c0m.fits', EXT=('SCI', 1) started at: 20:29:22.873 (28/10/2019)
#      Found 443 objects.
#   #  Source finding for 'u9712103m_c0m.fits', EXT=('SCI', 2) started at: 20:29:23.08 (28/10/2019)
#      Found 419 objects.
#   #  Source finding for 'u9712103m_c0m.fits', EXT=('SCI', 3) started at: 20:29:23.280 (28/10/2019)
#      Found 764 objects.
#   #  Source finding for 'u9712103m_c0m.fits', EXT=('SCI', 4) started at: 20:29:23.543 (28/10/2019)
#      Found 576 objects.
# ===  FINAL number of objects in image 'u9712103m_c0m.fits': 2202
#
# ===  Source finding for image 'u9712106m_c0m.fits':
#   #  Source finding for 'u9712106m_c0m.fits', EXT=('SCI', 1) started at: 20:29:24.517 (28/10/2019)
#      Found 894 objects.
#   #  Source finding for 'u9712106m_c0m.fits', EXT=('SCI', 2) started at: 20:29:24.74 (28/10/2019)
#      Found 507 objects.
#   #  Source finding for 'u9712106m_c0m.fits', EXT=('SCI', 3) started at: 20:29:24.91 (28/10/2019)
#      Found 830 objects.
#   #  Source finding for 'u9712106m_c0m.fits', EXT=('SCI', 4) started at: 20:29:25.14 (28/10/2019)
#      Found 588 objects.
# ===  FINAL number of objects in image 'u9712106m_c0m.fits': 2819
#
# ===  Source finding for image 'u9712109m_c0m.fits':
#   #  Source finding for 'u9712109m_c0m.fits', EXT=('SCI', 1) started at: 20:29:26.143 (28/10/2019)
#      Found 348 objects.
#   #  Source finding for 'u9712109m_c0m.fits', EXT=('SCI', 2) started at: 20:29:26.289 (28/10/2019)
#      Found 687 objects.
#   #  Source finding for 'u9712109m_c0m.fits', EXT=('SCI', 3) started at: 20:29:26.450 (28/10/2019)
#      Found 808 objects.
#   #  Source finding for 'u9712109m_c0m.fits', EXT=('SCI', 4) started at: 20:29:26.623 (28/10/2019)
#      Found 777 objects.
# ===  FINAL number of objects in image 'u9712109m_c0m.fits': 2620
#
# ===  Source finding for image 'u971210cm_c0m.fits':
#   #  Source finding for 'u971210cm_c0m.fits', EXT=('SCI', 1) started at: 20:29:27.6 (28/10/2019)
#      Found 695 objects.
#   #  Source finding for 'u971210cm_c0m.fits', EXT=('SCI', 2) started at: 20:29:27.872 (28/10/2019)
#      Found 474 objects.
#   #  Source finding for 'u971210cm_c0m.fits', EXT=('SCI', 3) started at: 20:29:28.083 (28/10/2019)
#      Found 823 objects.
#   #  Source finding for 'u971210cm_c0m.fits', EXT=('SCI', 4) started at: 20:29:28.346 (28/10/2019)
#      Found 553 objects.
# ===  FINAL number of objects in image 'u971210cm_c0m.fits': 2545
#
# ===  Source finding for image 'u971210fm_c0m.fits':
#   #  Source finding for 'u971210fm_c0m.fits', EXT=('SCI', 1) started at: 20:29:29.41 (28/10/2019)
#      Found 1404 objects.
#   #  Source finding for 'u971210fm_c0m.fits', EXT=('SCI', 2) started at: 20:29:29.761 (28/10/2019)
# ...
# NAXIS    : 800 800
# Plate Scale : 0.04551692958714395
# ORIENTAT : -44.7068995735214
# WCSNAME  :  TWEAK
#
# Processing u9713409m_c0m.fits['SCI',2]
#
# Updating header for u9713409m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.9622516032463965e-05 1.948125251185846e-05
# CD_21  CD_22: 1.948656668418197e-05 1.9621948333390644e-05
# CRVAL    : 265.14802489267737 -53.651190789250485
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09955631585206429
# ORIENTAT : 44.7938470046526
# WCSNAME  :  TWEAK
#
# Processing u9713409m_c0m.fits['SCI',3]
#
# Updating header for u9713409m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.9580954133381426e-05 1.9517576336843955e-05
# CD_21  CD_22: 1.9520859808958544e-05 -1.9579942955079796e-05
# CRVAL    : 265.17264405718487 -53.66603756594104
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09953732852691638
# ORIENTAT : 135.0913955934116
# WCSNAME  :  TWEAK
#
# Processing u9713409m_c0m.fits['SCI',4]
#
# Updating header for u9713409m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9329461472448657e-05 -1.978853663350598e-05
# CD_21  CD_22: -1.9788179513411546e-05 -1.9333052182057702e-05
# CRVAL    : 265.1471297562224 -53.68107654723178
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.0995843465636356
# ORIENTAT : -134.33294739852263
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713503m_c0m.fits
#
# Matching sources from 'u9713503m_c0m.fits' with sources from reference image 'u9710103m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.04135981341670458 -0.563098943851486
#     with significance of  2076.398833409568 and  570.0  matches
# Found 1058 matches for u9713503m_c0m.fits...
# Computed  rscale  fit for  u9713503m_c0m.fits :
# XSH: 0.2233  YSH: 0.0362    ROT: 0.000401536485    SCALE: 1.000043
# XRMS: 0.13    YRMS: 0.099
#
# RMS_RA: 3.4e-06 (deg)   RMS_DEC: 2.3e-07 (deg)
#
# Final solution based on  999  objects.
# wrote XY data to:  u9713503m_c0m_catalog_fit.match
# Total # points:  999
# # of points after clipping:  999
# Total # points:  999
# # of points after clipping:  999
# Initializing new WCSCORR table for  u9713503m_c0m.fits
#
# ....Updating header for u9713503m_c0m.fits...
#
#
# Processing u9713503m_c0m.fits['SCI',1]
#
# Updating header for u9713503m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -8.99765068920014e-06 -8.891877391643484e-06
# CD_21  CD_22: -8.881942464652289e-06 8.98319257234293e-06
# CRVAL    : 265.13597941583924 -53.66655996323807
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.04551694419686874
# ORIENTAT : -44.70730581990039
# WCSNAME  :  TWEAK
#
# Processing u9713503m_c0m.fits['SCI',2]
#
# Updating header for u9713503m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.962185583565591e-05 1.948032096798661e-05
# CD_21  CD_22: 1.9485634948515627e-05 1.96212880909746e-05
# CRVAL    : 265.14799480675555 -53.651399323886245
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09955634808731545
# ORIENTAT : 44.79344107825179
# WCSNAME  :  TWEAK
#
# Processing u9713503m_c0m.fits['SCI',3]
#
# Updating header for u9713503m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.958001939188942e-05 1.951692086866365e-05
# CD_21  CD_22: 1.952020417609737e-05 -1.9579008302645216e-05
# CRVAL    : 265.1726132564951 -53.66624539437323
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09953736067934763
# ORIENTAT : 135.09099016221916
# WCSNAME  :  TWEAK
#
# Processing u9713503m_c0m.fits['SCI',4]
#
# Updating header for u9713503m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9328815371093054e-05 -1.97875944921455e-05
# CD_21  CD_22: -1.9787237503030665e-05 -1.9332405940417864e-05
# CRVAL    : 265.1471000602555 -53.68128386398075
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.0995843787950024
# ORIENTAT : -134.33335363750933
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713506m_c0m.fits
#
# Matching sources from 'u9713506m_c0m.fits' with sources from reference image 'u9710103m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.08963676746149574 -0.23451309254983244
#     with significance of  2397.395976524105 and  695.0  matches
# Found 1065 matches for u9713506m_c0m.fits...
# Computed  rscale  fit for  u9713506m_c0m.fits :
# XSH: 0.1636  YSH: 0.1277    ROT: 0.001136146823    SCALE: 1.000027
# XRMS: 0.098    YRMS: 0.12
#
# RMS_RA: 3.3e-06 (deg)   RMS_DEC: 2.1e-07 (deg)
#
# Final solution based on  991  objects.
# wrote XY data to:  u9713506m_c0m_catalog_fit.match
# Total # points:  991
# # of points after clipping:  991
# Total # points:  991
# # of points after clipping:  991
# Initializing new WCSCORR table for  u9713506m_c0m.fits
#
# ....Updating header for u9713506m_c0m.fits...
#
#
# Processing u9713506m_c0m.fits['SCI',1]
#
# Updating header for u9713506m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -8.997902547687961e-06 -8.89192940699854e-06
# CD_21  CD_22: -8.881994116766418e-06 8.983444313333926e-06
# CRVAL    : 265.13611369178307 -53.666490771174914
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.04551695015168273
# ORIENTAT : -44.70667063147106
# WCSNAME  :  TWEAK
#
# Processing u9713506m_c0m.fits['SCI',2]
#
# Updating header for u9713506m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.9621974345834552e-05 1.948087054920897e-05
# CD_21  CD_22: 1.9486184588452612e-05 1.9621406689792378e-05
# CRVAL    : 265.1481295514126 -53.65132995229896
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.0995563610593583
# ORIENTAT : 44.794076109559036
# WCSNAME  :  TWEAK
#
# Processing u9713506m_c0m.fits['SCI',3]
#
# Updating header for u9713506m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.9580569534993025e-05 1.9517036608891018e-05
# CD_21  CD_22: 1.9520319996901955e-05 -1.9579558353156543e-05
# CRVAL    : 265.17274810281 -53.666176437560104
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09953737372535992
# ORIENTAT : 135.09162508970564
# WCSNAME  :  TWEAK
#
# Processing u9713506m_c0m.fits['SCI',4]
#
# Updating header for u9713506m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9328925435732758e-05 -1.978814625095564e-05
# CD_21  CD_22: -1.978778918487045e-05 -1.9332516026185345e-05
# CRVAL    : 265.1472342319116 -53.68121499598933
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958439172407829
# ORIENTAT : -134.332718132013
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713509m_c0m.fits
#
# Matching sources from 'u9713509m_c0m.fits' with sources from reference image 'u9710103m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.24679037817169203 -0.0989030542280318
#     with significance of  2475.097568669126 and  717.0  matches
# Found 1043 matches for u9713509m_c0m.fits...
# Computed  rscale  fit for  u9713509m_c0m.fits :
# XSH: 0.1377  YSH: 0.1966    ROT: 0.001718568932    SCALE: 1.000007
# XRMS: 0.14    YRMS: 0.13
#
# RMS_RA: 4e-06 (deg)   RMS_DEC: 8.1e-08 (deg)
#
# Final solution based on  1006  objects.
# wrote XY data to:  u9713509m_c0m_catalog_fit.match
# Total # points:  1006
# # of points after clipping:  1006
# Total # points:  1006
# # of points after clipping:  1006
# Initializing new WCSCORR table for  u9713509m_c0m.fits
#
# ....Updating header for u9713509m_c0m.fits...
#
#
# Processing u9713509m_c0m.fits['SCI',1]
#
# Updating header for u9713509m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -8.998165907115488e-06 -8.892009175241849e-06
# CD_21  CD_22: -8.882073537842806e-06 8.983707476410521e-06
# CRVAL    : 265.1361066580222 -53.66662017330739
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.04551694490970479
# ORIENTAT : -44.706088451516095
# WCSNAME  :  TWEAK
#
# Processing u9713509m_c0m.fits['SCI',2]
#
# Updating header for u9713509m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.9622154004777527e-05 1.9481444529373793e-05
# CD_21  CD_22: 1.9486758643363034e-05 1.9621586405041964e-05
# CRVAL    : 265.1481230455096 -53.65145913509815
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09955634967149203
# ORIENTAT : 44.79465776849185
# WCSNAME  :  TWEAK
#
# Processing u9713509m_c0m.fits['SCI',3]
#
# Updating header for u9713509m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.9581144278326693e-05 1.9517213352723407e-05
# CD_21  CD_22: 1.95204968229063e-05 -1.9580133089046483e-05
# CRVAL    : 265.172741891776 -53.666306054047745
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09953736225999613
# ORIENTAT : 135.09220657040146
# WCSNAME  :  TWEAK
#
# Processing u9713509m_c0m.fits['SCI',4]
#
# Updating header for u9713509m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9329096182069966e-05 -1.9788723369166854e-05
# CD_21  CD_22: -1.978836621616718e-05 -1.9332686904183325e-05
# CRVAL    : 265.14722719373793 -53.68134474830875
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958438027984365
# ORIENTAT : -134.3321360054801
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713603m_c0m.fits
#
# Matching sources from 'u9713603m_c0m.fits' with sources from reference image 'u9710103m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.29448495797277374 -0.6404565219538156
#     with significance of  1772.3362209242352 and  395.0  matches
# Found 995 matches for u9713603m_c0m.fits...
# Computed  rscale  fit for  u9713603m_c0m.fits :
# XSH: 0.0564  YSH: -0.0081    ROT: 359.9998918    SCALE: 1.000018
# XRMS: 0.083    YRMS: 0.12
#
# RMS_RA: 3.1e-06 (deg)   RMS_DEC: 3.6e-07 (deg)
#
# Final solution based on  915  objects.
# wrote XY data to:  u9713603m_c0m_catalog_fit.match
# Total # points:  915
# # of points after clipping:  915
# Total # points:  915
# # of points after clipping:  915
# Initializing new WCSCORR table for  u9713603m_c0m.fits
#
# ....Updating header for u9713603m_c0m.fits...
#
#
# Processing u9713603m_c0m.fits['SCI',1]
#
# Updating header for u9713603m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -8.997796810843003e-06 -8.892176778791301e-06
# CD_21  CD_22: -8.88224167998808e-06 8.98333823565217e-06
# CRVAL    : 265.1359657646551 -53.66663315432417
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.04551693974766062
# ORIENTAT : -44.707805819990746
# WCSNAME  :  TWEAK
#
# Processing u9713603m_c0m.fits['SCI',2]
#
# Updating header for u9713603m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.962251343931112e-05 1.9480633860285833e-05
# CD_21  CD_22: 1.9485947953287706e-05 1.9621945677211307e-05
# CRVAL    : 265.1479812447343 -53.65147207303939
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09955633806068642
# ORIENTAT : 44.79294114214754
# WCSNAME  :  TWEAK
#
# Processing u9713603m_c0m.fits['SCI',3]
#
# Updating header for u9713603m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.9580335416148136e-05 1.9517576943502033e-05
# CD_21  CD_22: 1.9520860417914115e-05 -1.95793242769209e-05
# CRVAL    : 265.17260057974283 -53.66631838397392
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09953735075754544
# ORIENTAT : 135.09048949019336
# WCSNAME  :  TWEAK
#
# Processing u9713603m_c0m.fits['SCI',4]
#
# Updating header for u9713603m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9329468469806442e-05 -1.9787917405695657e-05
# CD_21  CD_22: -1.978756040120484e-05 -1.9333059143295665e-05
# CRVAL    : 265.1470869142513 -53.68135736621996
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958436872632058
# ORIENTAT : -134.33385393919286
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713606m_c0m.fits
#
# Matching sources from 'u9713606m_c0m.fits' with sources from reference image 'u9710103m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.2042802659073928 -0.29714355051616437
#     with significance of  1952.0071804658023 and  502.0  matches
# Found 1067 matches for u9713606m_c0m.fits...
# Computed  rscale  fit for  u9713606m_c0m.fits :
# XSH: 0.0909  YSH: 0.0600    ROT: 359.9997144    SCALE: 0.999983
# XRMS: 0.12    YRMS: 0.11
#
# RMS_RA: 3.5e-06 (deg)   RMS_DEC: 3.8e-08 (deg)
#
# Final solution based on  1004  objects.
# wrote XY data to:  u9713606m_c0m_catalog_fit.match
# Total # points:  1004
# # of points after clipping:  1004
# Total # points:  1004
# # of points after clipping:  1004
# Initializing new WCSCORR table for  u9713606m_c0m.fits
#
# ....Updating header for u9713606m_c0m.fits...
#
#
# Processing u9713606m_c0m.fits['SCI',1]
#
# Updating header for u9713606m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -8.998066930545103e-06 -8.89253192721306e-06
# CD_21  CD_22: -8.882596535210994e-06 8.983607819622675e-06
# CRVAL    : 265.1361040115527 -53.666553288248004
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.04551691140659962
# ORIENTAT : -44.708090271479605
# WCSNAME  :  TWEAK
#
# Processing u9713606m_c0m.fits['SCI',2]
#
# Updating header for u9713606m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.962329558205922e-05 1.948121670705854e-05
# CD_21  CD_22: 1.9486530965925147e-05 1.962272778175808e-05
# CRVAL    : 265.1481197613634 -53.65139164211029
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09955627640443125
# ORIENTAT : 44.79265641748526
# WCSNAME  :  TWEAK
#
# Processing u9713606m_c0m.fits['SCI',3]
#
# Updating header for u9713606m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.9580921988201547e-05 1.9518356124397382e-05
# CD_21  CD_22: 1.9521639687888158e-05 -1.9579910858891557e-05
# CRVAL    : 265.1727400339645 -53.666238398971494
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09953728892284794
# ORIENTAT : 135.09020408969027
# WCSNAME  :  TWEAK
#
# Processing u9713606m_c0m.fits['SCI',4]
#
# Updating header for u9713606m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9330241899887016e-05 -1.9788512371018908e-05
# CD_21  CD_22: -1.9788155359502506e-05 -1.933383271313329e-05
# CRVAL    : 265.14722565200594 -53.681277981653146
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958430689491309
# ORIENTAT : -134.33413877550413
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713609m_c0m.fits
#
# Matching sources from 'u9713609m_c0m.fits' with sources from reference image 'u9710103m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.2256481740698888 -0.7791569459997127
#     with significance of  2211.6178017684024 and  631.0  matches
# Found 1060 matches for u9713609m_c0m.fits...
# Computed  rscale  fit for  u9713609m_c0m.fits :
# XSH: 0.0793  YSH: -0.0451    ROT: 0.0003457419574    SCALE: 0.999997
# XRMS: 0.092    YRMS: 0.083
#
# RMS_RA: 2.6e-06 (deg)   RMS_DEC: 6.9e-08 (deg)
#
# Final solution based on  981  objects.
# wrote XY data to:  u9713609m_c0m_catalog_fit.match
# Total # points:  981
# # of points after clipping:  981
# Total # points:  981
# # of points after clipping:  981
# Initializing new WCSCORR table for  u9713609m_c0m.fits
#
# ....Updating header for u9713609m_c0m.fits...
#
#
# Processing u9713609m_c0m.fits['SCI',1]
#
# Updating header for u9713609m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -8.99804806551472e-06 -8.892293595429366e-06
# CD_21  CD_22: -8.882358195675971e-06 8.983589281558344e-06
# CRVAL    : 265.1360077944874 -53.666351262770455
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.045516906408713725
# ORIENTAT : -44.70738161242186
# WCSNAME  :  TWEAK
#
# Processing u9713609m_c0m.fits['SCI',2]
#
# Updating header for u9713609m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.9622773812644237e-05 1.9481180646126864e-05
# CD_21  CD_22: 1.94864948532947e-05 1.9622206078727125e-05
# CRVAL    : 265.14802363124005 -53.65118992160947
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.0995562651553432
# ORIENTAT : 44.79336503211019
# WCSNAME  :  TWEAK
#
# Processing u9713609m_c0m.fits['SCI',3]
#
# Updating header for u9713609m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.95808834820442e-05 1.951783449680676e-05
# CD_21  CD_22: 1.9521117975845173e-05 -1.95798723521511e-05
# CRVAL    : 265.1726431237951 -53.666036646559064
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09953727783986355
# ORIENTAT : 135.09091337023682
# WCSNAME  :  TWEAK
#
# Processing u9713609m_c0m.fits['SCI',4]
#
# Updating header for u9713609m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9329720485469548e-05 -1.9788468500597984e-05
# CD_21  CD_22: -1.9788111470447714e-05 -1.9333311189629305e-05
# CRVAL    : 265.1471289149739 -53.6810758270068
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.0995842958526379
# ORIENTAT : -134.33342970127737
# WCSNAME  :  TWEAK
# Initializing new WCSCORR table for  u9710103m_c0m.fits
# Trailer file written to:  tweakreg.log

# %% [markdown]
# ## 4. Equalize the chip sensitivities
#
# This step adjusts image data values so that all images and chips appear (to `AstroDrizzle`) to have a single inverse sensitivity (`PHOTFLAM`). This can be achieved using the `photeq` task in `Drizzlepac`. This task adjusts image data so that when these data are multiplied by the same single `PHOTFLAM` value, the correct flux is obtained.

# %%
photeq.photeq(files='u*_c0m.fits', ref_phot_ext=3, readonly=False)
# Out:
# ***** drizzlepac.photeq started on 2019-10-28 20:35:12.148029
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'u9710103m_c0m.fits[3]'
# REFERENCE 'PHOTFLAM' VALUE IS: 5.451384e-17
#
# Processing file 'u9710103m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3) - This is the "reference" extension.
#           Nothing to do. Skipping this extension...
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710106m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710109m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710203m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710206m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710209m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710303m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710306m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710403m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710406m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710503m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710506m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710603m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710606m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710703m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710706m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710803m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710806m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710903m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9710906m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711003m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711006m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711103m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711106m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711203m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711206m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711209m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971120cm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971120fm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711303m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711306m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711309m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971130cm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971130fm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711403m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711406m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711409m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971140cm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971140fm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711503m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711506m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711509m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971150cm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971150fm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711603m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711606m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711609m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971160cm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971160fm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711703m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711706m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711709m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971170cm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971170fm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711803m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711806m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9711809m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u971180cm_c0m.fits'
#    * EXT: ('SCI', 1)
# ...
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713009m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713103m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713106m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713109m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713203m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713206m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713209m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713303m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713306m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713309m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713403m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713406m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713409m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713503m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713506m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713509m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713603m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713606m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Processing file 'u9713609m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.613531e-17)
#      - Computed conversion factor for data: 1.029744189732369
#      - Data have been multiplied by 1.029744189732369
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.44483e-17)
#      - Computed conversion factor for data: 0.9987977365014095
#      - Data have been multiplied by 0.9987977365014095
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.451384e-17)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 5.451384e-17 (old value was 5.590183e-17)
#      - Computed conversion factor for data: 1.0254612406684247
#      - Data have been multiplied by 1.0254612406684247
#
# Done.

# %% [markdown]
# In the above command, we instruct `photeq` to "equalize" all chips of all input images using the `PHOTFLAM` for the `WF3` chip (`ref_phot_ext=3`), using the first image as a reference. This reference `PHOTFLAM` value is reported in the log file:
#
# ```
# REFERENCE VALUE FROM FILE: 'ua060502m_c0m.fits['SCI',1]'
# REFERENCE 'PHOTFLAM' VALUE IS: 2.507987e-18
# ```
#
# Upon the completion, `photeq` will not only adjust image data but also update `PHOTFLAM` values for all chips to this specific reference value.

# %% [markdown]
# ## 5. Drizzle-combine the images
#
# All four chips are now drizzled together with an output pixel scale set to that of the WF chips:

# %%
astrodrizzle.AstroDrizzle('u*c0m.fits',
                          preserve=False,
                          driz_sep_bits='8,1024',
                          driz_sep_wcs=True,
                          driz_sep_scale=0.0996,
                          combine_type='median',
                          driz_cr_snr='5.5 3.5',
                          driz_cr_scale='2.0 1.5',
                          final_fillval=None,
                          final_bits='8,1024',
                          final_wcs=True)
# Out:
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 2.2.6 (2018-11-02 15:37:13 -0400) started at: 20:35:26.808 (28/10/2019)
#
# ==== Processing Step  Initialization  started at  20:35:26.811 (28/10/2019)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 265.14763521107307  -53.66660702603412
# CRPIX : 1695.0  1671.0
# CD1_1 CD1_2  : -8.986322902194754e-06  -8.893020950428481e-06
# CD2_1 CD2_2  : -8.893020950428481e-06  8.986322902194754e-06
# NAXIS : 3390  3342
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 6457 Mb.
# *  Output image size:       3390 X 3342 pixels.
# *  Output image file:       ~ 129 Mb.
# *  Cores available:         48
# *
# ********************************************************************************
# ==== Processing Step  Initialization  finished at  20:36:44.212 (28/10/2019)
#
# ==== Processing Step  Static Mask  started at  20:36:44.215 (28/10/2019)
# ==== Processing Step  Static Mask  finished at  20:37:02.307 (28/10/2019)
#
# ==== Processing Step  Subtract Sky  started at  20:37:02.310 (28/10/2019)
# ***** skymatch started on 2019-10-28 20:37:25.274043
#       Version 1.0.4 (2019-05-30 14:31:23 -0400)
#
# 'skymatch' task will apply computed sky differences to input image file(s).
#
# NOTE: Computed sky values WILL NOT be subtracted from image data ('subtractsky'=False).
# 'MDRIZSKY' header keyword will represent sky value *computed* from data.
#
# -----  User specified keywords:  -----
#        Sky Value Keyword:  'MDRIZSKY'
#        Data Units Keyword: 'BUNIT'
#
#
# -----  Input file list:  -----
#
#    **  Input image: 'u9710103m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710103m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710103m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710103m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710103m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710106m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710106m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710106m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710106m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710106m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710109m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710109m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710109m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710109m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710109m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710203m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710203m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710203m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710203m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710203m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710206m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710206m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710206m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710206m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710206m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710209m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710209m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710209m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710209m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710209m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710303m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710303m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710303m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710303m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710303m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710306m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710306m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710306m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710306m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710306m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710403m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710403m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710403m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710403m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710403m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710406m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710406m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710406m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710406m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710406m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710503m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710503m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710503m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710503m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710503m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710506m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710506m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710506m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710506m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710506m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710603m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710603m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710603m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710603m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710603m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710606m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710606m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710606m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710606m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710606m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710703m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710703m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710703m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710703m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710703m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710706m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710706m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710706m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710706m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710706m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710803m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710803m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710803m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710803m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710803m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710806m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710806m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710806m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710806m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710806m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710903m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710903m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710903m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710903m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710903m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710906m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710906m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710906m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710906m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710906m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711003m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711003m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711003m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711003m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711003m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711006m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711006m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711006m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711006m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711006m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711103m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711103m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711103m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711103m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711103m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711106m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711106m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711106m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711106m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711106m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711203m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711203m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711203m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711203m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711203m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711206m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711206m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711206m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711206m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711206m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711209m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711209m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711209m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711209m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711209m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971120cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971120cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971120cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971120cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971120cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971120fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971120fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971120fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971120fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971120fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711303m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711303m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711303m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711303m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711303m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711306m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711306m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711306m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711306m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711306m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711309m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711309m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711309m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711309m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711309m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971130cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971130cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971130cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971130cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971130cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971130fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971130fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971130fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971130fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971130fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711403m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711403m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711403m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711403m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711403m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711406m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711406m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711406m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711406m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711406m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711409m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711409m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711409m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711409m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711409m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971140cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971140cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971140cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971140cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971140cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971140fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971140fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971140fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971140fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971140fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711503m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711503m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711503m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711503m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711503m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711506m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711506m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711506m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711506m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711506m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711509m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711509m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711509m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711509m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711509m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971150cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971150cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971150cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971150cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971150cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971150fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971150fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971150fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971150fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971150fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711603m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711603m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711603m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711603m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711603m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711606m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711606m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711606m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711606m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711606m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711609m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711609m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711609m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711609m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711609m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971160cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971160cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971160cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971160cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971160cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971160fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971160fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971160fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971160fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971160fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711703m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711703m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711703m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711703m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711703m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711706m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711706m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711706m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711706m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711706m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711709m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711709m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711709m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711709m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711709m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971170cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971170cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971170cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971170cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971170cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971170fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971170fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971170fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971170fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971170fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711803m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711803m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711803m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711803m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711803m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711806m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711806m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711806m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711806m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711806m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711809m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711809m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711809m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711809m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711809m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971180cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971180cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971180cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971180cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971180cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971180fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971180fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971180fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971180fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971180fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711903m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711903m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711903m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711903m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711903m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711906m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711906m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711906m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711906m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711906m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711909m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711909m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711909m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711909m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711909m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971190cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971190cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971190cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971190cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971190cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971190fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971190fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971190fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971190fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971190fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712003m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712003m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712003m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712003m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712003m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712006m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712006m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712006m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712006m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712006m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712009m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712009m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712009m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712009m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712009m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971200cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971200cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971200cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971200cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971200cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971200fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971200fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971200fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971200fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971200fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712103m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712103m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712103m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712103m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712103m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712106m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712106m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712106m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712106m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712106m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712109m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712109m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712109m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712109m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712109m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971210cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971210cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971210cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971210cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971210cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971210fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971210fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971210fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971210fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971210fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712203m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712203m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712203m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712203m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712203m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712206m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712206m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712206m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712206m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712206m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712209m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712209m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712209m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712209m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712209m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971220cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971220cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971220cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971220cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971220cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971220fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971220fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971220fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971220fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971220fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712303m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712303m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712303m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712303m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712303m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712306m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712306m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712306m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712306m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712306m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712309m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712309m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712309m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712309m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712309m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971230cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971230cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971230cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971230cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971230cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971230fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971230fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971230fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971230fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971230fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712403m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712403m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712403m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712403m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712403m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712406m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712406m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712406m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712406m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712406m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712409m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712409m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712409m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712409m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712409m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971240cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971240cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971240cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971240cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971240cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971240fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971240fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971240fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971240fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971240fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712503m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712503m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712503m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712503m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712503m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712506m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712506m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712506m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712506m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712506m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712509m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712509m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712509m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712509m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712509m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971250cm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971250cm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971250cm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971250cm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971250cm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971250fm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971250fm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971250fm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971250fm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971250fm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712603m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712603m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712603m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712603m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712603m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712606m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712606m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712606m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712606m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712606m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712609m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712609m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712609m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712609m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712609m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712703m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712703m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712703m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712703m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712703m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712706m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712706m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712706m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712706m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712706m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712803m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712803m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712803m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712803m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712803m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712806m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712806m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712806m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712806m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712806m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712809m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712809m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712809m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712809m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712809m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712903m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712903m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712903m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712903m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712903m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712906m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712906m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712906m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712906m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712906m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712909m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712909m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712909m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712909m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712909m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713003m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713003m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713003m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713003m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713003m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713006m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713006m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713006m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713006m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713006m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713009m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713009m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713009m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713009m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713009m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713103m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713103m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713103m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713103m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713103m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713106m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713106m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713106m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713106m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713106m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713109m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713109m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713109m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713109m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713109m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713203m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713203m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713203m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713203m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713203m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713206m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713206m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713206m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713206m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713206m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713209m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713209m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713209m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713209m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713209m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713303m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713303m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713303m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713303m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713303m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713306m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713306m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713306m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713306m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713306m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713309m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713309m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713309m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713309m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713309m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713403m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713403m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713403m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713403m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713403m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713406m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713406m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713406m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713406m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713406m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713409m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713409m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713409m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713409m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713409m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713503m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713503m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713503m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713503m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713503m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713506m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713506m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713506m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713506m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713506m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713509m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713509m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713509m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713509m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713509m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713603m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713603m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713603m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713603m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713603m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713606m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713606m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713606m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713606m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713606m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713609m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713609m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713609m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713609m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713609m_skymatch_mask_sci4.fits[0]
#
# -----  Sky statistics parameters:  -----
#        statistics function: 'median'
#        lower = None
#        upper = None
#        nclip = 5
#        lsigma = 4.0
#        usigma = 4.0
#        binwidth = 0.1
#
# -----  Data->Brightness conversion parameters for input files:  -----
#
#    *   Image: u9710103m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710106m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710109m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710203m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.804560605105929
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16817684828941182
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16824105931003033
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680822858571525
#
#    *   Image: u9710206m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710209m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710303m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710306m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710403m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.804560605105929
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16817684828941182
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16824105931003033
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680822858571525
#
#    *   Image: u9710406m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710503m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710506m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.689623375805082
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1441515842480673
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.1442066222657403
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 700.0 [s]
#              Conversion factor (data->brightness):  0.14407053073470216
#
#    *   Image: u9710603m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.804560605105929
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16817684828941182
#        EXT = 'SCI',3
#              Data units type: COUNTS
# ...
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u9711903m_c0m_single_sci.fits
# Writing out image to disk: u9711703m_c0m_single_wht.fits
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u971160fm_c0m_single_wht.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u9711803m_c0m_single_wht.fits
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u9711906m_c0m_single_sci.fits
# -Generating simple FITS output: u9712003m_c0m_single_sci.fits
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u9711809m_c0m_single_wht.fits
# Writing out image to disk: u971180cm_c0m_single_wht.fits
# Writing out image to disk: u971170fm_c0m_single_wht.fits
# Writing out image to disk: u9711909m_c0m_single_sci.fits
# Writing out image to disk: u971190cm_c0m_single_sci.fits
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# -Generating simple FITS output: u9712009m_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# -Generating simple FITS output: u9712103m_c0m_single_sci.fits
# Writing out image to disk: u971180fm_c0m_single_wht.fits
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u9711806m_c0m_single_wht.fits
# -Generating simple FITS output: u971200cm_c0m_single_sci.fits
# Writing out image to disk: u9711903m_c0m_single_wht.fits
# -Generating simple FITS output: u9712006m_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u9712009m_c0m_single_sci.fits
# Deleted all instances of WCS with key B in extensions [0]
# -Generating simple FITS output: u971200fm_c0m_single_sci.fits
# Writing out image to disk: u9712003m_c0m_single_sci.fits
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u9712103m_c0m_single_sci.fits
# -Generating simple FITS output: u9712109m_c0m_single_sci.fits
# Writing out image to disk: u9711906m_c0m_single_wht.fits
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u971190cm_c0m_single_wht.fits
# -Generating simple FITS output: u9712106m_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u9712006m_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u971200cm_c0m_single_sci.fits
# Writing out image to disk: u9711909m_c0m_single_wht.fits
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u971200fm_c0m_single_sci.fits
# Writing out image to disk: u9712003m_c0m_single_wht.fits
# Writing out image to disk: u9712109m_c0m_single_sci.fits
# Writing out image to disk: u9712009m_c0m_single_wht.fits
# Deleted all instances of WCS with key B in extensions [0]
# -Generating simple FITS output: u9712206m_c0m_single_sci.fits
# Writing out image to disk: u9712103m_c0m_single_wht.fits
# Trailer file written to:  astrodrizzle.log
# -Generating simple FITS output: u9712203m_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# -Generating simple FITS output: u971210cm_c0m_single_sci.fits
# -Generating simple FITS output: u971220cm_c0m_single_sci.fits
# -Generating simple FITS output: u9712303m_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# -Generating simple FITS output: u9712209m_c0m_single_sci.fits
# Deleted all instances of WCS with key B in extensions [0]
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/util.py in wrapper(*args, **kwargs)
#     216             # finally clause is reached.
#     217             try:
# --> 218                 func(*args, **kwargs)
#     219             except Exception as e:
#     220                 errorobj = e
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/astrodrizzle.py in run(configobj, wcsmap)
#     212         #drizzle to separate images
#     213         adrizzle.drizSeparate(imgObjList, outwcs, configobj, wcsmap=wcsmap,
# --> 214                               procSteps=procSteps)
#     215
#     216 #       _dbg_dump_virtual_outputs(imgObjList)
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/adrizzle.py in drizSeparate(imageObjectList, output_wcs, configObj, wcsmap, procSteps)
#     354         # for single-drizzle step when called from the top-level.
#     355         run_driz(imageObjectList, output_wcs.single_wcs, paramDict, single=True,
# --> 356                  build=False, wcsmap=wcsmap)
#     357     else:
#     358         log.info('Single drizzle step not performed.')
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/adrizzle.py in run_driz(imageObjectList, output_wcs, paramDict, single, build, wcsmap)
#     681     # do the join if we spawned tasks
#     682     if will_parallel:
# --> 683         mputil.launch_and_wait(subprocs, pool_size) # blocks till all done
#     684
#     685     del _outsci,_outwht,_outctx,_hdrlist
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/stsci/tools/mputil.py in launch_and_wait(mp_proc_list, pool_size)
#      84             for p in procs:
#      85                 if started_now < num_to_start_now and p.state == 0:
# ---> 86                     p.start_process()
#      87                     # debug "launch_and_wait: started: "+str(p.process)
#      88                     started_now += 1
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/stsci/tools/mputil.py in start_process(self)
#      18         assert self.state == 0, "Already started: "+str(self.process)
#      19         self._start_time = time.time()
# ---> 20         self.process.start()
#      21         self.state = 1
#      22
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         self.returncode = None
#      19         self.finalizer = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      68         code = 1
#      69         parent_r, child_w = os.pipe()
# ---> 70         self.pid = os.fork()
#      71         if self.pid == 0:
#      72             try:
#
# BlockingIOError: [Errno 11] Resource temporarily unavailable
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# -Generating simple FITS output: u9712403m_c0m_single_sci.fits
# Writing out image to disk: u971200fm_c0m_single_wht.fits
# Writing out image to disk: u9712006m_c0m_single_wht.fits
# -Generating simple FITS output: u971210fm_c0m_single_sci.fits
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u971200cm_c0m_single_wht.fits
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# <ipython-input-10-53a4a881760c> in <module>
#       9                           final_fillval=None,
#      10                           final_bits='8,1024',
# ---> 11                           final_wcs=True)
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/astrodrizzle.py in AstroDrizzle(input, mdriztab, editpars, configobj, wcsmap, **input_dict)
#     120     # already called 'run()'.
#     121     if not editpars:
# --> 122         run(configObj, wcsmap=wcsmap)
#     123
#     124 ##############################
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/util.py in wrapper(*args, **kwargs)
#     227                     # (hope that end_logging didn't change the last exception raised)
#     228                     if errorobj:
# --> 229                         raise errorobj
#     230
#     231         return wrapper
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/util.py in wrapper(*args, **kwargs)
#     216             # finally clause is reached.
#     217             try:
# --> 218                 func(*args, **kwargs)
#     219             except Exception as e:
#     220                 errorobj = e
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/astrodrizzle.py in run(configobj, wcsmap)
#     212         #drizzle to separate images
#     213         adrizzle.drizSeparate(imgObjList, outwcs, configobj, wcsmap=wcsmap,
# --> 214                               procSteps=procSteps)
#     215
#     216 #       _dbg_dump_virtual_outputs(imgObjList)
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/adrizzle.py in drizSeparate(imageObjectList, output_wcs, configObj, wcsmap, procSteps)
#     354         # for single-drizzle step when called from the top-level.
#     355         run_driz(imageObjectList, output_wcs.single_wcs, paramDict, single=True,
# --> 356                  build=False, wcsmap=wcsmap)
#     357     else:
#     358         log.info('Single drizzle step not performed.')
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/drizzlepac/adrizzle.py in run_driz(imageObjectList, output_wcs, paramDict, single, build, wcsmap)
#     681     # do the join if we spawned tasks
#     682     if will_parallel:
# --> 683         mputil.launch_and_wait(subprocs, pool_size) # blocks till all done
#     684
#     685     del _outsci,_outwht,_outctx,_hdrlist
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/stsci/tools/mputil.py in launch_and_wait(mp_proc_list, pool_size)
#      84             for p in procs:
#      85                 if started_now < num_to_start_now and p.state == 0:
# ---> 86                     p.start_process()
#      87                     # debug "launch_and_wait: started: "+str(p.process)
#      88                     started_now += 1
#
# ~/anaconda3/envs/muse/lib/python3.7/site-packages/stsci/tools/mputil.py in start_process(self)
#      18         assert self.state == 0, "Already started: "+str(self.process)
#      19         self._start_time = time.time()
# ---> 20         self.process.start()
#      21         self.state = 1
#      22
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         self.returncode = None
#      19         self.finalizer = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda3/envs/muse/lib/python3.7/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      68         code = 1
#      69         parent_r, child_w = os.pipe()
# ---> 70         self.pid = os.fork()
#      71         if self.pid == 0:
#      72             try:
#
# BlockingIOError: [Errno 11] Resource temporarily unavailable
# Writing out image to disk: u9712106m_c0m_single_sci.fits
# Writing out image to disk: u9712109m_c0m_single_wht.fits
# Writing out image to disk: u9712206m_c0m_single_sci.fits
# Writing out image to disk: u9712209m_c0m_single_sci.fits
# -Generating simple FITS output: u9712306m_c0m_single_sci.fits
# Writing out image to disk: u9712203m_c0m_single_sci.fits
# Writing out image to disk: u971220cm_c0m_single_sci.fits
# Writing out image to disk: u9712303m_c0m_single_sci.fits
# Writing out image to disk: u971210cm_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u9712403m_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u971210fm_c0m_single_sci.fits
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u9712206m_c0m_single_wht.fits
# Writing out image to disk: u9712106m_c0m_single_wht.fits
# Writing out image to disk: u9712306m_c0m_single_sci.fits
# Writing out image to disk: u9712209m_c0m_single_wht.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u9712203m_c0m_single_wht.fits
# Writing out image to disk: u971220cm_c0m_single_wht.fits
# Writing out image to disk: u9712303m_c0m_single_wht.fits
# -Generating simple FITS output: u971230fm_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u971210cm_c0m_single_wht.fits
# Deleted all instances of WCS with key B in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u9712403m_c0m_single_wht.fits
# Deleted all instances of WCS with key A in extensions [0]
# Writing out image to disk: u971210fm_c0m_single_wht.fits
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u9712306m_c0m_single_wht.fits
# Writing out image to disk: u971230fm_c0m_single_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: u971230fm_c0m_single_wht.fits

# %%
drz = fits.getdata('final_drz_sci.fits')
plt.figure(figsize=(15, 15))
plt.imshow(drz, cmap='gray', vmin=-0.1, vmax=0.5, origin='lower')

# %% [markdown]
# # Individual image

# %%
singlename = 'u9712903m_c0m_single_sci.fits'
single = fits.getdata(singlename)
plt.figure(figsize=(15, 15))
plt.imshow(drz, cmap='gray', vmin=-0.1, vmax=0.5, origin='lower')

# %% [markdown]
# ## Cosmic Rays
#
# If there are a lot of cosmic rays in a small set of input images, some sources may be misidentified as cosmic rays, resulting in those PSFs having chopped-off peaks. Try adjusting the combine_nsigma, combine_nlow and combine_nhigh AstroDrizzle parameter values to get more optimal cosmic ray rejection parameter values for your images.

# %%
astrodrizzle.AstroDrizzle('u*c0m.fits',
                          preserve=False,
                          driz_sep_bits='8,1024',
                          driz_sep_wcs=True,
                          driz_sep_scale=0.0996,
                          combine_type='median',
                          driz_cr_snr='5.5 3.5',
                          driz_cr_scale='2.0 1.5',
                          final_fillval=None,
                          final_bits='8,1024',
                          final_wcs=True,
                          final_scale=0.0996,
                          combine_nsigma=,
                          combine_nlow=,
                          combine_nhigh=
                         )

# %% [markdown]
# # About this Notebook
#
# Based on notebook by
#
#     Author: M. Cara, STScI Data Analysis Tools Branch
#     Updated: December 14, 2018
