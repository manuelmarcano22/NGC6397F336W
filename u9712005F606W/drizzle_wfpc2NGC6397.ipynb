# %% [markdown]
# # Drizzling WFPC2 Images to use a Single Zeropoint

# %% [markdown]
# <div class="alert-danger">Note: The notebook in this repository 'Initialization.ipynb' goes over many of the basic concepts such as the setup of the environment/package installation and should be read first if you are new to HST images, DrizzlePac, or Astroquery.</div>

# %% [markdown]
# ## Introduction
#
# Extra care must be taken when using `AstroDrizzle` to combine observations from detectors comprised of multiple chips of varying sensitivity. `AstroDrizzle` works with calibrated images in units of counts (electrons or Data Numbers) or count rates and not in units of flux. It assumes that all input frames can be converted to physical flux units using a single inverse-sensitivity factor, recorded in the FITS image headers as `PHOTFLAM`, and the output drizzled product simply copies the `PHOTFLAM` keyword value from the first input image. When this occurs, the inverse-sensitivity will vary across the final drizzled product, and users will need to keep track of which sources fell on which chip when doing photometry. Moreover, varying detector sensitivities will affect the cosmic-ray rejection algorithm used by `AstroDrizzle`, and this may result in the misidentification of some good pixels as cosmic rays.
#
# This is a typical situation when drizzle-combining images from HST instruments with different chip sensitivities, e.g. Wide Field and Planetary Camera 2 (WFPC2). For more detail, see the section on [Gain Variation](http://www.stsci.edu/instruments/wfpc2/Wfpc2_dhb/wfpc2_ch53.html) under 'Position-Dependent Photometric Corrections' in the WFPC2 Data Handbook. As a result, each of the four chips requires a [unique PHOTFLAM](http://www.stsci.edu/instruments/wfpc2/Wfpc2_dhb/wfpc2_ch52.html#1933986) header keyword value. A similar situation may occur when drizzle-combining observations taken over a span of several years as detector's sensitivity declines over time, see e.g. [ACS ISR 2016-03](https://doi.org/10.3847/0004-6256/152/3/60).
#
# One approach is to rescale the input data so that `AstroDrizzle` can properly assume the images/chips have the same sensitivity; that is, a single `PHOTFLAM` value can be used to convert re-scaled image counts (or count-rates) to physical _integrated_ flux units. The `photeq` task in `Drizzlepac` automates this image intensity rescaling to a single inverse-sensitivity factor `PHOTFLAM`.
#
# In this example notebook, archival WFPC2 images are used to demonstrate advanced reprocessing using `TweakReg` and `AstroDrizzle` for alignment and image combination. The notebook is based on a prior WFPC2 [example](http://www.stsci.edu/hst/HST_overview/drizzlepac/examples/example7) but includes additional information about equalizing the chip sensitivities prior to combining.
#
# **NOTE:** It is important to note that `photeq` only adjusts image counts so that _integrated_ physical fluxes can be obtained using a single `PHOTFLAM`. It does nothing to account for different throughtputs at different wavelengths.

# %%
import shutil
import glob
import os
import subprocess

import matplotlib.pyplot as plt
from astropy.io import fits

from astroquery.mast import Observations
from stwcs.updatewcs import updatewcs
from drizzlepac import tweakreg, astrodrizzle, photeq
from stsci.skypac import skymatch

# ONLY needed for the simulation section:
import numpy as np
from stwcs.wcsutil import HSTWCS
from drizzlepac.wfpc2Data import WFPC2_GAINS

# %matplotlib inline

# %% [markdown]
# ## 1. Download the Data
#
# This example uses WFPC2 observations of Messier 2 in the F814W filter. The data come from GO proposal [11100](http://www.stsci.edu/cgi-bin/get-proposal-info?id=11100&observatory=HST) _"Two new 'bullets' for MOND: revealing the properties of dark matter in massive merging clusters"_. Four images were acquired using a 4-pt dither box pattern, followed by two images offset with a dither-line pattern.
#
# The data are downloaded using the `astroquery` API to access the [MAST](http://archive.stsci.edu) archive. The `astroquery.mast` [documentation](http://astroquery.readthedocs.io/en/latest/mast/mast.html) has more examples for how to find and download data from MAST.

# %%
# Retrieve the observation information.
if os.path.isdir('mastDownload'):
    shutil.rmtree('mastDownload')
#obs_table = Observations.query_criteria(obs_id='ua0605*', filters='F814W', obstype='ALL')
obs_table = Observations.query_criteria(obs_collection='HST', proposal_id=['10424'],filters='F606W')

products = Observations.get_product_list(obs_table)

# Download only the ua0605*_c0m.fits and ua0605*_c1m.fits (DQ) images:
Observations.download_products(products, mrp_only=False, productSubGroupDescription=['C0M', 'C1M'], extension='fits')

# Move the files from the mastDownload directory to the current working
# directory and make a backup of the files.
fits_files = glob.glob('mastDownload/HST/u*/u*c?m.fits')
for fil in fits_files:
    base_name = os.path.basename(fil)
    if os.path.isfile(base_name):
        os.remove(base_name)
    shutil.move(fil, '.')
    
# Delete the mastDownload directory and all subdirectories it contains.
shutil.rmtree('mastDownload')
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710102m_c0m.fits to ./mastDownload/HST/u9710102m/u9710102m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710102m_c1m.fits to ./mastDownload/HST/u9710102m/u9710102m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710105m_c0m.fits to ./mastDownload/HST/u9710105m/u9710105m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710105m_c1m.fits to ./mastDownload/HST/u9710105m/u9710105m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710108m_c0m.fits to ./mastDownload/HST/u9710108m/u9710108m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710108m_c1m.fits to ./mastDownload/HST/u9710108m/u9710108m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710202m_c0m.fits to ./mastDownload/HST/u9710202m/u9710202m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710202m_c1m.fits to ./mastDownload/HST/u9710202m/u9710202m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710205m_c0m.fits to ./mastDownload/HST/u9710205m/u9710205m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710205m_c1m.fits to ./mastDownload/HST/u9710205m/u9710205m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710208m_c0m.fits to ./mastDownload/HST/u9710208m/u9710208m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710208m_c1m.fits to ./mastDownload/HST/u9710208m/u9710208m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710302m_c0m.fits to ./mastDownload/HST/u9710302m/u9710302m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710302m_c1m.fits to ./mastDownload/HST/u9710302m/u9710302m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710305m_c0m.fits to ./mastDownload/HST/u9710305m/u9710305m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710305m_c1m.fits to ./mastDownload/HST/u9710305m/u9710305m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710402m_c0m.fits to ./mastDownload/HST/u9710402m/u9710402m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710402m_c1m.fits to ./mastDownload/HST/u9710402m/u9710402m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710405m_c0m.fits to ./mastDownload/HST/u9710405m/u9710405m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710405m_c1m.fits to ./mastDownload/HST/u9710405m/u9710405m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710502m_c0m.fits to ./mastDownload/HST/u9710502m/u9710502m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710502m_c1m.fits to ./mastDownload/HST/u9710502m/u9710502m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710505m_c0m.fits to ./mastDownload/HST/u9710505m/u9710505m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710505m_c1m.fits to ./mastDownload/HST/u9710505m/u9710505m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710602m_c0m.fits to ./mastDownload/HST/u9710602m/u9710602m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710602m_c1m.fits to ./mastDownload/HST/u9710602m/u9710602m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710605m_c0m.fits to ./mastDownload/HST/u9710605m/u9710605m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710605m_c1m.fits to ./mastDownload/HST/u9710605m/u9710605m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710702m_c0m.fits to ./mastDownload/HST/u9710702m/u9710702m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710702m_c1m.fits to ./mastDownload/HST/u9710702m/u9710702m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710705m_c0m.fits to ./mastDownload/HST/u9710705m/u9710705m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710705m_c1m.fits to ./mastDownload/HST/u9710705m/u9710705m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710802m_c0m.fits to ./mastDownload/HST/u9710802m/u9710802m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710802m_c1m.fits to ./mastDownload/HST/u9710802m/u9710802m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710805m_c0m.fits to ./mastDownload/HST/u9710805m/u9710805m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710805m_c1m.fits to ./mastDownload/HST/u9710805m/u9710805m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710902m_c0m.fits to ./mastDownload/HST/u9710902m/u9710902m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710902m_c1m.fits to ./mastDownload/HST/u9710902m/u9710902m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710905m_c0m.fits to ./mastDownload/HST/u9710905m/u9710905m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9710905m_c1m.fits to ./mastDownload/HST/u9710905m/u9710905m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711002m_c0m.fits to ./mastDownload/HST/u9711002m/u9711002m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711002m_c1m.fits to ./mastDownload/HST/u9711002m/u9711002m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711005m_c0m.fits to ./mastDownload/HST/u9711005m/u9711005m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711005m_c1m.fits to ./mastDownload/HST/u9711005m/u9711005m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711102m_c0m.fits to ./mastDownload/HST/u9711102m/u9711102m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711102m_c1m.fits to ./mastDownload/HST/u9711102m/u9711102m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711105m_c0m.fits to ./mastDownload/HST/u9711105m/u9711105m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711105m_c1m.fits to ./mastDownload/HST/u9711105m/u9711105m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711202m_c0m.fits to ./mastDownload/HST/u9711202m/u9711202m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711202m_c1m.fits to ./mastDownload/HST/u9711202m/u9711202m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711205m_c0m.fits to ./mastDownload/HST/u9711205m/u9711205m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711205m_c1m.fits to ./mastDownload/HST/u9711205m/u9711205m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711208m_c0m.fits to ./mastDownload/HST/u9711208m/u9711208m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711208m_c1m.fits to ./mastDownload/HST/u9711208m/u9711208m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971120bm_c0m.fits to ./mastDownload/HST/u971120bm/u971120bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971120bm_c1m.fits to ./mastDownload/HST/u971120bm/u971120bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971120em_c0m.fits to ./mastDownload/HST/u971120em/u971120em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971120em_c1m.fits to ./mastDownload/HST/u971120em/u971120em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711302m_c0m.fits to ./mastDownload/HST/u9711302m/u9711302m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711302m_c1m.fits to ./mastDownload/HST/u9711302m/u9711302m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711305m_c0m.fits to ./mastDownload/HST/u9711305m/u9711305m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711305m_c1m.fits to ./mastDownload/HST/u9711305m/u9711305m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711308m_c0m.fits to ./mastDownload/HST/u9711308m/u9711308m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711308m_c1m.fits to ./mastDownload/HST/u9711308m/u9711308m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971130bm_c0m.fits to ./mastDownload/HST/u971130bm/u971130bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971130bm_c1m.fits to ./mastDownload/HST/u971130bm/u971130bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971130em_c0m.fits to ./mastDownload/HST/u971130em/u971130em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971130em_c1m.fits to ./mastDownload/HST/u971130em/u971130em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711402m_c0m.fits to ./mastDownload/HST/u9711402m/u9711402m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711402m_c1m.fits to ./mastDownload/HST/u9711402m/u9711402m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711405m_c0m.fits to ./mastDownload/HST/u9711405m/u9711405m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711405m_c1m.fits to ./mastDownload/HST/u9711405m/u9711405m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711408m_c0m.fits to ./mastDownload/HST/u9711408m/u9711408m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711408m_c1m.fits to ./mastDownload/HST/u9711408m/u9711408m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971140bm_c0m.fits to ./mastDownload/HST/u971140bm/u971140bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971140bm_c1m.fits to ./mastDownload/HST/u971140bm/u971140bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971140em_c0m.fits to ./mastDownload/HST/u971140em/u971140em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971140em_c1m.fits to ./mastDownload/HST/u971140em/u971140em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711502m_c0m.fits to ./mastDownload/HST/u9711502m/u9711502m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711502m_c1m.fits to ./mastDownload/HST/u9711502m/u9711502m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711505m_c0m.fits to ./mastDownload/HST/u9711505m/u9711505m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711505m_c1m.fits to ./mastDownload/HST/u9711505m/u9711505m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711508m_c0m.fits to ./mastDownload/HST/u9711508m/u9711508m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711508m_c1m.fits to ./mastDownload/HST/u9711508m/u9711508m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971150bm_c0m.fits to ./mastDownload/HST/u971150bm/u971150bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971150bm_c1m.fits to ./mastDownload/HST/u971150bm/u971150bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971150em_c0m.fits to ./mastDownload/HST/u971150em/u971150em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971150em_c1m.fits to ./mastDownload/HST/u971150em/u971150em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711602m_c0m.fits to ./mastDownload/HST/u9711602m/u9711602m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711602m_c1m.fits to ./mastDownload/HST/u9711602m/u9711602m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711605m_c0m.fits to ./mastDownload/HST/u9711605m/u9711605m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711605m_c1m.fits to ./mastDownload/HST/u9711605m/u9711605m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711608m_c0m.fits to ./mastDownload/HST/u9711608m/u9711608m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711608m_c1m.fits to ./mastDownload/HST/u9711608m/u9711608m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971160bm_c0m.fits to ./mastDownload/HST/u971160bm/u971160bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971160bm_c1m.fits to ./mastDownload/HST/u971160bm/u971160bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971160em_c0m.fits to ./mastDownload/HST/u971160em/u971160em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971160em_c1m.fits to ./mastDownload/HST/u971160em/u971160em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711702m_c0m.fits to ./mastDownload/HST/u9711702m/u9711702m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711702m_c1m.fits to ./mastDownload/HST/u9711702m/u9711702m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711705m_c0m.fits to ./mastDownload/HST/u9711705m/u9711705m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711705m_c1m.fits to ./mastDownload/HST/u9711705m/u9711705m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711708m_c0m.fits to ./mastDownload/HST/u9711708m/u9711708m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711708m_c1m.fits to ./mastDownload/HST/u9711708m/u9711708m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971170bm_c0m.fits to ./mastDownload/HST/u971170bm/u971170bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971170bm_c1m.fits to ./mastDownload/HST/u971170bm/u971170bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971170em_c0m.fits to ./mastDownload/HST/u971170em/u971170em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971170em_c1m.fits to ./mastDownload/HST/u971170em/u971170em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711802m_c0m.fits to ./mastDownload/HST/u9711802m/u9711802m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711802m_c1m.fits to ./mastDownload/HST/u9711802m/u9711802m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711805m_c0m.fits to ./mastDownload/HST/u9711805m/u9711805m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711805m_c1m.fits to ./mastDownload/HST/u9711805m/u9711805m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711808m_c0m.fits to ./mastDownload/HST/u9711808m/u9711808m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711808m_c1m.fits to ./mastDownload/HST/u9711808m/u9711808m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971180bm_c0m.fits to ./mastDownload/HST/u971180bm/u971180bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971180bm_c1m.fits to ./mastDownload/HST/u971180bm/u971180bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971180em_c0m.fits to ./mastDownload/HST/u971180em/u971180em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971180em_c1m.fits to ./mastDownload/HST/u971180em/u971180em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711902m_c0m.fits to ./mastDownload/HST/u9711902m/u9711902m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711902m_c1m.fits to ./mastDownload/HST/u9711902m/u9711902m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711905m_c0m.fits to ./mastDownload/HST/u9711905m/u9711905m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711905m_c1m.fits to ./mastDownload/HST/u9711905m/u9711905m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711908m_c0m.fits to ./mastDownload/HST/u9711908m/u9711908m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9711908m_c1m.fits to ./mastDownload/HST/u9711908m/u9711908m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971190bm_c0m.fits to ./mastDownload/HST/u971190bm/u971190bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971190bm_c1m.fits to ./mastDownload/HST/u971190bm/u971190bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971190em_c0m.fits to ./mastDownload/HST/u971190em/u971190em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971190em_c1m.fits to ./mastDownload/HST/u971190em/u971190em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712002m_c0m.fits to ./mastDownload/HST/u9712002m/u9712002m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712002m_c1m.fits to ./mastDownload/HST/u9712002m/u9712002m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712005m_c0m.fits to ./mastDownload/HST/u9712005m/u9712005m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712005m_c1m.fits to ./mastDownload/HST/u9712005m/u9712005m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712008m_c0m.fits to ./mastDownload/HST/u9712008m/u9712008m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712008m_c1m.fits to ./mastDownload/HST/u9712008m/u9712008m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971200bm_c0m.fits to ./mastDownload/HST/u971200bm/u971200bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971200bm_c1m.fits to ./mastDownload/HST/u971200bm/u971200bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971200em_c0m.fits to ./mastDownload/HST/u971200em/u971200em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971200em_c1m.fits to ./mastDownload/HST/u971200em/u971200em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712102m_c0m.fits to ./mastDownload/HST/u9712102m/u9712102m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712102m_c1m.fits to ./mastDownload/HST/u9712102m/u9712102m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712105m_c0m.fits to ./mastDownload/HST/u9712105m/u9712105m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712105m_c1m.fits to ./mastDownload/HST/u9712105m/u9712105m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712108m_c0m.fits to ./mastDownload/HST/u9712108m/u9712108m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712108m_c1m.fits to ./mastDownload/HST/u9712108m/u9712108m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971210bm_c0m.fits to ./mastDownload/HST/u971210bm/u971210bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971210bm_c1m.fits to ./mastDownload/HST/u971210bm/u971210bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971210em_c0m.fits to ./mastDownload/HST/u971210em/u971210em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971210em_c1m.fits to ./mastDownload/HST/u971210em/u971210em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712202m_c0m.fits to ./mastDownload/HST/u9712202m/u9712202m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712202m_c1m.fits to ./mastDownload/HST/u9712202m/u9712202m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712205m_c0m.fits to ./mastDownload/HST/u9712205m/u9712205m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712205m_c1m.fits to ./mastDownload/HST/u9712205m/u9712205m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712208m_c0m.fits to ./mastDownload/HST/u9712208m/u9712208m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712208m_c1m.fits to ./mastDownload/HST/u9712208m/u9712208m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971220bm_c0m.fits to ./mastDownload/HST/u971220bm/u971220bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971220bm_c1m.fits to ./mastDownload/HST/u971220bm/u971220bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971220em_c0m.fits to ./mastDownload/HST/u971220em/u971220em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971220em_c1m.fits to ./mastDownload/HST/u971220em/u971220em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712302m_c0m.fits to ./mastDownload/HST/u9712302m/u9712302m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712302m_c1m.fits to ./mastDownload/HST/u9712302m/u9712302m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712305m_c0m.fits to ./mastDownload/HST/u9712305m/u9712305m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712305m_c1m.fits to ./mastDownload/HST/u9712305m/u9712305m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712308m_c0m.fits to ./mastDownload/HST/u9712308m/u9712308m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712308m_c1m.fits to ./mastDownload/HST/u9712308m/u9712308m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971230bm_c0m.fits to ./mastDownload/HST/u971230bm/u971230bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971230bm_c1m.fits to ./mastDownload/HST/u971230bm/u971230bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971230em_c0m.fits to ./mastDownload/HST/u971230em/u971230em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971230em_c1m.fits to ./mastDownload/HST/u971230em/u971230em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712402m_c0m.fits to ./mastDownload/HST/u9712402m/u9712402m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712402m_c1m.fits to ./mastDownload/HST/u9712402m/u9712402m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712405m_c0m.fits to ./mastDownload/HST/u9712405m/u9712405m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712405m_c1m.fits to ./mastDownload/HST/u9712405m/u9712405m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712408m_c0m.fits to ./mastDownload/HST/u9712408m/u9712408m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712408m_c1m.fits to ./mastDownload/HST/u9712408m/u9712408m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971240bm_c0m.fits to ./mastDownload/HST/u971240bm/u971240bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971240bm_c1m.fits to ./mastDownload/HST/u971240bm/u971240bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971240em_c0m.fits to ./mastDownload/HST/u971240em/u971240em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971240em_c1m.fits to ./mastDownload/HST/u971240em/u971240em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712502m_c0m.fits to ./mastDownload/HST/u9712502m/u9712502m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712502m_c1m.fits to ./mastDownload/HST/u9712502m/u9712502m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712505m_c0m.fits to ./mastDownload/HST/u9712505m/u9712505m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712505m_c1m.fits to ./mastDownload/HST/u9712505m/u9712505m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712508m_c0m.fits to ./mastDownload/HST/u9712508m/u9712508m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712508m_c1m.fits to ./mastDownload/HST/u9712508m/u9712508m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971250bm_c0m.fits to ./mastDownload/HST/u971250bm/u971250bm_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971250bm_c1m.fits to ./mastDownload/HST/u971250bm/u971250bm_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971250em_c0m.fits to ./mastDownload/HST/u971250em/u971250em_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u971250em_c1m.fits to ./mastDownload/HST/u971250em/u971250em_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712602m_c0m.fits to ./mastDownload/HST/u9712602m/u9712602m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712602m_c1m.fits to ./mastDownload/HST/u9712602m/u9712602m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712605m_c0m.fits to ./mastDownload/HST/u9712605m/u9712605m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712605m_c1m.fits to ./mastDownload/HST/u9712605m/u9712605m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712608m_c0m.fits to ./mastDownload/HST/u9712608m/u9712608m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712608m_c1m.fits to ./mastDownload/HST/u9712608m/u9712608m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712702m_c0m.fits to ./mastDownload/HST/u9712702m/u9712702m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712702m_c1m.fits to ./mastDownload/HST/u9712702m/u9712702m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712705m_c0m.fits to ./mastDownload/HST/u9712705m/u9712705m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712705m_c1m.fits to ./mastDownload/HST/u9712705m/u9712705m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712802m_c0m.fits to ./mastDownload/HST/u9712802m/u9712802m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712802m_c1m.fits to ./mastDownload/HST/u9712802m/u9712802m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712805m_c0m.fits to ./mastDownload/HST/u9712805m/u9712805m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712805m_c1m.fits to ./mastDownload/HST/u9712805m/u9712805m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712808m_c0m.fits to ./mastDownload/HST/u9712808m/u9712808m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712808m_c1m.fits to ./mastDownload/HST/u9712808m/u9712808m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712902m_c0m.fits to ./mastDownload/HST/u9712902m/u9712902m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712902m_c1m.fits to ./mastDownload/HST/u9712902m/u9712902m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712905m_c0m.fits to ./mastDownload/HST/u9712905m/u9712905m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712905m_c1m.fits to ./mastDownload/HST/u9712905m/u9712905m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712908m_c0m.fits to ./mastDownload/HST/u9712908m/u9712908m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9712908m_c1m.fits to ./mastDownload/HST/u9712908m/u9712908m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713002m_c0m.fits to ./mastDownload/HST/u9713002m/u9713002m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713002m_c1m.fits to ./mastDownload/HST/u9713002m/u9713002m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713005m_c0m.fits to ./mastDownload/HST/u9713005m/u9713005m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713005m_c1m.fits to ./mastDownload/HST/u9713005m/u9713005m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713008m_c0m.fits to ./mastDownload/HST/u9713008m/u9713008m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713008m_c1m.fits to ./mastDownload/HST/u9713008m/u9713008m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713102m_c0m.fits to ./mastDownload/HST/u9713102m/u9713102m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713102m_c1m.fits to ./mastDownload/HST/u9713102m/u9713102m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713105m_c0m.fits to ./mastDownload/HST/u9713105m/u9713105m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713105m_c1m.fits to ./mastDownload/HST/u9713105m/u9713105m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713108m_c0m.fits to ./mastDownload/HST/u9713108m/u9713108m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713108m_c1m.fits to ./mastDownload/HST/u9713108m/u9713108m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713202m_c0m.fits to ./mastDownload/HST/u9713202m/u9713202m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713202m_c1m.fits to ./mastDownload/HST/u9713202m/u9713202m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713205m_c0m.fits to ./mastDownload/HST/u9713205m/u9713205m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713205m_c1m.fits to ./mastDownload/HST/u9713205m/u9713205m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713208m_c0m.fits to ./mastDownload/HST/u9713208m/u9713208m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713208m_c1m.fits to ./mastDownload/HST/u9713208m/u9713208m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713302m_c0m.fits to ./mastDownload/HST/u9713302m/u9713302m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713302m_c1m.fits to ./mastDownload/HST/u9713302m/u9713302m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713305m_c0m.fits to ./mastDownload/HST/u9713305m/u9713305m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713305m_c1m.fits to ./mastDownload/HST/u9713305m/u9713305m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713308m_c0m.fits to ./mastDownload/HST/u9713308m/u9713308m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713308m_c1m.fits to ./mastDownload/HST/u9713308m/u9713308m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713402m_c0m.fits to ./mastDownload/HST/u9713402m/u9713402m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713402m_c1m.fits to ./mastDownload/HST/u9713402m/u9713402m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713405m_c0m.fits to ./mastDownload/HST/u9713405m/u9713405m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713405m_c1m.fits to ./mastDownload/HST/u9713405m/u9713405m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713408m_c0m.fits to ./mastDownload/HST/u9713408m/u9713408m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713408m_c1m.fits to ./mastDownload/HST/u9713408m/u9713408m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713502m_c0m.fits to ./mastDownload/HST/u9713502m/u9713502m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713502m_c1m.fits to ./mastDownload/HST/u9713502m/u9713502m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713505m_c0m.fits to ./mastDownload/HST/u9713505m/u9713505m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713505m_c1m.fits to ./mastDownload/HST/u9713505m/u9713505m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713508m_c0m.fits to ./mastDownload/HST/u9713508m/u9713508m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713508m_c1m.fits to ./mastDownload/HST/u9713508m/u9713508m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713602m_c0m.fits to ./mastDownload/HST/u9713602m/u9713602m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713602m_c1m.fits to ./mastDownload/HST/u9713602m/u9713602m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713605m_c0m.fits to ./mastDownload/HST/u9713605m/u9713605m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713605m_c1m.fits to ./mastDownload/HST/u9713605m/u9713605m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713608m_c0m.fits to ./mastDownload/HST/u9713608m/u9713608m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/u9713608m_c1m.fits to ./mastDownload/HST/u9713608m/u9713608m_c1m.fits ... [Done]

# %% [markdown]
# ## 2. Update the WCS
#
# WFPC2 images downloaded from the archive contain World Coordinate System (WCS) information based on an older-style description of image distortions. Before these images can be processed with `drizzlepac`, their WCS must be converted to a new format. This can be achieved using `updatewcs()` function from the `stwcs` package. More details may be found here: ['Making WFPC2 Images Compatible with AstroDrizzle'](http://documents.stsci.edu/hst/HST_overview/documents/DrizzlePac/ch45.html#601857). Note that `updatewcs` is no longer a parameter in AstroDrizzle or TweakReg and must be run separately before processing the data.
#
# First we download the reference files from the CRDS website. See the initialization notebook in this repository for more information.

# %%
os.environ['CRDS_SERVER_URL'] = 'https://hst-crds.stsci.edu'
os.environ['CRDS_PATH'] = os.path.abspath(os.path.join('.', 'reference_files'))

subprocess.check_output('crds bestrefs --files *c0m.fits --sync-references=1 --update-bestrefs', shell=True)

#
os.environ['uref'] = os.path.abspath(os.path.join('.', 'reference_files', 'references', 'hst', 'wfpc2')) + os.path.sep

# %%
! echo $uref
# Out:
# /home/mmarcano/Documents/NGC6397F336W/u9712005F606W/reference_files/references/hst/wfpc2/

# %% [markdown]
# **NOTE:** This next step may raise warnings because the Astrometry database is in progress and currently does not cover the entire sky. Please ignore these warnings. The WCS will still be updated.

# %%
updatewcs('u*c0m.fits', True)
# Out:
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# ...
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 88 for chip 1 : F606W
# - OFFTAB: Offset interpolated from rows 25 and 29
# - IDCTAB: Distortion model from row 254 for chip 2 : F606W
# - OFFTAB: Offset interpolated from rows 26 and 30
# - IDCTAB: Distortion model from row 420 for chip 3 : F606W
# - OFFTAB: Offset interpolated from rows 27 and 31
# - IDCTAB: Distortion model from row 586 for chip 4 : F606W
# - OFFTAB: Offset interpolated from rows 28 and 32
# ['u9710102m_c0m.fits',
#  'u9710105m_c0m.fits',
#  'u9710108m_c0m.fits',
#  'u9710202m_c0m.fits',
#  'u9710205m_c0m.fits',
#  'u9710208m_c0m.fits',
#  'u9710302m_c0m.fits',
#  'u9710305m_c0m.fits',
#  'u9710402m_c0m.fits',
#  'u9710405m_c0m.fits',
#  'u9710502m_c0m.fits',
#  'u9710505m_c0m.fits',
#  'u9710602m_c0m.fits',
#  'u9710605m_c0m.fits',
#  'u9710702m_c0m.fits',
#  'u9710705m_c0m.fits',
#  'u9710802m_c0m.fits',
#  'u9710805m_c0m.fits',
#  'u9710902m_c0m.fits',
#  'u9710905m_c0m.fits',
#  'u9711002m_c0m.fits',
#  'u9711005m_c0m.fits',
#  'u9711102m_c0m.fits',
#  'u9711105m_c0m.fits',
#  'u9711202m_c0m.fits',
#  'u9711205m_c0m.fits',
#  'u9711208m_c0m.fits',
#  'u971120bm_c0m.fits',
#  'u971120em_c0m.fits',
#  'u9711302m_c0m.fits',
#  'u9711305m_c0m.fits',
#  'u9711308m_c0m.fits',
#  'u971130bm_c0m.fits',
#  'u971130em_c0m.fits',
#  'u9711402m_c0m.fits',
#  'u9711405m_c0m.fits',
#  'u9711408m_c0m.fits',
#  'u971140bm_c0m.fits',
#  'u971140em_c0m.fits',
#  'u9711502m_c0m.fits',
#  'u9711505m_c0m.fits',
#  'u9711508m_c0m.fits',
#  'u971150bm_c0m.fits',
#  'u971150em_c0m.fits',
#  'u9711602m_c0m.fits',
#  'u9711605m_c0m.fits',
#  'u9711608m_c0m.fits',
#  'u971160bm_c0m.fits',
#  'u971160em_c0m.fits',
#  'u9711702m_c0m.fits',
#  'u9711705m_c0m.fits',
#  'u9711708m_c0m.fits',
#  'u971170bm_c0m.fits',
#  'u971170em_c0m.fits',
#  'u9711802m_c0m.fits',
#  'u9711805m_c0m.fits',
#  'u9711808m_c0m.fits',
#  'u971180bm_c0m.fits',
#  'u971180em_c0m.fits',
#  'u9711902m_c0m.fits',
#  'u9711905m_c0m.fits',
#  'u9711908m_c0m.fits',
#  'u971190bm_c0m.fits',
#  'u971190em_c0m.fits',
#  'u9712002m_c0m.fits',
#  'u9712005m_c0m.fits',
#  'u9712008m_c0m.fits',
#  'u971200bm_c0m.fits',
#  'u971200em_c0m.fits',
#  'u9712102m_c0m.fits',
#  'u9712105m_c0m.fits',
#  'u9712108m_c0m.fits',
#  'u971210bm_c0m.fits',
#  'u971210em_c0m.fits',
#  'u9712202m_c0m.fits',
#  'u9712205m_c0m.fits',
#  'u9712208m_c0m.fits',
#  'u971220bm_c0m.fits',
#  'u971220em_c0m.fits',
#  'u9712302m_c0m.fits',
#  'u9712305m_c0m.fits',
#  'u9712308m_c0m.fits',
#  'u971230bm_c0m.fits',
#  'u971230em_c0m.fits',
#  'u9712402m_c0m.fits',
#  'u9712405m_c0m.fits',
#  'u9712408m_c0m.fits',
#  'u971240bm_c0m.fits',
#  'u971240em_c0m.fits',
#  'u9712502m_c0m.fits',
#  'u9712505m_c0m.fits',
#  'u9712508m_c0m.fits',
#  'u971250bm_c0m.fits',
#  'u971250em_c0m.fits',
#  'u9712602m_c0m.fits',
#  'u9712605m_c0m.fits',
#  'u9712608m_c0m.fits',
#  'u9712702m_c0m.fits',
#  'u9712705m_c0m.fits',
#  'u9712802m_c0m.fits',
#  'u9712805m_c0m.fits',
#  'u9712808m_c0m.fits',
#  'u9712902m_c0m.fits',
#  'u9712905m_c0m.fits',
#  'u9712908m_c0m.fits',
#  'u9713002m_c0m.fits',
#  'u9713005m_c0m.fits',
#  'u9713008m_c0m.fits',
#  'u9713102m_c0m.fits',
#  'u9713105m_c0m.fits',
#  'u9713108m_c0m.fits',
#  'u9713202m_c0m.fits',
#  'u9713205m_c0m.fits',
#  'u9713208m_c0m.fits',
#  'u9713302m_c0m.fits',
#  'u9713305m_c0m.fits',
#  'u9713308m_c0m.fits',
#  'u9713402m_c0m.fits',
#  'u9713405m_c0m.fits',
#  'u9713408m_c0m.fits',
#  'u9713502m_c0m.fits',
#  'u9713505m_c0m.fits',
#  'u9713508m_c0m.fits',
#  'u9713602m_c0m.fits',
#  'u9713605m_c0m.fits',
#  'u9713608m_c0m.fits']

# %% [markdown]
# ### Backup an Image
#
# In a later section we will generate simulated data to illustrate the effects of drizzling WFPC2 images without sensitivity equalization. For that purpose we will need a copy of an original image that has the original inverse-sensitivity values (`PHOTFLAM`) in their headers. Here we create a backup copy of the first image.
#
# **NOTE:** This step is needed for illustration purpose in this notebook only. It is not needed when processing data.

# %%
orig_image = glob.glob('u*c0m.fits')[0]
backup_image = 'simulation.fits'
if os.path.isfile(backup_image):
    os.remove(backup_image)
shutil.copy2(orig_image, backup_image)
# Out:
# 'simulation.fits'

# %% [markdown]
# ## 3. Align the Images
#
# Due to small pointing errors, the image header WCS typically needs to be updated in order to achieve the best drizzle-combined products. The expected pointing accuracy for various observing scenerios is summarized in the DrizzlePac Handbook [Appendix B](http://documents.stsci.edu/hst/HST_overview/documents/DrizzlePac/AppendixB2.html). Input images must first be aligned so that when the coordinates of a given object (in detector space) are converted to sky coordinates (using the WCS), that object's sky coordinates must be approximately equal in each frame.
#
# The `DrizzlePac` task `TweakReg` may be used to correct for any errors in the image header WCS. First, `TweakReg` finds sources in each image, matches sources in common across images, and finds a separate linear transformation to align each image. `TweakReg` then computes a new WCS for each image based on this linear transformation.
#
# Here we show a basic image alignment procedure. For a more detailed illustration of image alignment, please refer to other example notebooks such as the mosaic example in this repository.

# %%
tweakreg.TweakReg('u*c0m.fits', updatehdr=True, reusename=True, interactive=False,
                  conv_width=3.0, threshold=300.0, peakmin=100, peakmax=10000)
# Out:
# Setting up logfile :  tweakreg.log
# TweakReg Version 1.4.7(18-April-2018) started at: 16:31:51.606 (21/08/2019)
#
# Version Information
# --------------------
# Python Version [GCC 7.3.0]
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# numpy Version -> 1.16.4
# astropy Version -> 3.2.1
# stwcs Version -> 1.5.1
#
# Finding shifts for:
#     u9710102m_c0m.fits
#     u9710105m_c0m.fits
#     u9710108m_c0m.fits
#     u9710202m_c0m.fits
#     u9710205m_c0m.fits
#     u9710208m_c0m.fits
#     u9710302m_c0m.fits
#     u9710305m_c0m.fits
#     u9710402m_c0m.fits
#     u9710405m_c0m.fits
#     u9710502m_c0m.fits
#     u9710505m_c0m.fits
#     u9710602m_c0m.fits
#     u9710605m_c0m.fits
#     u9710702m_c0m.fits
#     u9710705m_c0m.fits
#     u9710802m_c0m.fits
#     u9710805m_c0m.fits
#     u9710902m_c0m.fits
#     u9710905m_c0m.fits
#     u9711002m_c0m.fits
#     u9711005m_c0m.fits
#     u9711102m_c0m.fits
#     u9711105m_c0m.fits
#     u9711202m_c0m.fits
#     u9711205m_c0m.fits
#     u9711208m_c0m.fits
#     u971120bm_c0m.fits
#     u971120em_c0m.fits
#     u9711302m_c0m.fits
#     u9711305m_c0m.fits
#     u9711308m_c0m.fits
#     u971130bm_c0m.fits
#     u971130em_c0m.fits
#     u9711402m_c0m.fits
#     u9711405m_c0m.fits
#     u9711408m_c0m.fits
#     u971140bm_c0m.fits
#     u971140em_c0m.fits
#     u9711502m_c0m.fits
#     u9711505m_c0m.fits
#     u9711508m_c0m.fits
#     u971150bm_c0m.fits
#     u971150em_c0m.fits
#     u9711602m_c0m.fits
#     u9711605m_c0m.fits
#     u9711608m_c0m.fits
#     u971160bm_c0m.fits
#     u971160em_c0m.fits
#     u9711702m_c0m.fits
#     u9711705m_c0m.fits
#     u9711708m_c0m.fits
#     u971170bm_c0m.fits
#     u971170em_c0m.fits
#     u9711802m_c0m.fits
#     u9711805m_c0m.fits
#     u9711808m_c0m.fits
#     u971180bm_c0m.fits
#     u971180em_c0m.fits
#     u9711902m_c0m.fits
#     u9711905m_c0m.fits
#     u9711908m_c0m.fits
#     u971190bm_c0m.fits
#     u971190em_c0m.fits
#     u9712002m_c0m.fits
#     u9712005m_c0m.fits
#     u9712008m_c0m.fits
#     u971200bm_c0m.fits
#     u971200em_c0m.fits
#     u9712102m_c0m.fits
#     u9712105m_c0m.fits
#     u9712108m_c0m.fits
#     u971210bm_c0m.fits
#     u971210em_c0m.fits
#     u9712202m_c0m.fits
#     u9712205m_c0m.fits
#     u9712208m_c0m.fits
#     u971220bm_c0m.fits
#     u971220em_c0m.fits
#     u9712302m_c0m.fits
#     u9712305m_c0m.fits
#     u9712308m_c0m.fits
#     u971230bm_c0m.fits
#     u971230em_c0m.fits
#     u9712402m_c0m.fits
#     u9712405m_c0m.fits
#     u9712408m_c0m.fits
#     u971240bm_c0m.fits
#     u971240em_c0m.fits
#     u9712502m_c0m.fits
#     u9712505m_c0m.fits
#     u9712508m_c0m.fits
#     u971250bm_c0m.fits
#     u971250em_c0m.fits
#     u9712602m_c0m.fits
#     u9712605m_c0m.fits
#     u9712608m_c0m.fits
#     u9712702m_c0m.fits
#     u9712705m_c0m.fits
#     u9712802m_c0m.fits
#     u9712805m_c0m.fits
#     u9712808m_c0m.fits
#     u9712902m_c0m.fits
#     u9712905m_c0m.fits
#     u9712908m_c0m.fits
#     u9713002m_c0m.fits
#     u9713005m_c0m.fits
#     u9713008m_c0m.fits
#     u9713102m_c0m.fits
#     u9713105m_c0m.fits
#     u9713108m_c0m.fits
#     u9713202m_c0m.fits
#     u9713205m_c0m.fits
#     u9713208m_c0m.fits
#     u9713302m_c0m.fits
#     u9713305m_c0m.fits
#     u9713308m_c0m.fits
#     u9713402m_c0m.fits
#     u9713405m_c0m.fits
#     u9713408m_c0m.fits
#     u9713502m_c0m.fits
#     u9713505m_c0m.fits
#     u9713508m_c0m.fits
#     u9713602m_c0m.fits
#     u9713605m_c0m.fits
#     u9713608m_c0m.fits
#
# ===  Source finding for image 'u9710102m_c0m.fits':
#   #  Source finding for 'u9710102m_c0m.fits', EXT=('SCI', 1) started at: 16:31:51.861 (21/08/2019)
#      Found 308 objects.
#   #  Source finding for 'u9710102m_c0m.fits', EXT=('SCI', 2) started at: 16:31:53.346 (21/08/2019)
#      Found 804 objects.
#   #  Source finding for 'u9710102m_c0m.fits', EXT=('SCI', 3) started at: 16:31:53.661 (21/08/2019)
#      Found 2057 objects.
#   #  Source finding for 'u9710102m_c0m.fits', EXT=('SCI', 4) started at: 16:31:54.073 (21/08/2019)
#      Found 1169 objects.
# ===  FINAL number of objects in image 'u9710102m_c0m.fits': 4338
#
# ===  Source finding for image 'u9710105m_c0m.fits':
#   #  Source finding for 'u9710105m_c0m.fits', EXT=('SCI', 1) started at: 16:31:55.416 (21/08/2019)
#      Found 338 objects.
#   #  Source finding for 'u9710105m_c0m.fits', EXT=('SCI', 2) started at: 16:31:55.625 (21/08/2019)
#      Found 862 objects.
#   #  Source finding for 'u9710105m_c0m.fits', EXT=('SCI', 3) started at: 16:31:55.84 (21/08/2019)
#      Found 2015 objects.
#   #  Source finding for 'u9710105m_c0m.fits', EXT=('SCI', 4) started at: 16:31:56.244 (21/08/2019)
#      Found 1274 objects.
# ===  FINAL number of objects in image 'u9710105m_c0m.fits': 4489
#
# ===  Source finding for image 'u9710108m_c0m.fits':
#   #  Source finding for 'u9710108m_c0m.fits', EXT=('SCI', 1) started at: 16:31:57.314 (21/08/2019)
#      Found 359 objects.
#   #  Source finding for 'u9710108m_c0m.fits', EXT=('SCI', 2) started at: 16:31:57.463 (21/08/2019)
#      Found 861 objects.
#   #  Source finding for 'u9710108m_c0m.fits', EXT=('SCI', 3) started at: 16:31:57.669 (21/08/2019)
#      Found 2010 objects.
#   #  Source finding for 'u9710108m_c0m.fits', EXT=('SCI', 4) started at: 16:31:58.045 (21/08/2019)
#      Found 1262 objects.
# ===  FINAL number of objects in image 'u9710108m_c0m.fits': 4492
#
# ===  Source finding for image 'u9710202m_c0m.fits':
#   #  Source finding for 'u9710202m_c0m.fits', EXT=('SCI', 1) started at: 16:31:59.242 (21/08/2019)
#      Found 293 objects.
#   #  Source finding for 'u9710202m_c0m.fits', EXT=('SCI', 2) started at: 16:31:59.400 (21/08/2019)
#      Found 812 objects.
#   #  Source finding for 'u9710202m_c0m.fits', EXT=('SCI', 3) started at: 16:31:59.670 (21/08/2019)
#      Found 2142 objects.
#   #  Source finding for 'u9710202m_c0m.fits', EXT=('SCI', 4) started at: 16:32:00.06 (21/08/2019)
#      Found 1152 objects.
# ===  FINAL number of objects in image 'u9710202m_c0m.fits': 4399
#
# ===  Source finding for image 'u9710205m_c0m.fits':
#   #  Source finding for 'u9710205m_c0m.fits', EXT=('SCI', 1) started at: 16:32:01.210 (21/08/2019)
#      Found 297 objects.
#   #  Source finding for 'u9710205m_c0m.fits', EXT=('SCI', 2) started at: 16:32:01.398 (21/08/2019)
#      Found 882 objects.
#   #  Source finding for 'u9710205m_c0m.fits', EXT=('SCI', 3) started at: 16:32:01.680 (21/08/2019)
#      Found 2089 objects.
#   #  Source finding for 'u9710205m_c0m.fits', EXT=('SCI', 4) started at: 16:32:02.070 (21/08/2019)
#      Found 1298 objects.
# ===  FINAL number of objects in image 'u9710205m_c0m.fits': 4566
#
# ===  Source finding for image 'u9710208m_c0m.fits':
#   #  Source finding for 'u9710208m_c0m.fits', EXT=('SCI', 1) started at: 16:32:03.11 (21/08/2019)
#      Found 320 objects.
#   #  Source finding for 'u9710208m_c0m.fits', EXT=('SCI', 2) started at: 16:32:03.309 (21/08/2019)
#      Found 863 objects.
#   #  Source finding for 'u9710208m_c0m.fits', EXT=('SCI', 3) started at: 16:32:03.509 (21/08/2019)
#      Found 2047 objects.
#   #  Source finding for 'u9710208m_c0m.fits', EXT=('SCI', 4) started at: 16:32:03.849 (21/08/2019)
#      Found 1238 objects.
# ===  FINAL number of objects in image 'u9710208m_c0m.fits': 4468
#
# ===  Source finding for image 'u9710302m_c0m.fits':
#   #  Source finding for 'u9710302m_c0m.fits', EXT=('SCI', 1) started at: 16:32:04.977 (21/08/2019)
#      Found 247 objects.
#   #  Source finding for 'u9710302m_c0m.fits', EXT=('SCI', 2) started at: 16:32:05.106 (21/08/2019)
#      Found 809 objects.
#   #  Source finding for 'u9710302m_c0m.fits', EXT=('SCI', 3) started at: 16:32:05.294 (21/08/2019)
#      Found 2036 objects.
#   #  Source finding for 'u9710302m_c0m.fits', EXT=('SCI', 4) started at: 16:32:05.69 (21/08/2019)
#      Found 1147 objects.
# ===  FINAL number of objects in image 'u9710302m_c0m.fits': 4239
#
# ===  Source finding for image 'u9710305m_c0m.fits':
#   #  Source finding for 'u9710305m_c0m.fits', EXT=('SCI', 1) started at: 16:32:06.716 (21/08/2019)
#      Found 258 objects.
#   #  Source finding for 'u9710305m_c0m.fits', EXT=('SCI', 2) started at: 16:32:06.842 (21/08/2019)
#      Found 834 objects.
#   #  Source finding for 'u9710305m_c0m.fits', EXT=('SCI', 3) started at: 16:32:07.031 (21/08/2019)
#      Found 2064 objects.
#   #  Source finding for 'u9710305m_c0m.fits', EXT=('SCI', 4) started at: 16:32:07.348 (21/08/2019)
#      Found 1226 objects.
# ===  FINAL number of objects in image 'u9710305m_c0m.fits': 4382
#
# ===  Source finding for image 'u9710402m_c0m.fits':
#   #  Source finding for 'u9710402m_c0m.fits', EXT=('SCI', 1) started at: 16:32:08.429 (21/08/2019)
#      Found 298 objects.
#   #  Source finding for 'u9710402m_c0m.fits', EXT=('SCI', 2) started at: 16:32:08.624 (21/08/2019)
#      Found 862 objects.
#   #  Source finding for 'u9710402m_c0m.fits', EXT=('SCI', 3) started at: 16:32:08.901 (21/08/2019)
#      Found 2146 objects.
#   #  Source finding for 'u9710402m_c0m.fits', EXT=('SCI', 4) started at: 16:32:09.300 (21/08/2019)
#      Found 1159 objects.
# ===  FINAL number of objects in image 'u9710402m_c0m.fits': 4465
#
# ===  Source finding for image 'u9710405m_c0m.fits':
#   #  Source finding for 'u9710405m_c0m.fits', EXT=('SCI', 1) started at: 16:32:10.382 (21/08/2019)
#      Found 308 objects.
#   #  Source finding for 'u9710405m_c0m.fits', EXT=('SCI', 2) started at: 16:32:10.575 (21/08/2019)
#      Found 846 objects.
#   #  Source finding for 'u9710405m_c0m.fits', EXT=('SCI', 3) started at: 16:32:10.847 (21/08/2019)
#      Found 2088 objects.
#   #  Source finding for 'u9710405m_c0m.fits', EXT=('SCI', 4) started at: 16:32:11.314 (21/08/2019)
#      Found 1284 objects.
# ===  FINAL number of objects in image 'u9710405m_c0m.fits': 4526
#
# ===  Source finding for image 'u9710502m_c0m.fits':
#   #  Source finding for 'u9710502m_c0m.fits', EXT=('SCI', 1) started at: 16:32:12.404 (21/08/2019)
#      Found 275 objects.
#   #  Source finding for 'u9710502m_c0m.fits', EXT=('SCI', 2) started at: 16:32:12.590 (21/08/2019)
#      Found 819 objects.
#   #  Source finding for 'u9710502m_c0m.fits', EXT=('SCI', 3) started at: 16:32:12.85 (21/08/2019)
#      Found 2115 objects.
#   #  Source finding for 'u9710502m_c0m.fits', EXT=('SCI', 4) started at: 16:32:13.249 (21/08/2019)
#      Found 1185 objects.
# ===  FINAL number of objects in image 'u9710502m_c0m.fits': 4394
#
# ===  Source finding for image 'u9710505m_c0m.fits':
#   #  Source finding for 'u9710505m_c0m.fits', EXT=('SCI', 1) started at: 16:32:14.330 (21/08/2019)
#      Found 324 objects.
#   #  Source finding for 'u9710505m_c0m.fits', EXT=('SCI', 2) started at: 16:32:14.48 (21/08/2019)
#      Found 868 objects.
#   #  Source finding for 'u9710505m_c0m.fits', EXT=('SCI', 3) started at: 16:32:14.685 (21/08/2019)
#      Found 2085 objects.
#   #  Source finding for 'u9710505m_c0m.fits', EXT=('SCI', 4) started at: 16:32:15.001 (21/08/2019)
#      Found 1261 objects.
# ===  FINAL number of objects in image 'u9710505m_c0m.fits': 4538
#
# ===  Source finding for image 'u9710602m_c0m.fits':
#   #  Source finding for 'u9710602m_c0m.fits', EXT=('SCI', 1) started at: 16:32:16.166 (21/08/2019)
#      Found 312 objects.
#   #  Source finding for 'u9710602m_c0m.fits', EXT=('SCI', 2) started at: 16:32:16.294 (21/08/2019)
#      Found 822 objects.
#   #  Source finding for 'u9710602m_c0m.fits', EXT=('SCI', 3) started at: 16:32:16.5 (21/08/2019)
#      Found 2052 objects.
#   #  Source finding for 'u9710602m_c0m.fits', EXT=('SCI', 4) started at: 16:32:16.974 (21/08/2019)
#      Found 1202 objects.
# ===  FINAL number of objects in image 'u9710602m_c0m.fits': 4388
#
# ===  Source finding for image 'u9710605m_c0m.fits':
#   #  Source finding for 'u9710605m_c0m.fits', EXT=('SCI', 1) started at: 16:32:17.967 (21/08/2019)
#      Found 313 objects.
#   #  Source finding for 'u9710605m_c0m.fits', EXT=('SCI', 2) started at: 16:32:18.095 (21/08/2019)
#      Found 887 objects.
#   #  Source finding for 'u9710605m_c0m.fits', EXT=('SCI', 3) started at: 16:32:18.326 (21/08/2019)
#      Found 2144 objects.
#   #  Source finding for 'u9710605m_c0m.fits', EXT=('SCI', 4) started at: 16:32:18.720 (21/08/2019)
#      Found 1277 objects.
# ===  FINAL number of objects in image 'u9710605m_c0m.fits': 4621
#
# ===  Source finding for image 'u9710702m_c0m.fits':
#   #  Source finding for 'u9710702m_c0m.fits', EXT=('SCI', 1) started at: 16:32:19.85 (21/08/2019)
#      Found 236 objects.
#   #  Source finding for 'u9710702m_c0m.fits', EXT=('SCI', 2) started at: 16:32:20.031 (21/08/2019)
#      Found 784 objects.
#   #  Source finding for 'u9710702m_c0m.fits', EXT=('SCI', 3) started at: 16:32:20.214 (21/08/2019)
#      Found 2020 objects.
#   #  Source finding for 'u9710702m_c0m.fits', EXT=('SCI', 4) started at: 16:32:20.5 (21/08/2019)
#      Found 1155 objects.
# ===  FINAL number of objects in image 'u9710702m_c0m.fits': 4195
#
# ===  Source finding for image 'u9710705m_c0m.fits':
#   #  Source finding for 'u9710705m_c0m.fits', EXT=('SCI', 1) started at: 16:32:21.719 (21/08/2019)
#      Found 241 objects.
#   #  Source finding for 'u9710705m_c0m.fits', EXT=('SCI', 2) started at: 16:32:21.845 (21/08/2019)
#      Found 808 objects.
#   #  Source finding for 'u9710705m_c0m.fits', EXT=('SCI', 3) started at: 16:32:22.037 (21/08/2019)
#      Found 1907 objects.
#   #  Source finding for 'u9710705m_c0m.fits', EXT=('SCI', 4) started at: 16:32:22.422 (21/08/2019)
#      Found 1194 objects.
# ===  FINAL number of objects in image 'u9710705m_c0m.fits': 4150
#
# ===  Source finding for image 'u9710802m_c0m.fits':
#   #  Source finding for 'u9710802m_c0m.fits', EXT=('SCI', 1) started at: 16:32:23.501 (21/08/2019)
#      Found 243 objects.
#   #  Source finding for 'u9710802m_c0m.fits', EXT=('SCI', 2) started at: 16:32:23.682 (21/08/2019)
#      Found 780 objects.
#   #  Source finding for 'u9710802m_c0m.fits', EXT=('SCI', 3) started at: 16:32:23.949 (21/08/2019)
#      Found 2064 objects.
#   #  Source finding for 'u9710802m_c0m.fits', EXT=('SCI', 4) started at: 16:32:24.305 (21/08/2019)
#      Found 1182 objects.
# ===  FINAL number of objects in image 'u9710802m_c0m.fits': 4269
#
# ===  Source finding for image 'u9710805m_c0m.fits':
#   #  Source finding for 'u9710805m_c0m.fits', EXT=('SCI', 1) started at: 16:32:25.300 (21/08/2019)
#      Found 241 objects.
#   #  Source finding for 'u9710805m_c0m.fits', EXT=('SCI', 2) started at: 16:32:25.428 (21/08/2019)
#      Found 843 objects.
#   #  Source finding for 'u9710805m_c0m.fits', EXT=('SCI', 3) started at: 16:32:25.62 (21/08/2019)
#      Found 2103 objects.
#   #  Source finding for 'u9710805m_c0m.fits', EXT=('SCI', 4) started at: 16:32:25.94 (21/08/2019)
#      Found 1224 objects.
# ===  FINAL number of objects in image 'u9710805m_c0m.fits': 4411
#
# ===  Source finding for image 'u9710902m_c0m.fits':
#   #  Source finding for 'u9710902m_c0m.fits', EXT=('SCI', 1) started at: 16:32:27.157 (21/08/2019)
#      Found 241 objects.
#   #  Source finding for 'u9710902m_c0m.fits', EXT=('SCI', 2) started at: 16:32:27.282 (21/08/2019)
#      Found 808 objects.
#   #  Source finding for 'u9710902m_c0m.fits', EXT=('SCI', 3) started at: 16:32:27.472 (21/08/2019)
#      Found 2039 objects.
#   #  Source finding for 'u9710902m_c0m.fits', EXT=('SCI', 4) started at: 16:32:27.791 (21/08/2019)
#      Found 1186 objects.
# ===  FINAL number of objects in image 'u9710902m_c0m.fits': 4274
#
# ===  Source finding for image 'u9710905m_c0m.fits':
#   #  Source finding for 'u9710905m_c0m.fits', EXT=('SCI', 1) started at: 16:32:28.841 (21/08/2019)
#      Found 273 objects.
#   #  Source finding for 'u9710905m_c0m.fits', EXT=('SCI', 2) started at: 16:32:29.029 (21/08/2019)
#      Found 853 objects.
#   #  Source finding for 'u9710905m_c0m.fits', EXT=('SCI', 3) started at: 16:32:29.298 (21/08/2019)
#      Found 2086 objects.
#   #  Source finding for 'u9710905m_c0m.fits', EXT=('SCI', 4) started at: 16:32:29.690 (21/08/2019)
#      Found 1222 objects.
# ===  FINAL number of objects in image 'u9710905m_c0m.fits': 4434
#
# ===  Source finding for image 'u9711002m_c0m.fits':
#   #  Source finding for 'u9711002m_c0m.fits', EXT=('SCI', 1) started at: 16:32:30.952 (21/08/2019)
#      Found 232 objects.
#   #  Source finding for 'u9711002m_c0m.fits', EXT=('SCI', 2) started at: 16:32:31.137 (21/08/2019)
#      Found 776 objects.
#   #  Source finding for 'u9711002m_c0m.fits', EXT=('SCI', 3) started at: 16:32:31.404 (21/08/2019)
#      Found 2017 objects.
#   #  Source finding for 'u9711002m_c0m.fits', EXT=('SCI', 4) started at: 16:32:31.798 (21/08/2019)
#      Found 1185 objects.
# ===  FINAL number of objects in image 'u9711002m_c0m.fits': 4210
#
# ===  Source finding for image 'u9711005m_c0m.fits':
#   #  Source finding for 'u9711005m_c0m.fits', EXT=('SCI', 1) started at: 16:32:33.014 (21/08/2019)
#      Found 278 objects.
#   #  Source finding for 'u9711005m_c0m.fits', EXT=('SCI', 2) started at: 16:32:33.147 (21/08/2019)
#      Found 836 objects.
#   #  Source finding for 'u9711005m_c0m.fits', EXT=('SCI', 3) started at: 16:32:33.349 (21/08/2019)
#      Found 1968 objects.
#   #  Source finding for 'u9711005m_c0m.fits', EXT=('SCI', 4) started at: 16:32:33.736 (21/08/2019)
#      Found 1241 objects.
# ===  FINAL number of objects in image 'u9711005m_c0m.fits': 4323
#
# ===  Source finding for image 'u9711102m_c0m.fits':
#   #  Source finding for 'u9711102m_c0m.fits', EXT=('SCI', 1) started at: 16:32:34.838 (21/08/2019)
#      Found 260 objects.
#   #  Source finding for 'u9711102m_c0m.fits', EXT=('SCI', 2) started at: 16:32:34.968 (21/08/2019)
#      Found 767 objects.
#   #  Source finding for 'u9711102m_c0m.fits', EXT=('SCI', 3) started at: 16:32:35.160 (21/08/2019)
#      Found 2014 objects.
#   #  Source finding for 'u9711102m_c0m.fits', EXT=('SCI', 4) started at: 16:32:35.562 (21/08/2019)
#      Found 1165 objects.
# ===  FINAL number of objects in image 'u9711102m_c0m.fits': 4206
#
# ===  Source finding for image 'u9711105m_c0m.fits':
#   #  Source finding for 'u9711105m_c0m.fits', EXT=('SCI', 1) started at: 16:32:36.602 (21/08/2019)
#      Found 267 objects.
#   #  Source finding for 'u9711105m_c0m.fits', EXT=('SCI', 2) started at: 16:32:36.793 (21/08/2019)
#      Found 820 objects.
#   #  Source finding for 'u9711105m_c0m.fits', EXT=('SCI', 3) started at: 16:32:37.065 (21/08/2019)
#      Found 1962 objects.
#   #  Source finding for 'u9711105m_c0m.fits', EXT=('SCI', 4) started at: 16:32:37.440 (21/08/2019)
#      Found 1214 objects.
# ===  FINAL number of objects in image 'u9711105m_c0m.fits': 4263
#
# ===  Source finding for image 'u9711202m_c0m.fits':
#   #  Source finding for 'u9711202m_c0m.fits', EXT=('SCI', 1) started at: 16:32:38.446 (21/08/2019)
#      Found 253 objects.
#   #  Source finding for 'u9711202m_c0m.fits', EXT=('SCI', 2) started at: 16:32:38.602 (21/08/2019)
#      Found 835 objects.
#   #  Source finding for 'u9711202m_c0m.fits', EXT=('SCI', 3) started at: 16:32:38.858 (21/08/2019)
#      Found 1946 objects.
#   #  Source finding for 'u9711202m_c0m.fits', EXT=('SCI', 4) started at: 16:32:39.175 (21/08/2019)
#      Found 1156 objects.
# ===  FINAL number of objects in image 'u9711202m_c0m.fits': 4190
#
# ===  Source finding for image 'u9711205m_c0m.fits':
#   #  Source finding for 'u9711205m_c0m.fits', EXT=('SCI', 1) started at: 16:32:40.525 (21/08/2019)
#      Found 261 objects.
#   #  Source finding for 'u9711205m_c0m.fits', EXT=('SCI', 2) started at: 16:32:40.709 (21/08/2019)
#      Found 848 objects.
#   #  Source finding for 'u9711205m_c0m.fits', EXT=('SCI', 3) started at: 16:32:41.001 (21/08/2019)
#      Found 1977 objects.
#   #  Source finding for 'u9711205m_c0m.fits', EXT=('SCI', 4) started at: 16:32:41.431 (21/08/2019)
#      Found 1212 objects.
# ===  FINAL number of objects in image 'u9711205m_c0m.fits': 4298
#
# ===  Source finding for image 'u9711208m_c0m.fits':
#   #  Source finding for 'u9711208m_c0m.fits', EXT=('SCI', 1) started at: 16:32:42.440 (21/08/2019)
#      Found 239 objects.
#   #  Source finding for 'u9711208m_c0m.fits', EXT=('SCI', 2) started at: 16:32:42.582 (21/08/2019)
#      Found 825 objects.
#   #  Source finding for 'u9711208m_c0m.fits', EXT=('SCI', 3) started at: 16:32:42.823 (21/08/2019)
#      Found 2000 objects.
#   #  Source finding for 'u9711208m_c0m.fits', EXT=('SCI', 4) started at: 16:32:43.195 (21/08/2019)
#      Found 1167 objects.
# ===  FINAL number of objects in image 'u9711208m_c0m.fits': 4231
#
# ===  Source finding for image 'u971120bm_c0m.fits':
#   #  Source finding for 'u971120bm_c0m.fits', EXT=('SCI', 1) started at: 16:32:44.271 (21/08/2019)
#      Found 221 objects.
#   #  Source finding for 'u971120bm_c0m.fits', EXT=('SCI', 2) started at: 16:32:44.447 (21/08/2019)
#      Found 853 objects.
#   #  Source finding for 'u971120bm_c0m.fits', EXT=('SCI', 3) started at: 16:32:44.709 (21/08/2019)
#      Found 2012 objects.
#   #  Source finding for 'u971120bm_c0m.fits', EXT=('SCI', 4) started at: 16:32:45.079 (21/08/2019)
#      Found 1211 objects.
# ===  FINAL number of objects in image 'u971120bm_c0m.fits': 4297
#
# ===  Source finding for image 'u971120em_c0m.fits':
#   #  Source finding for 'u971120em_c0m.fits', EXT=('SCI', 1) started at: 16:32:46.132 (21/08/2019)
#      Found 227 objects.
#   #  Source finding for 'u971120em_c0m.fits', EXT=('SCI', 2) started at: 16:32:46.307 (21/08/2019)
#      Found 859 objects.
#   #  Source finding for 'u971120em_c0m.fits', EXT=('SCI', 3) started at: 16:32:46.575 (21/08/2019)
#      Found 1968 objects.
#   #  Source finding for 'u971120em_c0m.fits', EXT=('SCI', 4) started at: 16:32:47.004 (21/08/2019)
#      Found 1208 objects.
# ===  FINAL number of objects in image 'u971120em_c0m.fits': 4262
#
# ===  Source finding for image 'u9711302m_c0m.fits':
#   #  Source finding for 'u9711302m_c0m.fits', EXT=('SCI', 1) started at: 16:32:48.08 (21/08/2019)
#      Found 210 objects.
#   #  Source finding for 'u9711302m_c0m.fits', EXT=('SCI', 2) started at: 16:32:48.263 (21/08/2019)
#      Found 792 objects.
#   #  Source finding for 'u9711302m_c0m.fits', EXT=('SCI', 3) started at: 16:32:48.526 (21/08/2019)
#      Found 1962 objects.
#   #  Source finding for 'u9711302m_c0m.fits', EXT=('SCI', 4) started at: 16:32:48.897 (21/08/2019)
#      Found 1119 objects.
# ===  FINAL number of objects in image 'u9711302m_c0m.fits': 4083
#
# ===  Source finding for image 'u9711305m_c0m.fits':
#   #  Source finding for 'u9711305m_c0m.fits', EXT=('SCI', 1) started at: 16:32:50.103 (21/08/2019)
#      Found 251 objects.
#   #  Source finding for 'u9711305m_c0m.fits', EXT=('SCI', 2) started at: 16:32:50.284 (21/08/2019)
#      Found 809 objects.
#   #  Source finding for 'u9711305m_c0m.fits', EXT=('SCI', 3) started at: 16:32:50.548 (21/08/2019)
#      Found 1976 objects.
#   #  Source finding for 'u9711305m_c0m.fits', EXT=('SCI', 4) started at: 16:32:50.921 (21/08/2019)
#      Found 1197 objects.
# ===  FINAL number of objects in image 'u9711305m_c0m.fits': 4233
#
# ===  Source finding for image 'u9711308m_c0m.fits':
#   #  Source finding for 'u9711308m_c0m.fits', EXT=('SCI', 1) started at: 16:32:52.143 (21/08/2019)
#      Found 268 objects.
#   #  Source finding for 'u9711308m_c0m.fits', EXT=('SCI', 2) started at: 16:32:52.3 (21/08/2019)
#      Found 814 objects.
#   #  Source finding for 'u9711308m_c0m.fits', EXT=('SCI', 3) started at: 16:32:52.591 (21/08/2019)
#      Found 1991 objects.
#   #  Source finding for 'u9711308m_c0m.fits', EXT=('SCI', 4) started at: 16:32:52.963 (21/08/2019)
#      Found 1222 objects.
# ===  FINAL number of objects in image 'u9711308m_c0m.fits': 4295
#
# ===  Source finding for image 'u971130bm_c0m.fits':
#   #  Source finding for 'u971130bm_c0m.fits', EXT=('SCI', 1) started at: 16:32:54.029 (21/08/2019)
#      Found 250 objects.
#   #  Source finding for 'u971130bm_c0m.fits', EXT=('SCI', 2) started at: 16:32:54.209 (21/08/2019)
#      Found 842 objects.
#   #  Source finding for 'u971130bm_c0m.fits', EXT=('SCI', 3) started at: 16:32:54.476 (21/08/2019)
#      Found 1998 objects.
#   #  Source finding for 'u971130bm_c0m.fits', EXT=('SCI', 4) started at: 16:32:54.849 (21/08/2019)
#      Found 1185 objects.
# ===  FINAL number of objects in image 'u971130bm_c0m.fits': 4275
#
# ===  Source finding for image 'u971130em_c0m.fits':
#   #  Source finding for 'u971130em_c0m.fits', EXT=('SCI', 1) started at: 16:32:55.991 (21/08/2019)
#      Found 294 objects.
#   #  Source finding for 'u971130em_c0m.fits', EXT=('SCI', 2) started at: 16:32:56.184 (21/08/2019)
#      Found 824 objects.
#   #  Source finding for 'u971130em_c0m.fits', EXT=('SCI', 3) started at: 16:32:56.456 (21/08/2019)
#      Found 2012 objects.
#   #  Source finding for 'u971130em_c0m.fits', EXT=('SCI', 4) started at: 16:32:56.833 (21/08/2019)
#      Found 2806 objects.
# ===  FINAL number of objects in image 'u971130em_c0m.fits': 5936
#
# ===  Source finding for image 'u9711402m_c0m.fits':
#   #  Source finding for 'u9711402m_c0m.fits', EXT=('SCI', 1) started at: 16:32:58.380 (21/08/2019)
#      Found 245 objects.
#   #  Source finding for 'u9711402m_c0m.fits', EXT=('SCI', 2) started at: 16:32:58.563 (21/08/2019)
#      Found 816 objects.
#   #  Source finding for 'u9711402m_c0m.fits', EXT=('SCI', 3) started at: 16:32:58.830 (21/08/2019)
#      Found 2083 objects.
#   #  Source finding for 'u9711402m_c0m.fits', EXT=('SCI', 4) started at: 16:32:59.220 (21/08/2019)
#      Found 1139 objects.
# ===  FINAL number of objects in image 'u9711402m_c0m.fits': 4283
#
# ===  Source finding for image 'u9711405m_c0m.fits':
#   #  Source finding for 'u9711405m_c0m.fits', EXT=('SCI', 1) started at: 16:33:00.414 (21/08/2019)
#      Found 257 objects.
#   #  Source finding for 'u9711405m_c0m.fits', EXT=('SCI', 2) started at: 16:33:00.604 (21/08/2019)
#      Found 823 objects.
#   #  Source finding for 'u9711405m_c0m.fits', EXT=('SCI', 3) started at: 16:33:00.875 (21/08/2019)
#      Found 2022 objects.
#   #  Source finding for 'u9711405m_c0m.fits', EXT=('SCI', 4) started at: 16:33:01.238 (21/08/2019)
#      Found 1238 objects.
# ===  FINAL number of objects in image 'u9711405m_c0m.fits': 4340
#
# ===  Source finding for image 'u9711408m_c0m.fits':
#   #  Source finding for 'u9711408m_c0m.fits', EXT=('SCI', 1) started at: 16:33:02.287 (21/08/2019)
#      Found 285 objects.
#   #  Source finding for 'u9711408m_c0m.fits', EXT=('SCI', 2) started at: 16:33:02.478 (21/08/2019)
#      Found 828 objects.
#   #  Source finding for 'u9711408m_c0m.fits', EXT=('SCI', 3) started at: 16:33:02.745 (21/08/2019)
#      Found 1961 objects.
#   #  Source finding for 'u9711408m_c0m.fits', EXT=('SCI', 4) started at: 16:33:03.090 (21/08/2019)
#      Found 1238 objects.
# ===  FINAL number of objects in image 'u9711408m_c0m.fits': 4312
#
# ===  Source finding for image 'u971140bm_c0m.fits':
#   #  Source finding for 'u971140bm_c0m.fits', EXT=('SCI', 1) started at: 16:33:04.288 (21/08/2019)
#      Found 241 objects.
#   #  Source finding for 'u971140bm_c0m.fits', EXT=('SCI', 2) started at: 16:33:04.472 (21/08/2019)
#      Found 843 objects.
#   #  Source finding for 'u971140bm_c0m.fits', EXT=('SCI', 3) started at: 16:33:04.743 (21/08/2019)
#      Found 2068 objects.
#   #  Source finding for 'u971140bm_c0m.fits', EXT=('SCI', 4) started at: 16:33:05.190 (21/08/2019)
#      Found 1228 objects.
# ===  FINAL number of objects in image 'u971140bm_c0m.fits': 4380
#
# ===  Source finding for image 'u971140em_c0m.fits':
#   #  Source finding for 'u971140em_c0m.fits', EXT=('SCI', 1) started at: 16:33:06.282 (21/08/2019)
#      Found 239 objects.
#   #  Source finding for 'u971140em_c0m.fits', EXT=('SCI', 2) started at: 16:33:06.465 (21/08/2019)
#      Found 837 objects.
#   #  Source finding for 'u971140em_c0m.fits', EXT=('SCI', 3) started at: 16:33:06.73 (21/08/2019)
#      Found 2001 objects.
#   #  Source finding for 'u971140em_c0m.fits', EXT=('SCI', 4) started at: 16:33:07.112 (21/08/2019)
#      Found 1227 objects.
# ===  FINAL number of objects in image 'u971140em_c0m.fits': 4304
#
# ===  Source finding for image 'u9711502m_c0m.fits':
#   #  Source finding for 'u9711502m_c0m.fits', EXT=('SCI', 1) started at: 16:33:08.330 (21/08/2019)
#      Found 236 objects.
#   #  Source finding for 'u9711502m_c0m.fits', EXT=('SCI', 2) started at: 16:33:08.511 (21/08/2019)
#      Found 794 objects.
#   #  Source finding for 'u9711502m_c0m.fits', EXT=('SCI', 3) started at: 16:33:08.774 (21/08/2019)
#      Found 1986 objects.
#   #  Source finding for 'u9711502m_c0m.fits', EXT=('SCI', 4) started at: 16:33:09.148 (21/08/2019)
#      Found 1151 objects.
# ===  FINAL number of objects in image 'u9711502m_c0m.fits': 4167
#
# ===  Source finding for image 'u9711505m_c0m.fits':
#   #  Source finding for 'u9711505m_c0m.fits', EXT=('SCI', 1) started at: 16:33:10.435 (21/08/2019)
#      Found 226 objects.
#   #  Source finding for 'u9711505m_c0m.fits', EXT=('SCI', 2) started at: 16:33:10.616 (21/08/2019)
#      Found 830 objects.
#   #  Source finding for 'u9711505m_c0m.fits', EXT=('SCI', 3) started at: 16:33:10.884 (21/08/2019)
#      Found 1977 objects.
#   #  Source finding for 'u9711505m_c0m.fits', EXT=('SCI', 4) started at: 16:33:11.261 (21/08/2019)
#      Found 1218 objects.
# ===  FINAL number of objects in image 'u9711505m_c0m.fits': 4251
#
# ===  Source finding for image 'u9711508m_c0m.fits':
#   #  Source finding for 'u9711508m_c0m.fits', EXT=('SCI', 1) started at: 16:33:12.256 (21/08/2019)
#      Found 244 objects.
#   #  Source finding for 'u9711508m_c0m.fits', EXT=('SCI', 2) started at: 16:33:12.438 (21/08/2019)
#      Found 830 objects.
#   #  Source finding for 'u9711508m_c0m.fits', EXT=('SCI', 3) started at: 16:33:12.706 (21/08/2019)
#      Found 2020 objects.
#   #  Source finding for 'u9711508m_c0m.fits', EXT=('SCI', 4) started at: 16:33:13.085 (21/08/2019)
#      Found 1216 objects.
# ===  FINAL number of objects in image 'u9711508m_c0m.fits': 4310
#
# ===  Source finding for image 'u971150bm_c0m.fits':
#   #  Source finding for 'u971150bm_c0m.fits', EXT=('SCI', 1) started at: 16:33:14.175 (21/08/2019)
#      Found 278 objects.
#   #  Source finding for 'u971150bm_c0m.fits', EXT=('SCI', 2) started at: 16:33:14.362 (21/08/2019)
#      Found 839 objects.
#   #  Source finding for 'u971150bm_c0m.fits', EXT=('SCI', 3) started at: 16:33:14.631 (21/08/2019)
#      Found 2008 objects.
#   #  Source finding for 'u971150bm_c0m.fits', EXT=('SCI', 4) started at: 16:33:15.004 (21/08/2019)
#      Found 1204 objects.
# ===  FINAL number of objects in image 'u971150bm_c0m.fits': 4329
#
# ===  Source finding for image 'u971150em_c0m.fits':
#   #  Source finding for 'u971150em_c0m.fits', EXT=('SCI', 1) started at: 16:33:16.172 (21/08/2019)
#      Found 270 objects.
#   #  Source finding for 'u971150em_c0m.fits', EXT=('SCI', 2) started at: 16:33:16.357 (21/08/2019)
#      Found 830 objects.
#   #  Source finding for 'u971150em_c0m.fits', EXT=('SCI', 3) started at: 16:33:16.624 (21/08/2019)
#      Found 2023 objects.
#   #  Source finding for 'u971150em_c0m.fits', EXT=('SCI', 4) started at: 16:33:17.003 (21/08/2019)
#      Found 1196 objects.
# ===  FINAL number of objects in image 'u971150em_c0m.fits': 4319
#
# ===  Source finding for image 'u9711602m_c0m.fits':
#   #  Source finding for 'u9711602m_c0m.fits', EXT=('SCI', 1) started at: 16:33:18.049 (21/08/2019)
#      Found 244 objects.
#   #  Source finding for 'u9711602m_c0m.fits', EXT=('SCI', 2) started at: 16:33:18.231 (21/08/2019)
#      Found 802 objects.
#   #  Source finding for 'u9711602m_c0m.fits', EXT=('SCI', 3) started at: 16:33:18.497 (21/08/2019)
#      Found 2027 objects.
#   #  Source finding for 'u9711602m_c0m.fits', EXT=('SCI', 4) started at: 16:33:18.886 (21/08/2019)
#      Found 1155 objects.
# ===  FINAL number of objects in image 'u9711602m_c0m.fits': 4228
#
# ===  Source finding for image 'u9711605m_c0m.fits':
#   #  Source finding for 'u9711605m_c0m.fits', EXT=('SCI', 1) started at: 16:33:19.982 (21/08/2019)
#      Found 228 objects.
#   #  Source finding for 'u9711605m_c0m.fits', EXT=('SCI', 2) started at: 16:33:20.180 (21/08/2019)
#      Found 821 objects.
#   #  Source finding for 'u9711605m_c0m.fits', EXT=('SCI', 3) started at: 16:33:20.413 (21/08/2019)
#      Found 1984 objects.
#   #  Source finding for 'u9711605m_c0m.fits', EXT=('SCI', 4) started at: 16:33:20.796 (21/08/2019)
#      Found 1233 objects.
# ===  FINAL number of objects in image 'u9711605m_c0m.fits': 4266
#
# ===  Source finding for image 'u9711608m_c0m.fits':
#   #  Source finding for 'u9711608m_c0m.fits', EXT=('SCI', 1) started at: 16:33:21.82 (21/08/2019)
#      Found 243 objects.
#   #  Source finding for 'u9711608m_c0m.fits', EXT=('SCI', 2) started at: 16:33:21.987 (21/08/2019)
#      Found 810 objects.
#   #  Source finding for 'u9711608m_c0m.fits', EXT=('SCI', 3) started at: 16:33:22.214 (21/08/2019)
#      Found 1929 objects.
#   #  Source finding for 'u9711608m_c0m.fits', EXT=('SCI', 4) started at: 16:33:22.550 (21/08/2019)
#      Found 1242 objects.
# ===  FINAL number of objects in image 'u9711608m_c0m.fits': 4224
#
# ===  Source finding for image 'u971160bm_c0m.fits':
#   #  Source finding for 'u971160bm_c0m.fits', EXT=('SCI', 1) started at: 16:33:23.710 (21/08/2019)
#      Found 227 objects.
#   #  Source finding for 'u971160bm_c0m.fits', EXT=('SCI', 2) started at: 16:33:23.907 (21/08/2019)
#      Found 832 objects.
#   #  Source finding for 'u971160bm_c0m.fits', EXT=('SCI', 3) started at: 16:33:24.198 (21/08/2019)
#      Found 1986 objects.
#   #  Source finding for 'u971160bm_c0m.fits', EXT=('SCI', 4) started at: 16:33:24.641 (21/08/2019)
#      Found 1211 objects.
# ===  FINAL number of objects in image 'u971160bm_c0m.fits': 4256
#
# ===  Source finding for image 'u971160em_c0m.fits':
#   #  Source finding for 'u971160em_c0m.fits', EXT=('SCI', 1) started at: 16:33:25.590 (21/08/2019)
#      Found 244 objects.
#   #  Source finding for 'u971160em_c0m.fits', EXT=('SCI', 2) started at: 16:33:25.773 (21/08/2019)
#      Found 806 objects.
#   #  Source finding for 'u971160em_c0m.fits', EXT=('SCI', 3) started at: 16:33:26.086 (21/08/2019)
#      Found 2002 objects.
#   #  Source finding for 'u971160em_c0m.fits', EXT=('SCI', 4) started at: 16:33:26.499 (21/08/2019)
#      Found 1247 objects.
# ===  FINAL number of objects in image 'u971160em_c0m.fits': 4299
#
# ===  Source finding for image 'u9711702m_c0m.fits':
#   #  Source finding for 'u9711702m_c0m.fits', EXT=('SCI', 1) started at: 16:33:27.66 (21/08/2019)
#      Found 222 objects.
#   #  Source finding for 'u9711702m_c0m.fits', EXT=('SCI', 2) started at: 16:33:27.850 (21/08/2019)
#      Found 764 objects.
#   #  Source finding for 'u9711702m_c0m.fits', EXT=('SCI', 3) started at: 16:33:28.11 (21/08/2019)
#      Found 1956 objects.
#   #  Source finding for 'u9711702m_c0m.fits', EXT=('SCI', 4) started at: 16:33:28.495 (21/08/2019)
#      Found 1139 objects.
# ===  FINAL number of objects in image 'u9711702m_c0m.fits': 4081
#
# ===  Source finding for image 'u9711705m_c0m.fits':
#   #  Source finding for 'u9711705m_c0m.fits', EXT=('SCI', 1) started at: 16:33:29.583 (21/08/2019)
#      Found 239 objects.
#   #  Source finding for 'u9711705m_c0m.fits', EXT=('SCI', 2) started at: 16:33:29.768 (21/08/2019)
#      Found 803 objects.
#   #  Source finding for 'u9711705m_c0m.fits', EXT=('SCI', 3) started at: 16:33:30.034 (21/08/2019)
#      Found 1982 objects.
#   #  Source finding for 'u9711705m_c0m.fits', EXT=('SCI', 4) started at: 16:33:30.407 (21/08/2019)
#      Found 1208 objects.
# ===  FINAL number of objects in image 'u9711705m_c0m.fits': 4232
#
# ===  Source finding for image 'u9711708m_c0m.fits':
#   #  Source finding for 'u9711708m_c0m.fits', EXT=('SCI', 1) started at: 16:33:31.608 (21/08/2019)
#      Found 264 objects.
#   #  Source finding for 'u9711708m_c0m.fits', EXT=('SCI', 2) started at: 16:33:31.798 (21/08/2019)
#      Found 823 objects.
#   #  Source finding for 'u9711708m_c0m.fits', EXT=('SCI', 3) started at: 16:33:32.067 (21/08/2019)
#      Found 1987 objects.
#   #  Source finding for 'u9711708m_c0m.fits', EXT=('SCI', 4) started at: 16:33:32.444 (21/08/2019)
#      Found 1242 objects.
# ===  FINAL number of objects in image 'u9711708m_c0m.fits': 4316
#
# ===  Source finding for image 'u971170bm_c0m.fits':
#   #  Source finding for 'u971170bm_c0m.fits', EXT=('SCI', 1) started at: 16:33:33.625 (21/08/2019)
#      Found 264 objects.
#   #  Source finding for 'u971170bm_c0m.fits', EXT=('SCI', 2) started at: 16:33:33.81 (21/08/2019)
#      Found 830 objects.
#   #  Source finding for 'u971170bm_c0m.fits', EXT=('SCI', 3) started at: 16:33:34.101 (21/08/2019)
#      Found 1977 objects.
#   #  Source finding for 'u971170bm_c0m.fits', EXT=('SCI', 4) started at: 16:33:34.593 (21/08/2019)
#      Found 1212 objects.
# ===  FINAL number of objects in image 'u971170bm_c0m.fits': 4283
#
# ===  Source finding for image 'u971170em_c0m.fits':
#   #  Source finding for 'u971170em_c0m.fits', EXT=('SCI', 1) started at: 16:33:35.830 (21/08/2019)
#      Found 276 objects.
#   #  Source finding for 'u971170em_c0m.fits', EXT=('SCI', 2) started at: 16:33:36.017 (21/08/2019)
#      Found 836 objects.
#   #  Source finding for 'u971170em_c0m.fits', EXT=('SCI', 3) started at: 16:33:36.294 (21/08/2019)
#      Found 1982 objects.
#   #  Source finding for 'u971170em_c0m.fits', EXT=('SCI', 4) started at: 16:33:36.682 (21/08/2019)
#      Found 1209 objects.
# ===  FINAL number of objects in image 'u971170em_c0m.fits': 4303
#
# ===  Source finding for image 'u9711802m_c0m.fits':
#   #  Source finding for 'u9711802m_c0m.fits', EXT=('SCI', 1) started at: 16:33:37.864 (21/08/2019)
#      Found 242 objects.
#   #  Source finding for 'u9711802m_c0m.fits', EXT=('SCI', 2) started at: 16:33:37.989 (21/08/2019)
#      Found 813 objects.
#   #  Source finding for 'u9711802m_c0m.fits', EXT=('SCI', 3) started at: 16:33:38.178 (21/08/2019)
#      Found 2034 objects.
#   #  Source finding for 'u9711802m_c0m.fits', EXT=('SCI', 4) started at: 16:33:38.502 (21/08/2019)
#      Found 1194 objects.
# ===  FINAL number of objects in image 'u9711802m_c0m.fits': 4283
#
# ===  Source finding for image 'u9711805m_c0m.fits':
#   #  Source finding for 'u9711805m_c0m.fits', EXT=('SCI', 1) started at: 16:33:39.602 (21/08/2019)
#      Found 250 objects.
#   #  Source finding for 'u9711805m_c0m.fits', EXT=('SCI', 2) started at: 16:33:39.788 (21/08/2019)
#      Found 794 objects.
#   #  Source finding for 'u9711805m_c0m.fits', EXT=('SCI', 3) started at: 16:33:40.050 (21/08/2019)
#      Found 1970 objects.
#   #  Source finding for 'u9711805m_c0m.fits', EXT=('SCI', 4) started at: 16:33:40.351 (21/08/2019)
#      Found 1230 objects.
# ===  FINAL number of objects in image 'u9711805m_c0m.fits': 4244
#
# ===  Source finding for image 'u9711808m_c0m.fits':
#   #  Source finding for 'u9711808m_c0m.fits', EXT=('SCI', 1) started at: 16:33:41.397 (21/08/2019)
#      Found 251 objects.
#   #  Source finding for 'u9711808m_c0m.fits', EXT=('SCI', 2) started at: 16:33:41.523 (21/08/2019)
#      Found 794 objects.
#   #  Source finding for 'u9711808m_c0m.fits', EXT=('SCI', 3) started at: 16:33:41.784 (21/08/2019)
#      Found 1897 objects.
#   #  Source finding for 'u9711808m_c0m.fits', EXT=('SCI', 4) started at: 16:33:42.145 (21/08/2019)
#      Found 1224 objects.
# ===  FINAL number of objects in image 'u9711808m_c0m.fits': 4166
#
# ===  Source finding for image 'u971180bm_c0m.fits':
#   #  Source finding for 'u971180bm_c0m.fits', EXT=('SCI', 1) started at: 16:33:43.169 (21/08/2019)
#      Found 239 objects.
#   #  Source finding for 'u971180bm_c0m.fits', EXT=('SCI', 2) started at: 16:33:43.421 (21/08/2019)
#      Found 782 objects.
#   #  Source finding for 'u971180bm_c0m.fits', EXT=('SCI', 3) started at: 16:33:43.673 (21/08/2019)
#      Found 1930 objects.
#   #  Source finding for 'u971180bm_c0m.fits', EXT=('SCI', 4) started at: 16:33:44.034 (21/08/2019)
#      Found 1204 objects.
# ===  FINAL number of objects in image 'u971180bm_c0m.fits': 4155
#
# ===  Source finding for image 'u971180em_c0m.fits':
#   #  Source finding for 'u971180em_c0m.fits', EXT=('SCI', 1) started at: 16:33:45.121 (21/08/2019)
#      Found 248 objects.
#   #  Source finding for 'u971180em_c0m.fits', EXT=('SCI', 2) started at: 16:33:45.300 (21/08/2019)
#      Found 809 objects.
#   #  Source finding for 'u971180em_c0m.fits', EXT=('SCI', 3) started at: 16:33:45.563 (21/08/2019)
#      Found 1980 objects.
#   #  Source finding for 'u971180em_c0m.fits', EXT=('SCI', 4) started at: 16:33:45.931 (21/08/2019)
#      Found 1196 objects.
# ===  FINAL number of objects in image 'u971180em_c0m.fits': 4233
#
# ===  Source finding for image 'u9711902m_c0m.fits':
#   #  Source finding for 'u9711902m_c0m.fits', EXT=('SCI', 1) started at: 16:33:46.946 (21/08/2019)
#      Found 270 objects.
#   #  Source finding for 'u9711902m_c0m.fits', EXT=('SCI', 2) started at: 16:33:47.131 (21/08/2019)
#      Found 772 objects.
#   #  Source finding for 'u9711902m_c0m.fits', EXT=('SCI', 3) started at: 16:33:47.389 (21/08/2019)
#      Found 1916 objects.
#   #  Source finding for 'u9711902m_c0m.fits', EXT=('SCI', 4) started at: 16:33:47.755 (21/08/2019)
#      Found 1124 objects.
# ===  FINAL number of objects in image 'u9711902m_c0m.fits': 4082
#
# ===  Source finding for image 'u9711905m_c0m.fits':
#   #  Source finding for 'u9711905m_c0m.fits', EXT=('SCI', 1) started at: 16:33:48.995 (21/08/2019)
#      Found 244 objects.
#   #  Source finding for 'u9711905m_c0m.fits', EXT=('SCI', 2) started at: 16:33:49.120 (21/08/2019)
#      Found 798 objects.
#   #  Source finding for 'u9711905m_c0m.fits', EXT=('SCI', 3) started at: 16:33:49.307 (21/08/2019)
#      Found 1904 objects.
#   #  Source finding for 'u9711905m_c0m.fits', EXT=('SCI', 4) started at: 16:33:49.609 (21/08/2019)
#      Found 1194 objects.
# ===  FINAL number of objects in image 'u9711905m_c0m.fits': 4140
#
# ===  Source finding for image 'u9711908m_c0m.fits':
#   #  Source finding for 'u9711908m_c0m.fits', EXT=('SCI', 1) started at: 16:33:50.645 (21/08/2019)
#      Found 249 objects.
#   #  Source finding for 'u9711908m_c0m.fits', EXT=('SCI', 2) started at: 16:33:50.827 (21/08/2019)
#      Found 780 objects.
#   #  Source finding for 'u9711908m_c0m.fits', EXT=('SCI', 3) started at: 16:33:51.089 (21/08/2019)
#      Found 1873 objects.
#   #  Source finding for 'u9711908m_c0m.fits', EXT=('SCI', 4) started at: 16:33:51.453 (21/08/2019)
#      Found 1208 objects.
# ===  FINAL number of objects in image 'u9711908m_c0m.fits': 4110
#
# ===  Source finding for image 'u971190bm_c0m.fits':
#   #  Source finding for 'u971190bm_c0m.fits', EXT=('SCI', 1) started at: 16:33:52.561 (21/08/2019)
#      Found 248 objects.
#   #  Source finding for 'u971190bm_c0m.fits', EXT=('SCI', 2) started at: 16:33:52.744 (21/08/2019)
#      Found 816 objects.
#   #  Source finding for 'u971190bm_c0m.fits', EXT=('SCI', 3) started at: 16:33:53.009 (21/08/2019)
#      Found 1875 objects.
#   #  Source finding for 'u971190bm_c0m.fits', EXT=('SCI', 4) started at: 16:33:53.372 (21/08/2019)
#      Found 1203 objects.
# ===  FINAL number of objects in image 'u971190bm_c0m.fits': 4142
#
# ===  Source finding for image 'u971190em_c0m.fits':
#   #  Source finding for 'u971190em_c0m.fits', EXT=('SCI', 1) started at: 16:33:54.582 (21/08/2019)
#      Found 255 objects.
#   #  Source finding for 'u971190em_c0m.fits', EXT=('SCI', 2) started at: 16:33:54.769 (21/08/2019)
#      Found 815 objects.
#   #  Source finding for 'u971190em_c0m.fits', EXT=('SCI', 3) started at: 16:33:55.039 (21/08/2019)
#      Found 1964 objects.
#   #  Source finding for 'u971190em_c0m.fits', EXT=('SCI', 4) started at: 16:33:55.484 (21/08/2019)
#      Found 1194 objects.
# ===  FINAL number of objects in image 'u971190em_c0m.fits': 4228
#
# ===  Source finding for image 'u9712002m_c0m.fits':
#   #  Source finding for 'u9712002m_c0m.fits', EXT=('SCI', 1) started at: 16:33:56.62 (21/08/2019)
#      Found 243 objects.
#   #  Source finding for 'u9712002m_c0m.fits', EXT=('SCI', 2) started at: 16:33:56.805 (21/08/2019)
#      Found 792 objects.
#   #  Source finding for 'u9712002m_c0m.fits', EXT=('SCI', 3) started at: 16:33:57.07 (21/08/2019)
#      Found 2022 objects.
#   #  Source finding for 'u9712002m_c0m.fits', EXT=('SCI', 4) started at: 16:33:57.45 (21/08/2019)
#      Found 1157 objects.
# ===  FINAL number of objects in image 'u9712002m_c0m.fits': 4214
#
# ===  Source finding for image 'u9712005m_c0m.fits':
#   #  Source finding for 'u9712005m_c0m.fits', EXT=('SCI', 1) started at: 16:33:58.634 (21/08/2019)
#      Found 256 objects.
#   #  Source finding for 'u9712005m_c0m.fits', EXT=('SCI', 2) started at: 16:33:58.823 (21/08/2019)
#      Found 800 objects.
#   #  Source finding for 'u9712005m_c0m.fits', EXT=('SCI', 3) started at: 16:33:59.089 (21/08/2019)
#      Found 1967 objects.
#   #  Source finding for 'u9712005m_c0m.fits', EXT=('SCI', 4) started at: 16:33:59.465 (21/08/2019)
#      Found 1235 objects.
# ===  FINAL number of objects in image 'u9712005m_c0m.fits': 4258
#
# ===  Source finding for image 'u9712008m_c0m.fits':
#   #  Source finding for 'u9712008m_c0m.fits', EXT=('SCI', 1) started at: 16:34:00.645 (21/08/2019)
#      Found 263 objects.
#   #  Source finding for 'u9712008m_c0m.fits', EXT=('SCI', 2) started at: 16:34:00.831 (21/08/2019)
#      Found 819 objects.
#   #  Source finding for 'u9712008m_c0m.fits', EXT=('SCI', 3) started at: 16:34:01.102 (21/08/2019)
#      Found 1913 objects.
#   #  Source finding for 'u9712008m_c0m.fits', EXT=('SCI', 4) started at: 16:34:01.493 (21/08/2019)
#      Found 1225 objects.
# ===  FINAL number of objects in image 'u9712008m_c0m.fits': 4220
#
# ===  Source finding for image 'u971200bm_c0m.fits':
#   #  Source finding for 'u971200bm_c0m.fits', EXT=('SCI', 1) started at: 16:34:02.589 (21/08/2019)
#      Found 222 objects.
#   #  Source finding for 'u971200bm_c0m.fits', EXT=('SCI', 2) started at: 16:34:02.77 (21/08/2019)
#      Found 808 objects.
#   #  Source finding for 'u971200bm_c0m.fits', EXT=('SCI', 3) started at: 16:34:03.044 (21/08/2019)
#      Found 1947 objects.
#   #  Source finding for 'u971200bm_c0m.fits', EXT=('SCI', 4) started at: 16:34:03.41 (21/08/2019)
#      Found 1218 objects.
# ===  FINAL number of objects in image 'u971200bm_c0m.fits': 4195
#
# ===  Source finding for image 'u971200em_c0m.fits':
#   #  Source finding for 'u971200em_c0m.fits', EXT=('SCI', 1) started at: 16:34:04.536 (21/08/2019)
#      Found 245 objects.
#   #  Source finding for 'u971200em_c0m.fits', EXT=('SCI', 2) started at: 16:34:04.73 (21/08/2019)
#      Found 827 objects.
#   #  Source finding for 'u971200em_c0m.fits', EXT=('SCI', 3) started at: 16:34:05.03 (21/08/2019)
#      Found 2037 objects.
#   #  Source finding for 'u971200em_c0m.fits', EXT=('SCI', 4) started at: 16:34:05.352 (21/08/2019)
#      Found 1213 objects.
# ===  FINAL number of objects in image 'u971200em_c0m.fits': 4322
#
# ===  Source finding for image 'u9712102m_c0m.fits':
#   #  Source finding for 'u9712102m_c0m.fits', EXT=('SCI', 1) started at: 16:34:06.404 (21/08/2019)
#      Found 238 objects.
#   #  Source finding for 'u9712102m_c0m.fits', EXT=('SCI', 2) started at: 16:34:06.587 (21/08/2019)
#      Found 797 objects.
#   #  Source finding for 'u9712102m_c0m.fits', EXT=('SCI', 3) started at: 16:34:06.917 (21/08/2019)
#      Found 2043 objects.
#   #  Source finding for 'u9712102m_c0m.fits', EXT=('SCI', 4) started at: 16:34:07.301 (21/08/2019)
#      Found 1138 objects.
# ===  FINAL number of objects in image 'u9712102m_c0m.fits': 4216
#
# ===  Source finding for image 'u9712105m_c0m.fits':
#   #  Source finding for 'u9712105m_c0m.fits', EXT=('SCI', 1) started at: 16:34:08.532 (21/08/2019)
#      Found 239 objects.
#   #  Source finding for 'u9712105m_c0m.fits', EXT=('SCI', 2) started at: 16:34:08.713 (21/08/2019)
#      Found 832 objects.
#   #  Source finding for 'u9712105m_c0m.fits', EXT=('SCI', 3) started at: 16:34:08.978 (21/08/2019)
#      Found 2046 objects.
#   #  Source finding for 'u9712105m_c0m.fits', EXT=('SCI', 4) started at: 16:34:09.358 (21/08/2019)
#      Found 1247 objects.
# ===  FINAL number of objects in image 'u9712105m_c0m.fits': 4364
#
# ===  Source finding for image 'u9712108m_c0m.fits':
#   #  Source finding for 'u9712108m_c0m.fits', EXT=('SCI', 1) started at: 16:34:10.369 (21/08/2019)
#      Found 269 objects.
#   #  Source finding for 'u9712108m_c0m.fits', EXT=('SCI', 2) started at: 16:34:10.555 (21/08/2019)
#      Found 874 objects.
#   #  Source finding for 'u9712108m_c0m.fits', EXT=('SCI', 3) started at: 16:34:10.826 (21/08/2019)
#      Found 2014 objects.
#   #  Source finding for 'u9712108m_c0m.fits', EXT=('SCI', 4) started at: 16:34:11.201 (21/08/2019)
#      Found 1216 objects.
# ===  FINAL number of objects in image 'u9712108m_c0m.fits': 4373
#
# ===  Source finding for image 'u971210bm_c0m.fits':
#   #  Source finding for 'u971210bm_c0m.fits', EXT=('SCI', 1) started at: 16:34:12.29 (21/08/2019)
#      Found 256 objects.
#   #  Source finding for 'u971210bm_c0m.fits', EXT=('SCI', 2) started at: 16:34:12.473 (21/08/2019)
#      Found 858 objects.
#   #  Source finding for 'u971210bm_c0m.fits', EXT=('SCI', 3) started at: 16:34:12.742 (21/08/2019)
#      Found 2016 objects.
#   #  Source finding for 'u971210bm_c0m.fits', EXT=('SCI', 4) started at: 16:34:13.116 (21/08/2019)
#      Found 1211 objects.
# ===  FINAL number of objects in image 'u971210bm_c0m.fits': 4341
#
# ===  Source finding for image 'u971210em_c0m.fits':
# ...
# Plate Scale : 0.04553984249932856
# ORIENTAT : -44.69978908783577
# WCSNAME  :  TWEAK
#
# Processing u9713408m_c0m.fits['SCI',2]
#
# Updating header for u9713408m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.963149812467118e-05 1.949288324587072e-05
# CD_21  CD_22: 1.9496116897849854e-05 1.9633542287225995e-05
# CRVAL    : 265.1480243568626 -53.65119140832287
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09960632278442907
# ORIENTAT : 44.79402323131402
# WCSNAME  :  TWEAK
#
# Processing u9713408m_c0m.fits['SCI',3]
#
# Updating header for u9713408m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.9589878802659297e-05 1.9526900215582063e-05
# CD_21  CD_22: 1.9530073490427134e-05 -1.9589926832570237e-05
# CRVAL    : 265.17264341490784 -53.66603800414635
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958633628135974
# ORIENTAT : 135.09231720203167
# WCSNAME  :  TWEAK
#
# Processing u9713408m_c0m.fits['SCI',4]
#
# Updating header for u9713408m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.933771250564237e-05 -1.9798672485862667e-05
# CD_21  CD_22: -1.97984365166222e-05 -1.934538967210783e-05
# CRVAL    : 265.1471294258901 -53.68107691943903
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09963435459705
# ORIENTAT : -134.33655246894872
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713502m_c0m.fits
#
# Matching sources from 'u9713502m_c0m.fits' with sources from reference image 'u9710102m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.18396139865676275 -0.3274384018387124
#     with significance of  3237.807774315376 and  1335.0  matches
# Found 2887 matches for u9713502m_c0m.fits...
# Computed  rscale  fit for  u9713502m_c0m.fits :
# XSH: 0.1748  YSH: 0.1127    ROT: 3.279392351e-05    SCALE: 1.000041
# XRMS: 0.21    YRMS: 0.26
#
# RMS_RA: 7e-06 (deg)   RMS_DEC: 4.7e-07 (deg)
#
# Final solution based on  2694  objects.
# wrote XY data to:  u9713502m_c0m_catalog_fit.match
# Total # points:  2694
# # of points after clipping:  2694
# Total # points:  2694
# # of points after clipping:  2694
# Initializing new WCSCORR table for  u9713502m_c0m.fits
#
# ....Updating header for u9713502m_c0m.fits...
#
#
# Processing u9713502m_c0m.fits['SCI',1]
#
# Updating header for u9713502m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -9.000860445155895e-06 -8.897483254194946e-06
# CD_21  CD_22: -8.887744025444992e-06 8.991042292463594e-06
# CRVAL    : 265.1359791570739 -53.666561131002304
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.04553974870247769
# ORIENTAT : -44.70033924051733
# WCSNAME  :  TWEAK
#
# Processing u9713502m_c0m.fits['SCI',2]
#
# Updating header for u9713502m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.9631438933397094e-05 1.9492450156728817e-05
# CD_21  CD_22: 1.9495683772294223e-05 1.9633483065839076e-05
# CRVAL    : 265.14799462150734 -53.651400145534225
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09960611752299595
# ORIENTAT : 44.793473157008876
# WCSNAME  :  TWEAK
#
# Processing u9713502m_c0m.fits['SCI',3]
#
# Updating header for u9713502m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.958944546908614e-05 1.952684327569012e-05
# CD_21  CD_22: 1.953001653146558e-05 -1.958949353007698e-05
# CRVAL    : 265.1726137207981 -53.6662464160853
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958613105431342
# ORIENTAT : 135.0917670821329
# WCSNAME  :  TWEAK
#
# Processing u9713502m_c0m.fits['SCI',4]
#
# Updating header for u9713502m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.933766002557363e-05 -1.9798238188789543e-05
# CD_21  CD_22: -1.9798002351936214e-05 -1.934533714509351e-05
# CRVAL    : 265.14710018217795 -53.68128528091201
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09963414934765696
# ORIENTAT : -134.33710295339532
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713505m_c0m.fits
#
# Matching sources from 'u9713505m_c0m.fits' with sources from reference image 'u9710102m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.2854197995369745 -0.2313412496880325
#     with significance of  3157.490869241223 and  1266.0  matches
# Found 2844 matches for u9713505m_c0m.fits...
# Computed  rscale  fit for  u9713505m_c0m.fits :
# XSH: 0.1299  YSH: 0.1664    ROT: 0.001125568365    SCALE: 1.000044
# XRMS: 0.19    YRMS: 0.24
#
# RMS_RA: 6.5e-06 (deg)   RMS_DEC: 4.1e-07 (deg)
#
# Final solution based on  2625  objects.
# wrote XY data to:  u9713505m_c0m_catalog_fit.match
# Total # points:  2625
# # of points after clipping:  2625
# Total # points:  2625
# # of points after clipping:  2625
# Initializing new WCSCORR table for  u9713505m_c0m.fits
#
# ....Updating header for u9713505m_c0m.fits...
#
#
# Processing u9713505m_c0m.fits['SCI',1]
#
# Updating header for u9713505m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -9.001015456067594e-06 -8.897328212940282e-06
# CD_21  CD_22: -8.887588796531039e-06 8.991197447113038e-06
# CRVAL    : 265.13611322122676 -53.66649142788913
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.04553987131989612
# ORIENTAT : -44.699345732459506
# WCSNAME  :  TWEAK
#
# Processing u9713505m_c0m.fits['SCI',2]
#
# Updating header for u9713505m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.9631102851776594e-05 1.949279243465532e-05
# CD_21  CD_22: 1.9496026032710527e-05 1.9633147000711727e-05
# CRVAL    : 265.148129110589 -53.651330564412554
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09960638580268984
# ORIENTAT : 44.79446653825795
# WCSNAME  :  TWEAK
#
# Processing u9713505m_c0m.fits['SCI',3]
#
# Updating header for u9713505m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.958978612496947e-05 1.9526505430071764e-05
# CD_21  CD_22: 1.9529678656390246e-05 -1.958983408156807e-05
# CRVAL    : 265.17274773727723 -53.66617708938368
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958639934753974
# ORIENTAT : 135.09276075747644
# WCSNAME  :  TWEAK
#
# Processing u9713505m_c0m.fits['SCI',4]
#
# Updating header for u9713505m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9337318414643967e-05 -1.9798575780169158e-05
# CD_21  CD_22: -1.9798339708249167e-05 -1.9344995545540872e-05
# CRVAL    : 265.14723379788285 -53.68121569349376
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09963441757428458
# ORIENTAT : -134.336108863876
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713508m_c0m.fits
#
# Matching sources from 'u9713508m_c0m.fits' with sources from reference image 'u9710102m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.3622397760203384 -0.12323121892384847
#     with significance of  3185.598613226432 and  1288.0  matches
# Found 2836 matches for u9713508m_c0m.fits...
# Computed  rscale  fit for  u9713508m_c0m.fits :
# XSH: 0.0844  YSH: 0.2337    ROT: 0.001519061266    SCALE: 1.000026
# XRMS: 0.25    YRMS: 0.21
#
# RMS_RA: 7e-06 (deg)   RMS_DEC: 3.2e-07 (deg)
#
# Final solution based on  2638  objects.
# wrote XY data to:  u9713508m_c0m_catalog_fit.match
# Total # points:  2638
# # of points after clipping:  2638
# Total # points:  2638
# # of points after clipping:  2638
# Initializing new WCSCORR table for  u9713508m_c0m.fits
#
# ....Updating header for u9713508m_c0m.fits...
#
#
# Processing u9713508m_c0m.fits['SCI',1]
#
# Updating header for u9713508m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -9.001236813918853e-06 -8.89742498103114e-06
# CD_21  CD_22: -8.887685325499107e-06 8.991418722771533e-06
# CRVAL    : 265.13610588237333 -53.666621010388106
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.045539864156332065
# ORIENTAT : -44.698952306136235
# WCSNAME  :  TWEAK
#
# Processing u9713508m_c0m.fits['SCI',2]
#
# Updating header for u9713508m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.9631318842380302e-05 1.9493274444343317e-05
# CD_21  CD_22: 1.949650806407172e-05 1.963336307285428e-05
# CRVAL    : 265.1481221983318 -53.65145992568213
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09960637012287661
# ORIENTAT : 44.79485963059075
# WCSNAME  :  TWEAK
#
# Processing u9713508m_c0m.fits['SCI',3]
#
# Updating header for u9713508m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.959026899639525e-05 1.952671898271475e-05
# CD_21  CD_22: 1.9529892264326845e-05 -1.959031697405191e-05
# CRVAL    : 265.17274116746165 -53.6663068152127
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958638351812404
# ORIENTAT : 135.09315361425803
# WCSNAME  :  TWEAK
#
# Processing u9713508m_c0m.fits['SCI',4]
#
# Updating header for u9713508m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9337526958724257e-05 -1.979906131574602e-05
# CD_21  CD_22: -1.9798825181605527e-05 -1.9345204229578712e-05
# CRVAL    : 265.14722652072044 -53.68134558355506
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09963440184216914
# ORIENTAT : -134.33571546145302
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713602m_c0m.fits
#
# Matching sources from 'u9713602m_c0m.fits' with sources from reference image 'u9710102m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.6909867612265508 -0.5648130523063628
#     with significance of  3158.0832977651976 and  1233.0  matches
# Found 2938 matches for u9713602m_c0m.fits...
# Computed  rscale  fit for  u9713602m_c0m.fits :
# XSH: -0.0089  YSH: 0.0246    ROT: 0.0002150822988    SCALE: 1.000009
# XRMS: 0.12    YRMS: 0.11
#
# RMS_RA: 3.5e-06 (deg)   RMS_DEC: 2.6e-08 (deg)
#
# Final solution based on  2643  objects.
# wrote XY data to:  u9713602m_c0m_catalog_fit.match
# Total # points:  2643
# # of points after clipping:  2643
# Total # points:  2643
# # of points after clipping:  2643
# Initializing new WCSCORR table for  u9713602m_c0m.fits
#
# ....Updating header for u9713602m_c0m.fits...
#
#
# Processing u9713602m_c0m.fits['SCI',1]
#
# Updating header for u9713602m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -9.00119085784398e-06 -8.897750085562935e-06
# CD_21  CD_22: -8.888010519045335e-06 8.991372425526044e-06
# CRVAL    : 265.1359644727159 -53.66663399640215
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.04553977663491044
# ORIENTAT : -44.70014650120857
# WCSNAME  :  TWEAK
#
# Processing u9713602m_c0m.fits['SCI',2]
#
# Updating header for u9713602m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.963202891898145e-05 1.949316700683765e-05
# CD_21  CD_22: 1.949640072678651e-05 1.9634073069175417e-05
# CRVAL    : 265.1479804381108 -53.65147252560814
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09960617885020145
# ORIENTAT : 44.793665799994535
# WCSNAME  :  TWEAK
#
# Processing u9713602m_c0m.fits['SCI',3]
#
# Updating header for u9713602m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.9590164977238444e-05 1.9527429708176747e-05
# CD_21  CD_22: 1.953060302736615e-05 -1.9590213028382847e-05
# CRVAL    : 265.17260032997154 -53.666319339725554
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958619231332871
# ORIENTAT : 135.09195892009816
# WCSNAME  :  TWEAK
#
# Processing u9713602m_c0m.fits['SCI',4]
#
# Updating header for u9713602m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9338239132579386e-05 -1.97989643036722e-05
# CD_21  CD_22: -1.9798728353417196e-05 -1.9345916445658217e-05
# CRVAL    : 265.147085797319 -53.68135866287307
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09963421051025852
# ORIENTAT : -134.3369101967543
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713605m_c0m.fits
#
# Matching sources from 'u9713605m_c0m.fits' with sources from reference image 'u9710102m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.598670337735502 -0.1411853077953822
#     with significance of  3326.87876496427 and  1452.0  matches
# Found 2863 matches for u9713605m_c0m.fits...
# Computed  rscale  fit for  u9713605m_c0m.fits :
# XSH: -0.0127  YSH: 0.1416    ROT: 0.000160295036    SCALE: 0.999986
# XRMS: 0.18    YRMS: 0.16
#
# RMS_RA: 5.1e-06 (deg)   RMS_DEC: 2.4e-07 (deg)
#
# Final solution based on  2655  objects.
# wrote XY data to:  u9713605m_c0m_catalog_fit.match
# Total # points:  2655
# # of points after clipping:  2655
# Total # points:  2655
# # of points after clipping:  2655
# Initializing new WCSCORR table for  u9713605m_c0m.fits
#
# ....Updating header for u9713605m_c0m.fits...
#
#
# Processing u9713605m_c0m.fits['SCI',1]
#
# Updating header for u9713605m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -9.001378673443882e-06 -8.89798590119775e-06
# CD_21  CD_22: -8.888246134173685e-06 8.991559936355856e-06
# CRVAL    : 265.1361029570242 -53.666554897559585
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.04553983517010933
# ORIENTAT : -44.70030830069345
# WCSNAME  :  TWEAK
#
# Processing u9713605m_c0m.fits['SCI',2]
#
# Updating header for u9713605m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.963254839230828e-05 1.949357243117461e-05
# CD_21  CD_22: 1.9496806260267735e-05 1.96345926056999e-05
# CRVAL    : 265.14811911163565 -53.65139304805423
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09960630668998066
# ORIENTAT : 44.79350358404434
# WCSNAME  :  TWEAK
#
# Processing u9713605m_c0m.fits['SCI',3]
#
# Updating header for u9713605m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.9590572843470515e-05 1.952794703451899e-05
# CD_21  CD_22: 1.9531120491766084e-05 -1.9590620947965522e-05
# CRVAL    : 265.1727396104219 -53.66624017196505
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958632008665984
# ORIENTAT : 135.0917965007088
# WCSNAME  :  TWEAK
#
# Processing u9713605m_c0m.fits['SCI',4]
#
# Updating header for u9713605m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.933875252211993e-05 -1.979937778827409e-05
# CD_21  CD_22: -1.9799141886137118e-05 -1.9346430052214337e-05
# CRVAL    : 265.1472245941334 -53.68127989363309
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09963433837683291
# ORIENTAT : -134.33707242324738
# WCSNAME  :  TWEAK
#
# ====================
# Performing fit for: u9713608m_c0m.fits
#
# Matching sources from 'u9713608m_c0m.fits' with sources from reference image 'u9710102m_c0m.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.3687660437593543 -0.5925145175078264
#     with significance of  2882.20005263952 and  905.0  matches
# Found 2809 matches for u9713608m_c0m.fits...
# Computed  rscale  fit for  u9713608m_c0m.fits :
# XSH: 0.0610  YSH: -0.0209    ROT: 4.928555107e-05    SCALE: 1.000013
# XRMS: 0.2    YRMS: 0.25
#
# RMS_RA: 6.7e-06 (deg)   RMS_DEC: 4.5e-07 (deg)
#
# Final solution based on  2624  objects.
# wrote XY data to:  u9713608m_c0m_catalog_fit.match
# Total # points:  2624
# # of points after clipping:  2624
# Total # points:  2624
# # of points after clipping:  2624
# Initializing new WCSCORR table for  u9713608m_c0m.fits
#
# ....Updating header for u9713608m_c0m.fits...
#
#
# Processing u9713608m_c0m.fits['SCI',1]
#
# Updating header for u9713608m_c0m.fits[1]
# WCS Keywords
#
# CD_11  CD_12: -9.001134869701879e-06 -8.897755563106443e-06
# CD_21  CD_22: -8.888016044441326e-06 8.991316390315454e-06
# CRVAL    : 265.13600731412885 -53.666351688223045
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.045539827783087315
# ORIENTAT : -44.70034266371061
# WCSNAME  :  TWEAK
#
# Processing u9713608m_c0m.fits['SCI',2]
#
# Updating header for u9713608m_c0m.fits[2]
# WCS Keywords
#
# CD_11  CD_12: -1.96320398015116e-05 1.9493044404898437e-05
# CD_21  CD_22: 1.949627812976174e-05 1.9634083977619626e-05
# CRVAL    : 265.1480230773076 -53.65119023614697
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09960629059655494
# ORIENTAT : 44.79346970770518
# WCSNAME  :  TWEAK
#
# Processing u9713608m_c0m.fits['SCI',3]
#
# Updating header for u9713608m_c0m.fits[3]
# WCS Keywords
#
# CD_11  CD_12: 1.9590042527854225e-05 1.9527441113993475e-05
# CD_21  CD_22: 1.9530614459688884e-05 -1.9590090574915193e-05
# CRVAL    : 265.17264281996717 -53.66603695817024
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09958630409994448
# ORIENTAT : 135.09176311683058
# WCSNAME  :  TWEAK
#
# Processing u9713608m_c0m.fits['SCI',4]
#
# Updating header for u9713608m_c0m.fits[4]
# WCS Keywords
#
# CD_11  CD_12: 1.9338251944184435e-05 -1.979884179649563e-05
# CD_21  CD_22: -1.9798605884277956e-05 -1.9345929250683212e-05
# CRVAL    : 265.14712861771363 -53.681076290277844
# CRPIX    : 425.0 425.0
# NAXIS    : 800 800
# Plate Scale : 0.09963432240011966
# ORIENTAT : -134.33710636712246
# WCSNAME  :  TWEAK
# Initializing new WCSCORR table for  u9710102m_c0m.fits
# Trailer file written to:  tweakreg.log

# %% [markdown]
# ## 4. Equalize the chip sensitivities
#
# This step adjusts image data values so that all images and chips appear (to `AstroDrizzle`) to have a single inverse sensitivity (`PHOTFLAM`). This can be achieved using the `photeq` task in `Drizzlepac`. This task adjusts image data so that when these data are multiplied by the same single `PHOTFLAM` value, the correct flux is obtained.

# %%
photeq.photeq(files='u*_c0m.fits', ref_phot_ext=3, readonly=False)
# Out:
# ***** drizzlepac.photeq started on 2019-08-21 17:07:54.665821
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'u9710102m_c0m.fits[3]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.888331e-18
#
# Processing file 'u9710102m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3) - This is the "reference" extension.
#           Nothing to do. Skipping this extension...
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710105m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710108m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710202m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710205m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710208m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710302m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710305m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710402m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710405m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710502m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710505m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710602m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710605m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710702m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710705m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710802m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710805m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710902m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9710905m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711002m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711005m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711102m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711105m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711202m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711205m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711208m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971120bm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971120em_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711302m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711305m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711308m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971130bm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971130em_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711402m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711405m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711408m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971140bm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971140em_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711502m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711505m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711508m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971150bm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971150em_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711602m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711605m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711608m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971160bm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971160em_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711702m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711705m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711708m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971170bm_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u971170em_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711802m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711805m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9711808m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
# ...
#
# Processing file 'u9713008m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713102m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713105m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713108m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713202m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713205m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713208m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713302m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713305m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713308m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713402m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713405m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713408m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713502m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713505m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713508m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713602m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713605m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Processing file 'u9713608m_c0m.fits'
#    * EXT: ('SCI', 1)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.899711e-18)
#      - Computed conversion factor for data: 1.0060264858226655
#      - Data have been multiplied by 1.0060264858226655
#    * EXT: ('SCI', 2)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.842419e-18)
#      - Computed conversion factor for data: 0.9756864659850417
#      - Data have been multiplied by 0.9756864659850417
#    * EXT: ('SCI', 3)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.888331e-18)
#      - Computed conversion factor for data: 1.0
#      - Data have been multiplied by 1.0
#    * EXT: ('SCI', 4)
#      - Setting PHOTFLAM to 1.888331e-18 (old value was 1.913699e-18)
#      - Computed conversion factor for data: 1.0134340854437067
#      - Data have been multiplied by 1.0134340854437067
#
# Done.

# %% [markdown]
# In the above command, we instruct `photeq` to "equalize" all chips of all input images using the `PHOTFLAM` for the `WF3` chip (`ref_phot_ext=3`), using the first image as a reference. This reference `PHOTFLAM` value is reported in the log file:
#
# ```
# REFERENCE VALUE FROM FILE: 'ua060502m_c0m.fits['SCI',1]'
# REFERENCE 'PHOTFLAM' VALUE IS: 2.507987e-18
# ```
#
# Upon the completion, `photeq` will not only adjust image data but also update `PHOTFLAM` values for all chips to this specific reference value.

# %% [markdown]
# ## 5. Drizzle-combine the images
#
# All four chips are now drizzled together with an output pixel scale set to that of the WF chips:

# %%
astrodrizzle.AstroDrizzle('u*c0m.fits',
                          preserve=False,
                          driz_sep_bits='8,1024',
                          driz_sep_wcs=True,
                          driz_sep_scale=0.0996,
                          combine_type='median',
                          driz_cr_snr='5.5 3.5',
                          driz_cr_scale='2.0 1.5',
                          final_fillval=None,
                          final_bits='8,1024',
                          final_wcs=True,
                          num_cores=20,
                          final_scale=0.0996)
# Out:
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 2.2.6 (2018-11-02 15:37:13 -0400) started at: 19:09:01.821 (21/08/2019)
#
# ==== Processing Step  Initialization  started at  19:09:01.823 (21/08/2019)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 265.14766375561516  -53.666591554185345
# CRPIX : 774.5633782773134  764.505225604677
# CD1_1 CD1_2  : -1.9665111723156235e-05  -1.9460930742393273e-05
# CD2_1 CD2_2  : -1.9460930742393273e-05  1.9665111723156235e-05
# NAXIS : 1548  1528
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 639 Mb.
# *  Output image size:       1548 X 1528 pixels.
# *  Output image file:       ~ 27 Mb.
# *  Cores available:         20
# *
# ********************************************************************************
# ==== Processing Step  Initialization  finished at  19:10:16.872 (21/08/2019)
#
# ==== Processing Step  Static Mask  started at  19:10:16.875 (21/08/2019)
# ==== Processing Step  Static Mask  finished at  19:10:35.407 (21/08/2019)
#
# ==== Processing Step  Subtract Sky  started at  19:10:35.410 (21/08/2019)
# ***** skymatch started on 2019-08-21 19:10:59.733543
#       Version 1.0.4 (2019-05-30 14:31:23 -0400)
#
# 'skymatch' task will apply computed sky differences to input image file(s).
#
# NOTE: Computed sky values WILL NOT be subtracted from image data ('subtractsky'=False).
# 'MDRIZSKY' header keyword will represent sky value *computed* from data.
#
# -----  User specified keywords:  -----
#        Sky Value Keyword:  'MDRIZSKY'
#        Data Units Keyword: 'BUNIT'
#
#
# -----  Input file list:  -----
#
#    **  Input image: 'u9710102m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710102m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710102m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710102m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710102m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710105m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710105m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710105m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710105m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710105m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710108m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710108m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710108m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710108m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710108m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710202m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710202m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710202m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710202m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710202m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710205m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710205m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710205m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710205m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710205m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710208m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710208m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710208m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710208m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710208m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710302m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710302m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710302m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710302m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710302m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710305m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710305m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710305m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710305m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710305m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710402m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710402m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710402m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710402m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710402m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710405m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710405m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710405m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710405m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710405m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710502m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710502m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710502m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710502m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710502m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710505m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710505m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710505m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710505m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710505m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710602m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710602m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710602m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710602m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710602m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710605m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710605m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710605m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710605m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710605m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710702m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710702m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710702m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710702m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710702m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710705m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710705m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710705m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710705m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710705m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710802m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710802m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710802m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710802m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710802m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710805m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710805m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710805m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710805m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710805m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710902m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710902m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710902m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710902m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710902m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9710905m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9710905m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9710905m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9710905m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9710905m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711002m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711002m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711002m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711002m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711002m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711005m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711005m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711005m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711005m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711005m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711102m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711102m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711102m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711102m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711102m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711105m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711105m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711105m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711105m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711105m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711202m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711202m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711202m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711202m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711202m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711205m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711205m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711205m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711205m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711205m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711208m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711208m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711208m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711208m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711208m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971120bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971120bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971120bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971120bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971120bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971120em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971120em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971120em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971120em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971120em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711302m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711302m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711302m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711302m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711302m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711305m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711305m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711305m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711305m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711305m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711308m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711308m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711308m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711308m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711308m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971130bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971130bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971130bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971130bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971130bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971130em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971130em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971130em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971130em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971130em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711402m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711402m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711402m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711402m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711402m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711405m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711405m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711405m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711405m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711405m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711408m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711408m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711408m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711408m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711408m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971140bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971140bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971140bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971140bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971140bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971140em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971140em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971140em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971140em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971140em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711502m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711502m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711502m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711502m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711502m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711505m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711505m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711505m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711505m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711505m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711508m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711508m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711508m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711508m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711508m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971150bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971150bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971150bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971150bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971150bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971150em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971150em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971150em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971150em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971150em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711602m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711602m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711602m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711602m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711602m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711605m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711605m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711605m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711605m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711605m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711608m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711608m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711608m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711608m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711608m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971160bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971160bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971160bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971160bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971160bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971160em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971160em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971160em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971160em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971160em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711702m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711702m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711702m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711702m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711702m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711705m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711705m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711705m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711705m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711705m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711708m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711708m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711708m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711708m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711708m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971170bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971170bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971170bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971170bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971170bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971170em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971170em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971170em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971170em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971170em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711802m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711802m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711802m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711802m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711802m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711805m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711805m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711805m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711805m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711805m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711808m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711808m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711808m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711808m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711808m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971180bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971180bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971180bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971180bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971180bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971180em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971180em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971180em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971180em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971180em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711902m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711902m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711902m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711902m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711902m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711905m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711905m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711905m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711905m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711905m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9711908m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9711908m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9711908m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9711908m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9711908m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971190bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971190bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971190bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971190bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971190bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971190em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971190em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971190em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971190em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971190em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712002m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712002m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712002m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712002m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712002m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712005m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712005m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712005m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712005m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712005m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712008m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712008m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712008m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712008m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712008m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971200bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971200bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971200bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971200bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971200bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971200em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971200em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971200em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971200em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971200em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712102m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712102m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712102m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712102m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712102m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712105m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712105m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712105m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712105m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712105m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712108m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712108m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712108m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712108m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712108m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971210bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971210bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971210bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971210bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971210bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971210em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971210em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971210em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971210em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971210em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712202m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712202m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712202m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712202m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712202m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712205m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712205m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712205m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712205m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712205m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712208m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712208m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712208m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712208m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712208m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971220bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971220bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971220bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971220bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971220bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971220em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971220em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971220em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971220em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971220em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712302m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712302m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712302m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712302m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712302m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712305m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712305m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712305m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712305m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712305m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712308m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712308m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712308m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712308m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712308m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971230bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971230bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971230bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971230bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971230bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971230em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971230em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971230em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971230em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971230em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712402m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712402m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712402m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712402m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712402m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712405m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712405m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712405m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712405m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712405m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712408m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712408m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712408m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712408m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712408m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971240bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971240bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971240bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971240bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971240bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971240em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971240em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971240em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971240em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971240em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712502m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712502m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712502m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712502m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712502m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712505m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712505m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712505m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712505m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712505m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712508m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712508m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712508m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712508m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712508m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971250bm_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971250bm_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971250bm_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971250bm_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971250bm_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u971250em_c0m.fits'
#        EXT: 'SCI',1;	MASK: u971250em_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u971250em_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u971250em_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u971250em_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712602m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712602m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712602m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712602m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712602m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712605m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712605m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712605m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712605m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712605m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712608m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712608m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712608m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712608m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712608m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712702m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712702m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712702m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712702m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712702m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712705m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712705m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712705m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712705m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712705m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712802m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712802m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712802m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712802m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712802m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712805m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712805m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712805m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712805m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712805m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712808m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712808m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712808m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712808m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712808m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712902m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712902m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712902m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712902m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712902m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712905m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712905m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712905m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712905m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712905m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9712908m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9712908m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9712908m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9712908m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9712908m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713002m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713002m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713002m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713002m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713002m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713005m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713005m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713005m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713005m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713005m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713008m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713008m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713008m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713008m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713008m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713102m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713102m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713102m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713102m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713102m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713105m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713105m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713105m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713105m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713105m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713108m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713108m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713108m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713108m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713108m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713202m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713202m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713202m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713202m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713202m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713205m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713205m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713205m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713205m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713205m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713208m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713208m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713208m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713208m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713208m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713302m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713302m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713302m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713302m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713302m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713305m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713305m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713305m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713305m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713305m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713308m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713308m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713308m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713308m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713308m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713402m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713402m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713402m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713402m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713402m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713405m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713405m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713405m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713405m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713405m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713408m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713408m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713408m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713408m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713408m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713502m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713502m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713502m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713502m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713502m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713505m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713505m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713505m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713505m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713505m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713508m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713508m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713508m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713508m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713508m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713602m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713602m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713602m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713602m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713602m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713605m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713605m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713605m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713605m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713605m_skymatch_mask_sci4.fits[0]
#
#    **  Input image: 'u9713608m_c0m.fits'
#        EXT: 'SCI',1;	MASK: u9713608m_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: u9713608m_skymatch_mask_sci2.fits[0]
#        EXT: 'SCI',3;	MASK: u9713608m_skymatch_mask_sci3.fits[0]
#        EXT: 'SCI',4;	MASK: u9713608m_skymatch_mask_sci4.fits[0]
#
# -----  Sky statistics parameters:  -----
#        statistics function: 'median'
#        lower = None
#        upper = None
#        nclip = 5
#        lsigma = 4.0
#        usigma = 4.0
#        binwidth = 0.1
#
# -----  Data->Brightness conversion parameters for input files:  -----
#
#    *   Image: u9710102m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.9645399793502201
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20161775671959636
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.201698743028583
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20150444575074858
#
#    *   Image: u9710105m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.8037833161251834
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680147972663303
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680822858571525
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16792037145895714
#
#    *   Image: u9710108m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.8037833161251834
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680147972663303
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680822858571525
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16792037145895714
#
#    *   Image: u9710202m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.9645399793502201
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20161775671959636
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.201698743028583
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20150444575074858
#
#    *   Image: u9710205m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.8037833161251834
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680147972663303
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680822858571525
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16792037145895714
#
#    *   Image: u9710208m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.8037833161251834
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680147972663303
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680822858571525
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16792037145895714
#
#    *   Image: u9710302m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.9645399793502201
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20161775671959636
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.201698743028583
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20150444575074858
#
#    *   Image: u9710305m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.8037833161251834
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680147972663303
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680822858571525
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16792037145895714
#
#    *   Image: u9710402m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.9645399793502201
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20161775671959636
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.201698743028583
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20150444575074858
#
#    *   Image: u9710405m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.8037833161251834
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680147972663303
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680822858571525
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16792037145895714
#
#    *   Image: u9710502m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.9645399793502201
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20161775671959636
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.201698743028583
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20150444575074858
#
#    *   Image: u9710505m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.8037833161251834
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680147972663303
#        EXT = 'SCI',3
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.1680822858571525
#        EXT = 'SCI',4
#              Data units type: COUNTS
#              EXPTIME: 600.0 [s]
#              Conversion factor (data->brightness):  0.16792037145895714
#
#    *   Image: u9710602m_c0m.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.9645399793502201
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 500.0 [s]
#              Conversion factor (data->brightness):  0.20161775671959636
#        EXT = 'SCI',3
# ...
# Creating output :  u9711802m_c0m_sci3_crmask.fits
# Creating output :  u971170em_c0m_sci3_crmask.fits
# Creating output :  u9711805m_c0m_sci3_crmask.fits
# Creating output :  u971180bm_c0m_sci1_crmask.fits
# Creating output :  u9711802m_c0m_sci4_crmask.fits
# Creating output :  u9711808m_c0m_sci2_crmask.fits
# Creating output :  u971180em_c0m_sci1_crmask.fits
# Creating output :  u971170em_c0m_sci4_crmask.fits
# Creating output :  u9711805m_c0m_sci4_crmask.fits
# Creating output :  u9711808m_c0m_sci3_crmask.fits
# Creating output :  u971180bm_c0m_sci2_crmask.fits
# Creating output :  u9711902m_c0m_sci1_crmask.fits
# Creating output :  u9711905m_c0m_sci1_crmask.fits
# Creating output :  u971180em_c0m_sci2_crmask.fits
# Creating output :  u9711808m_c0m_sci4_crmask.fits
# Creating output :  u9711902m_c0m_sci2_crmask.fits
# Creating output :  u971180bm_c0m_sci3_crmask.fits
# Creating output :  u971180em_c0m_sci3_crmask.fits
# Creating output :  u9711902m_c0m_sci3_crmask.fits
# Creating output :  u9711905m_c0m_sci2_crmask.fits
# Creating output :  u971180bm_c0m_sci4_crmask.fits
# Creating output :  u9711902m_c0m_sci4_crmask.fits
# Creating output :  u9711905m_c0m_sci3_crmask.fits
# Creating output :  u971180em_c0m_sci4_crmask.fits
# Creating output :  u9711908m_c0m_sci1_crmask.fits
# Creating output :  u9711905m_c0m_sci4_crmask.fits
# Creating output :  u971190bm_c0m_sci1_crmask.fits
# Creating output :  u9711908m_c0m_sci2_crmask.fits
# Creating output :  u971190em_c0m_sci1_crmask.fits
# Creating output :  u971190bm_c0m_sci2_crmask.fits
# Creating output :  u9711908m_c0m_sci3_crmask.fits
# Creating output :  u971190em_c0m_sci2_crmask.fits
# Creating output :  u971190bm_c0m_sci3_crmask.fits
# Creating output :  u9712002m_c0m_sci1_crmask.fits
# Creating output :  u9711908m_c0m_sci4_crmask.fits
# Creating output :  u9712005m_c0m_sci1_crmask.fits
# Creating output :  u971190em_c0m_sci3_crmask.fits
# Creating output :  u9712002m_c0m_sci2_crmask.fits
# Creating output :  u9712008m_c0m_sci1_crmask.fits
# Creating output :  u971190bm_c0m_sci4_crmask.fits
# Creating output :  u971190em_c0m_sci4_crmask.fits
# Creating output :  u971200bm_c0m_sci1_crmask.fits
# Creating output :  u9712005m_c0m_sci2_crmask.fits
# Creating output :  u9712002m_c0m_sci3_crmask.fits
# Creating output :  u9712008m_c0m_sci2_crmask.fits
# Creating output :  u971200bm_c0m_sci2_crmask.fits
# Creating output :  u971200em_c0m_sci1_crmask.fits
# Creating output :  u9712005m_c0m_sci3_crmask.fits
# Creating output :  u9712002m_c0m_sci4_crmask.fits
# Creating output :  u9712008m_c0m_sci3_crmask.fits
# Creating output :  u9712102m_c0m_sci1_crmask.fits
# Creating output :  u9712005m_c0m_sci4_crmask.fits
# Creating output :  u971200bm_c0m_sci3_crmask.fits
# Creating output :  u9712105m_c0m_sci1_crmask.fits
# Creating output :  u9712008m_c0m_sci4_crmask.fits
# Creating output :  u971200em_c0m_sci2_crmask.fits
# Creating output :  u9712108m_c0m_sci1_crmask.fits
# Creating output :  u9712102m_c0m_sci2_crmask.fits
# Creating output :  u971200bm_c0m_sci4_crmask.fits
# Creating output :  u971210bm_c0m_sci1_crmask.fits
# Creating output :  u9712102m_c0m_sci3_crmask.fits
# Creating output :  u971200em_c0m_sci3_crmask.fits
# Creating output :  u9712108m_c0m_sci2_crmask.fits
# Creating output :  u9712105m_c0m_sci2_crmask.fits
# Creating output :  u971210bm_c0m_sci2_crmask.fits
# Creating output :  u971210em_c0m_sci1_crmask.fits
# Creating output :  u9712102m_c0m_sci4_crmask.fits
# Creating output :  u971200em_c0m_sci4_crmask.fits
# Creating output :  u9712105m_c0m_sci3_crmask.fits
# Creating output :  u9712108m_c0m_sci3_crmask.fits
# Creating output :  u971210bm_c0m_sci3_crmask.fits
# Creating output :  u9712105m_c0m_sci4_crmask.fits
# Creating output :  u971210em_c0m_sci2_crmask.fits
# Creating output :  u9712202m_c0m_sci1_crmask.fits
# Creating output :  u9712205m_c0m_sci1_crmask.fits
# Creating output :  u9712108m_c0m_sci4_crmask.fits
# Creating output :  u971210bm_c0m_sci4_crmask.fits
# Creating output :  u9712205m_c0m_sci2_crmask.fits
# Creating output :  u971210em_c0m_sci3_crmask.fits
# Creating output :  u9712202m_c0m_sci2_crmask.fits
# Creating output :  u9712205m_c0m_sci3_crmask.fits
# Creating output :  u9712208m_c0m_sci1_crmask.fits
# Creating output :  u971210em_c0m_sci4_crmask.fits
# Creating output :  u9712202m_c0m_sci3_crmask.fits
# Creating output :  u9712205m_c0m_sci4_crmask.fits
# Creating output :  u9712202m_c0m_sci4_crmask.fits
# Creating output :  u9712208m_c0m_sci2_crmask.fits
# Creating output :  u971220bm_c0m_sci1_crmask.fits
# Creating output :  u971220em_c0m_sci1_crmask.fits
# Creating output :  u9712208m_c0m_sci3_crmask.fits
# Creating output :  u9712302m_c0m_sci1_crmask.fits
# Creating output :  u971220em_c0m_sci2_crmask.fits
# Creating output :  u971220bm_c0m_sci2_crmask.fits
# Creating output :  u9712305m_c0m_sci1_crmask.fits
# Creating output :  u9712208m_c0m_sci4_crmask.fits
# Creating output :  u971220bm_c0m_sci3_crmask.fits
# Creating output :  u9712302m_c0m_sci2_crmask.fits
# Creating output :  u971220em_c0m_sci3_crmask.fits
# Creating output :  u9712308m_c0m_sci1_crmask.fits
# Creating output :  u9712305m_c0m_sci2_crmask.fits
# Creating output :  u971220bm_c0m_sci4_crmask.fits
# Creating output :  u9712302m_c0m_sci3_crmask.fits
# Creating output :  u9712305m_c0m_sci3_crmask.fits
# Creating output :  u971220em_c0m_sci4_crmask.fits
# Creating output :  u9712308m_c0m_sci2_crmask.fits
# Creating output :  u971230bm_c0m_sci1_crmask.fits
# Creating output :  u971230em_c0m_sci1_crmask.fits
# Creating output :  u9712302m_c0m_sci4_crmask.fits
# Creating output :  u9712308m_c0m_sci3_crmask.fits
# Creating output :  u9712305m_c0m_sci4_crmask.fits
# Creating output :  u9712402m_c0m_sci1_crmask.fits
# Creating output :  u971230bm_c0m_sci2_crmask.fits
# Creating output :  u971230em_c0m_sci2_crmask.fits
# Creating output :  u9712402m_c0m_sci2_crmask.fits
# Creating output :  u971230em_c0m_sci3_crmask.fits
# Creating output :  u9712308m_c0m_sci4_crmask.fits
# Creating output :  u9712405m_c0m_sci1_crmask.fits
# Creating output :  u971230bm_c0m_sci3_crmask.fits
# Creating output :  u971230em_c0m_sci4_crmask.fits
# Creating output :  u9712408m_c0m_sci1_crmask.fits
# Creating output :  u9712402m_c0m_sci3_crmask.fits
# Creating output :  u971240bm_c0m_sci1_crmask.fits
# Creating output :  u9712405m_c0m_sci2_crmask.fits
# Creating output :  u971230bm_c0m_sci4_crmask.fits
# Creating output :  u9712402m_c0m_sci4_crmask.fits
# Creating output :  u971240bm_c0m_sci2_crmask.fits
# Creating output :  u9712405m_c0m_sci3_crmask.fits
# Creating output :  u9712408m_c0m_sci2_crmask.fits
# Creating output :  u971240em_c0m_sci1_crmask.fits
# Creating output :  u9712502m_c0m_sci1_crmask.fits
# Creating output :  u971240em_c0m_sci2_crmask.fits
# Creating output :  u9712405m_c0m_sci4_crmask.fits
# Creating output :  u971240bm_c0m_sci3_crmask.fits
# Creating output :  u9712408m_c0m_sci3_crmask.fits
# Creating output :  u9712502m_c0m_sci2_crmask.fits
# Creating output :  u971240em_c0m_sci3_crmask.fits
# Creating output :  u9712408m_c0m_sci4_crmask.fits
# Creating output :  u9712502m_c0m_sci3_crmask.fits
# Creating output :  u971240bm_c0m_sci4_crmask.fits
# Creating output :  u9712505m_c0m_sci1_crmask.fits
# Creating output :  u971240em_c0m_sci4_crmask.fits
# Creating output :  u9712502m_c0m_sci4_crmask.fits
# Creating output :  u971250bm_c0m_sci1_crmask.fits
# Creating output :  u9712508m_c0m_sci1_crmask.fits
# Creating output :  u9712505m_c0m_sci2_crmask.fits
# Creating output :  u971250bm_c0m_sci2_crmask.fits
# Creating output :  u971250em_c0m_sci1_crmask.fits
# Creating output :  u9712508m_c0m_sci2_crmask.fits
# Creating output :  u9712505m_c0m_sci3_crmask.fits
# Creating output :  u971250bm_c0m_sci3_crmask.fits
# Creating output :  u9712508m_c0m_sci3_crmask.fits
# Creating output :  u9712602m_c0m_sci1_crmask.fits
# Creating output :  u971250em_c0m_sci2_crmask.fits
# Creating output :  u9712505m_c0m_sci4_crmask.fits
# Creating output :  u9712605m_c0m_sci1_crmask.fits
# Creating output :  u971250bm_c0m_sci4_crmask.fits
# Creating output :  u9712508m_c0m_sci4_crmask.fits
# Creating output :  u971250em_c0m_sci3_crmask.fits
# Creating output :  u9712602m_c0m_sci2_crmask.fits
# Creating output :  u9712605m_c0m_sci2_crmask.fits
# Creating output :  u9712608m_c0m_sci1_crmask.fits
# Creating output :  u971250em_c0m_sci4_crmask.fits
# Creating output :  u9712605m_c0m_sci3_crmask.fits
# Creating output :  u9712608m_c0m_sci2_crmask.fits
# Creating output :  u9712602m_c0m_sci3_crmask.fits
# Creating output :  u9712702m_c0m_sci1_crmask.fits
# Creating output :  u9712608m_c0m_sci3_crmask.fits
# Creating output :  u9712705m_c0m_sci1_crmask.fits
# Creating output :  u9712602m_c0m_sci4_crmask.fits
# Creating output :  u9712605m_c0m_sci4_crmask.fits
# Creating output :  u9712702m_c0m_sci2_crmask.fits
# Creating output :  u9712608m_c0m_sci4_crmask.fits
# Creating output :  u9712802m_c0m_sci1_crmask.fits
# Creating output :  u9712705m_c0m_sci2_crmask.fits
# Creating output :  u9712805m_c0m_sci1_crmask.fits
# Creating output :  u9712702m_c0m_sci3_crmask.fits
# Creating output :  u9712802m_c0m_sci2_crmask.fits
# Creating output :  u9712808m_c0m_sci1_crmask.fits
# Creating output :  u9712705m_c0m_sci3_crmask.fits
# Creating output :  u9712805m_c0m_sci2_crmask.fits
# Creating output :  u9712702m_c0m_sci4_crmask.fits
# Creating output :  u9712902m_c0m_sci1_crmask.fits
# Creating output :  u9712905m_c0m_sci1_crmask.fits
# Creating output :  u9712802m_c0m_sci3_crmask.fits
# Creating output :  u9712805m_c0m_sci3_crmask.fits
# Creating output :  u9712705m_c0m_sci4_crmask.fits
# Creating output :  u9712808m_c0m_sci2_crmask.fits
# Creating output :  u9712908m_c0m_sci1_crmask.fits
# Creating output :  u9712902m_c0m_sci2_crmask.fits
# Creating output :  u9712802m_c0m_sci4_crmask.fits
# Creating output :  u9712905m_c0m_sci2_crmask.fits
# Creating output :  u9712808m_c0m_sci3_crmask.fits
# Creating output :  u9712805m_c0m_sci4_crmask.fits
# Creating output :  u9712808m_c0m_sci4_crmask.fits
# Creating output :  u9712908m_c0m_sci2_crmask.fits
# Creating output :  u9712902m_c0m_sci3_crmask.fits
# Creating output :  u9712905m_c0m_sci3_crmask.fits
# Creating output :  u9712908m_c0m_sci3_crmask.fits
# Creating output :  u9713002m_c0m_sci1_crmask.fits
# Creating output :  u9712902m_c0m_sci4_crmask.fits
# Creating output :  u9712905m_c0m_sci4_crmask.fits
# Creating output :  u9713005m_c0m_sci1_crmask.fits
# Creating output :  u9712908m_c0m_sci4_crmask.fits
# Creating output :  u9713002m_c0m_sci2_crmask.fits
# Creating output :  u9713008m_c0m_sci1_crmask.fits
# Creating output :  u9713005m_c0m_sci2_crmask.fits
# Creating output :  u9713102m_c0m_sci1_crmask.fits
# Creating output :  u9713002m_c0m_sci3_crmask.fits
# Creating output :  u9713008m_c0m_sci2_crmask.fits
# Creating output :  u9713005m_c0m_sci3_crmask.fits
# Creating output :  u9713105m_c0m_sci1_crmask.fits
# Creating output :  u9713102m_c0m_sci2_crmask.fits
# Creating output :  u9713002m_c0m_sci4_crmask.fits
# Creating output :  u9713108m_c0m_sci1_crmask.fits
# Creating output :  u9713005m_c0m_sci4_crmask.fits
# Creating output :  u9713008m_c0m_sci3_crmask.fits
# Creating output :  u9713008m_c0m_sci4_crmask.fits
# Creating output :  u9713202m_c0m_sci1_crmask.fits
# Creating output :  u9713105m_c0m_sci2_crmask.fits
# Creating output :  u9713108m_c0m_sci2_crmask.fits
# Creating output :  u9713102m_c0m_sci3_crmask.fits
# Creating output :  u9713205m_c0m_sci1_crmask.fits
# Creating output :  u9713105m_c0m_sci3_crmask.fits
# Creating output :  u9713202m_c0m_sci2_crmask.fits
# Creating output :  u9713208m_c0m_sci1_crmask.fits
# Creating output :  u9713102m_c0m_sci4_crmask.fits
# Creating output :  u9713108m_c0m_sci3_crmask.fits
# Creating output :  u9713205m_c0m_sci2_crmask.fits
# Creating output :  u9713302m_c0m_sci1_crmask.fits
# Creating output :  u9713208m_c0m_sci2_crmask.fits
# Creating output :  u9713105m_c0m_sci4_crmask.fits
# Creating output :  u9713202m_c0m_sci3_crmask.fits
# Creating output :  u9713305m_c0m_sci1_crmask.fits
# Creating output :  u9713108m_c0m_sci4_crmask.fits
# Creating output :  u9713205m_c0m_sci3_crmask.fits
# Creating output :  u9713208m_c0m_sci3_crmask.fits
# Creating output :  u9713302m_c0m_sci2_crmask.fits
# Creating output :  u9713308m_c0m_sci1_crmask.fits
# Creating output :  u9713305m_c0m_sci2_crmask.fits
# Creating output :  u9713202m_c0m_sci4_crmask.fits
# Creating output :  u9713402m_c0m_sci1_crmask.fits
# Creating output :  u9713205m_c0m_sci4_crmask.fits
# Creating output :  u9713308m_c0m_sci2_crmask.fits
# Creating output :  u9713208m_c0m_sci4_crmask.fits
# Creating output :  u9713302m_c0m_sci3_crmask.fits
# Creating output :  u9713405m_c0m_sci1_crmask.fits
# Creating output :  u9713305m_c0m_sci3_crmask.fits
# Creating output :  u9713308m_c0m_sci3_crmask.fits
# Creating output :  u9713302m_c0m_sci4_crmask.fits
# Creating output :  u9713305m_c0m_sci4_crmask.fits
# Creating output :  u9713402m_c0m_sci2_crmask.fits
# Creating output :  u9713405m_c0m_sci2_crmask.fits
# Creating output :  u9713308m_c0m_sci4_crmask.fits
# Creating output :  u9713405m_c0m_sci3_crmask.fits
# Creating output :  u9713402m_c0m_sci3_crmask.fits
# Creating output :  u9713408m_c0m_sci1_crmask.fits
# Creating output :  u9713405m_c0m_sci4_crmask.fits
# Creating output :  u9713402m_c0m_sci4_crmask.fits
# Creating output :  u9713502m_c0m_sci1_crmask.fits
# Creating output :  u9713408m_c0m_sci2_crmask.fits
# Creating output :  u9713505m_c0m_sci1_crmask.fits
# Creating output :  u9713508m_c0m_sci1_crmask.fits
# Creating output :  u9713408m_c0m_sci3_crmask.fits
# Creating output :  u9713602m_c0m_sci1_crmask.fits
# Creating output :  u9713502m_c0m_sci2_crmask.fits
# Creating output :  u9713505m_c0m_sci2_crmask.fits
# Creating output :  u9713605m_c0m_sci1_crmask.fits
# Creating output :  u9713502m_c0m_sci3_crmask.fits
# Creating output :  u9713602m_c0m_sci2_crmask.fits
# Creating output :  u9713408m_c0m_sci4_crmask.fits
# Creating output :  u9713508m_c0m_sci2_crmask.fits
# Creating output :  u9713608m_c0m_sci1_crmask.fits
# Creating output :  u9713505m_c0m_sci3_crmask.fits
# Creating output :  u9713508m_c0m_sci3_crmask.fits
# Creating output :  u9713608m_c0m_sci2_crmask.fits
# Creating output :  u9713502m_c0m_sci4_crmask.fits
# Creating output :  u9713605m_c0m_sci2_crmask.fits
# Creating output :  u9713602m_c0m_sci3_crmask.fits
# Creating output :  u9713505m_c0m_sci4_crmask.fits
# Creating output :  u9713602m_c0m_sci4_crmask.fits
# Creating output :  u9713508m_c0m_sci4_crmask.fits
# Creating output :  u9713608m_c0m_sci3_crmask.fits
# Creating output :  u9713605m_c0m_sci3_crmask.fits
# Creating output :  u9713608m_c0m_sci4_crmask.fits
# Creating output :  u9713605m_c0m_sci4_crmask.fits
# ==== Processing Step  Driz_CR  finished at  19:19:58.154 (21/08/2019)
#
# ==== Processing Step  Final Drizzle  started at  19:19:58.219 (21/08/2019)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 265.14766375561516  -53.666591554185345
# CRPIX : 774.5633782773134  764.505225604677
# CD1_1 CD1_2  : -1.9665111723156235e-05  -1.9460930742393273e-05
# CD2_1 CD2_2  : -1.9460930742393273e-05  1.9665111723156235e-05
# NAXIS : 1548  1528
# -Generating simple FITS output: final_drz_sci.fits
# Writing out image to disk: final_drz_sci.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: final_drz_wht.fits
# Deleted all instances of WCS with key A in extensions [0]
# Deleted all instances of WCS with key B in extensions [0]
# Writing out image to disk: final_drz_ctx.fits
# ==== Processing Step  Final Drizzle  finished at  19:26:02.094 (21/08/2019)
#
#
# AstroDrizzle Version 2.2.6 is finished processing at 19:26:02.097 (21/08/2019).
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          75.0487 sec.
#             Static Mask          18.5319 sec.
#            Subtract Sky          79.3718 sec.
#        Separate Drizzle          45.2732 sec.
#           Create Median          62.6906 sec.
#                    Blot          305.1578 sec.
#                 Driz_CR          70.2407 sec.
#           Final Drizzle          363.8750 sec.
#    ====================          ====================
#                   Total          1020.1898 sec.
# Trailer file written to:  astrodrizzle.log

# %%
drz = fits.getdata('final_drz_sci.fits')
plt.figure(figsize=(15, 15))
plt.imshow(drz, cmap='gray', vmin=-0.1, vmax=0.5, origin='lower')

# %% [markdown]
# # Individual image

# %%
singlename = 'u9712903m_c0m_single_sci.fits'
single = fits.getdata(singlename)
plt.figure(figsize=(15, 15))
plt.imshow(drz, cmap='gray', vmin=-0.1, vmax=0.5, origin='lower')

# %% [markdown]
# ## Cosmic Rays
#
# If there are a lot of cosmic rays in a small set of input images, some sources may be misidentified as cosmic rays, resulting in those PSFs having chopped-off peaks. Try adjusting the combine_nsigma, combine_nlow and combine_nhigh AstroDrizzle parameter values to get more optimal cosmic ray rejection parameter values for your images.

# %%
astrodrizzle.AstroDrizzle('u*c0m.fits',
                          preserve=False,
                          driz_sep_bits='8,1024',
                          driz_sep_wcs=True,
                          driz_sep_scale=0.0996,
                          combine_type='median',
                          driz_cr_snr='5.5 3.5',
                          driz_cr_scale='2.0 1.5',
                          final_fillval=None,
                          final_bits='8,1024',
                          final_wcs=True,
                          final_scale=0.0996,
                          combine_nsigma=,
                          combine_nlow=,
                          combine_nhigh=
                         )

# %% [markdown]
# # About this Notebook
#
# Based on notebook by
#
#     Author: M. Cara, STScI Data Analysis Tools Branch
#     Updated: December 14, 2018
